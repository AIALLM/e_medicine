# %%
from langchain_openai import ChatOpenAI
import os
import openai
import getpass
import tiktoken
from langchain.chains import RetrievalQA
from langchain.chat_models import ChatOpenAI
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.embeddings import HuggingFaceEmbeddings

# %%
os.environ["OPENAI_API_KEY"] = getpass.getpass()

# %%
tokenizer = tiktoken.get_encoding("cl100k_base")

def tiktoken_len(text):
    tokens = tokenizer.encode(text)
    return len(tokens)

# %%
from langchain_community.document_loaders.csv_loader import CSVLoader

loader = CSVLoader(file_path='e약은요_의약품명추가.csv')
data = loader.load()

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size = 1000, chunk_overlap = 200, length_function=tiktoken_len)
texts = text_splitter.split_documents(data)

# %%
model_name = "jhgan/ko-sbert-nli"
model_kwargs = {'device': 'cuda'}
encode_kwargs = {'normalize_embeddings': True}
hf = HuggingFaceEmbeddings(
    model_name=model_name,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs
)
# Out:
# c:\Users\Admin\anaconda3\envs\sba\lib\site-packages\torch\_utils.py:776: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()

# %%
#save to disk
#emed_db = Chroma.from_documents(texts, hf,persist_directory="./e약은요db_jhgan_의약품명추가")

# %%
#벡터db의 데이터가 in-memory가 아니라 persistent storage인 disk에 저장되게 선언
#emed_db.persist()
#emed_db = None

# %%
# load from disk
emed_db = Chroma(persist_directory="./e약은요db_jhgan_의약품명추가",embedding_function=hf)

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain.chains import create_history_aware_retriever, create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_community.chat_message_histories import ChatMessageHistory
from langchain_core.chat_history import BaseChatMessageHistory

openai = ChatOpenAI(model = "gpt-3.5-turbo",temperature=0)

retriever = emed_db.as_retriever(search_type="similarity", search_kwargs={'k':3})#search_type = "mmr",

def format_docs(docs):
    return "\n\n".join([d.page_content for d in docs])

contextualize_q_system_prompt = """Given a chat history and the latest user question \
which might reference context in the chat history, formulate a standalone question \
which can be understood without the chat history. Do NOT answer the question, \
just reformulate it if needed and otherwise return it as is."""

contextualize_q_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", contextualize_q_system_prompt),
        MessagesPlaceholder("chat_history"),
        ("human","{input}"),
    ]
)

history_aware_retriever = create_history_aware_retriever(
    openai, retriever, contextualize_q_prompt
)

#답변 생성
qa_system_prompt = """You are an assistant for question-answering tasks. \
ONLY USE the following pieces of retrieved context to answer the question. \
If you don't know the answer, just say that you don't know. \
Use three sentences maximum and keep the answer concise.\

{context}"""

qa_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", qa_system_prompt),
        MessagesPlaceholder("chat_history"),
        ("human", "{input}"),
    ]
)
question_answer_chain = create_stuff_documents_chain(openai, qa_prompt)

rag_chain = create_retrieval_chain(history_aware_retriever,question_answer_chain)

# chat history 관리
store = {}

def get_session_history(session_id : str) -> BaseChatMessageHistory:
    if session_id not in store:
        store[session_id] = ChatMessageHistory()
    return store[session_id]

conversational_rag_chain = RunnableWithMessageHistory(
    rag_chain,
    get_session_history,
    input_messages_key= "input",
    history_messages_key= "chat_history",
    output_messages_key= "answer",
)
# Out:
# c:\Users\Admin\anaconda3\envs\sba\lib\site-packages\langchain_core\_api\deprecation.py:119: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(

# %%
id = "0"
query1 = "게보린정 효능 알려줘"
conversational_rag_chain.invoke(
    {"input": query1},
    config={
        "configurable": {"session_id":id}
    },
)["answer"]
# Out:
# '죄송합니다, "게보린정"에 대한 정보를 찾을 수 없습니다.'

# %% [markdown]
# # Test 수행

# %%
import pandas as pd

# %%
test_data = pd.read_excel("data preprocessing\e약은요 테스트용 질문 데이터셋.xlsx")
test_data.head()
# Out:
#                                  question  \
# 0                      닥터베아제정의 효능은 무엇입니까?
# 1                      닥터베아제정은 어떻게 사용합니까?
# 2    닥터베아제정을 사용하기 전에 반드시 알아야 할 내용은 무엇입니까?
# 3                닥터베아제정의 사용상 주의사항은 무엇입니까?
# 4  닥터베아제정을 사용하는 동안 주의해야 할 약 또는 음식은 무엇입니까?
#
#                                               answer
# 0  이 약은 소화불량, 식욕감퇴(식욕부진), 과식, 체함, 소화촉진, 소화불량으로 인한...
# 1                         성인 1회 1정을 1일 3회 식후에 복용합니다.
# 2                                                NaN
# 3  만 7세 이하의 소아는 이 약을 복용하지 마십시오.이 약을 복용하기 전에 알레르기 ...
# 4                                                NaN

# %% [markdown]
# ### 참고사항
# 추후에 특정 의약품에 대한 질문을 이어서했을때의 정확도를 살피고자 할때는 session_id로 제공되는 부분에 의약품명을 넣으면 된다.
#
# 의약품명을 넣는 방법은 애초에 데이터셋을 만들때 의약품명 열을 하나 추가하면 된다

# %%
import time
def measure_time(func):
    def wrapper(*args, **kwargs):
        start_time = time.time()
        result = func(*args, **kwargs)
        end_time = time.time()
        elapsed_time = end_time - start_time
        print(f"{func.__name__} 실행 시간: {elapsed_time} 초")
        return result
    return wrapper

# %%
@measure_time
def invoke(id, input):
    answer = conversational_rag_chain.invoke(
        {"input": input},
        config={
            "configurable": {"session_id":id}
        },
    )["answer"]

    return answer

# %%
answer = [] #llm의 응답을 저장할 리스트
for i, row in test_data.iterrows():
    answer.append(invoke(row.question, row.question))
    print(i+1,'번째 답변 : ',answer[i])
# Out:
# invoke 실행 시간: 1.7884516716003418 초
# 1 번째 답변 :  이 약은 소화불량, 식욕감퇴(식욕부진), 과식, 체함, 소화촉진, 소화불량으로 인한 위부팽만감에 사용됩니다.
# invoke 실행 시간: 1.373920202255249 초
# 2 번째 답변 :  성인 1회 1정을 1일 3회 식후에 복용합니다.
# invoke 실행 시간: 1.446096658706665 초
# 3 번째 답변 :  죄송합니다, 닥터베아제정에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 1.4820244312286377 초
# 4 번째 답변 :  죄송합니다, 닥터베아제정에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 1.428302526473999 초
# 5 번째 답변 :  죄송합니다, 닥터베아제정에 대한 정보가 제공되지 않았기 때문에 해당 질문에 대한 답변을 제공할 수 없습니다.
# invoke 실행 시간: 4.5406293869018555 초
# 6 번째 답변 :  죽상증상(호흡곤란, 전신조홍, 혈관부종, 두드러기), 천식발작, 과민증(홍반, 간지러움, 코막힘, 심장-호흡기 장애, 때때로 발진, 부종, 두드러기, 비염양 증상, 결막염) 등의 이상반응이 나타날 수 있습니다. 드물게 독성표피괴사용해(리엘증후군), 피부점막안증후군(스티븐스-존슨증후군), 박탈성피부염, 재생불량성빈혈, 빈혈, 백혈구감소, 혈소판감소, 혈소판기능 저하(출혈시간의 지연) 등도 나타날 수 있습니다.
# invoke 실행 시간: 0.7348203659057617 초
# 7 번째 답변 :  실온에서 보관하십시오.
# invoke 실행 시간: 1.454892635345459 초
# 8 번째 답변 :  맥시부펜시럽(덱시부프로펜)의 효능은 급성 상기도 감염으로 인한 발열 시 해열에 사용합니다.
# invoke 실행 시간: 3.395472526550293 초
# 9 번째 답변 :  생후 6개월 이상의 소아는 1회 0.4~0.6 mL/kg(5~7 mg/kg), 4~6시간 간격으로 필요시에 복용하며, 1일 최대 4회(28 mg/kg)를 넘지 않습니다. 체중이 30 kg 이하인 소아에게는 1일 최대 25 mL(300 mg)을 초과하지 않습니다. 몸무게를 알 경우 몸무게에 따른 용량으로 복용하는 것이 더 적절하므로 연령대별 권장용량은 허가사항을 참고하십시오.
# invoke 실행 시간: 1.9282424449920654 초
# 10 번째 답변 :  죄송합니다. 맥시부펜시럽(덱시부프로펜)에 대한 정보가 없어서 정확한 답변을 제공할 수 없습니다. 해당 의약품에 대한 상세 정보를 확인하시거나 의사 또는 약사와 상의하시는 것이 좋습니다.
# invoke 실행 시간: 4.578374624252319 초
# 11 번째 답변 :  맥시부펜시럽(덱시부프로펜)의 사용상 주의사항은 다음과 같습니다: 이 약을 복용하기 전에 과민증 환자, 소화성궤양, 심한 혈액이상, 심한 간장애, 심한 신장장애, 심한 심부전, 심한 고혈압, 기관지천식, 아스피린 또는 다른 소염진통제에 의한 천식, 두드러기, 알레르기 경험 환자, 심장동맥 우회로술 전후 통증 치료 환자, 임부 또는 임신하고 있을 가능성이 있는 여성 및 수유부는 이 약을 복용하지 마십시오. 장기 복용할 경우 원칙적으로 5일 이내로 합니다.
# invoke 실행 시간: 4.5292136669158936 초
# 12 번째 답변 :  다른 비스테로이드성 소염진통제, 아스피린, 고용량의 메토트렉세이트와 함께 사용하지 마십시오. 글루코코르티코이드, 알코올, 디곡신, 페니토인, 프로베네시드, 설핀피라존, 설포닐우레아제, 이뇨제와 항고혈압제 병용, ACE 억제제, 푸로세미드, 리튬, 저용량의 메토트렉세이트, 쿠마린계 항응고제(와파린 등)와 함께 사용 시 의사 또는 약사와 상담하십시오.
# invoke 실행 시간: 2.9128518104553223 초
# 13 번째 답변 :  맥시부펜시럽(덱시부프로펜) 복용 시 드물하게 혈액장애, 소화관 이상, 시각장애, 혈액학적 이상, 신장 이상, 혈액액체량 감소, 숨가쁨, 부종, 발열 등의 이상반응이 나타날 수 있습니다. 이러한 증상이 나타나면 즉시 의사나 약사와 상의해야 합니다.
# invoke 실행 시간: 1.8181192874908447 초
# 14 번째 답변 :  맥시부펜시럽(덱시부프로펜)은 습기와 빛을 피해 실온에서 보관해야 합니다. 어린이의 손이 닿지 않는 곳에 보관하는 것이 좋습니다.
# invoke 실행 시간: 2.2094099521636963 초
# 15 번째 답변 :  뮤테란과립200밀리그램(아세틸시스테인)은 급ㆍ만성기관지염, 기관지천식, 후두염, 부비동염, 낭성섬유증의 질환에서 객담배출곤란에 사용됩니다.
# invoke 실행 시간: 4.4912824630737305 초
# 16 번째 답변 :  급성질환에 성인은 1회 1포(200 mg)씩, 1일 3회, 6~14세는 1회 1포(200 mg)씩, 1일 2회, 2~5세는 1회 1/2 포(100 mg)씩, 1일 3회 소량의 물과 함께 복용합니다. 만성질환에 성인은 1회 1포(200 mg)씩, 1일 2회, 6~14세는 1회 1/2 포(100 mg)씩, 1일 3회 소량의 물과 함께 복용합니다. 낭성섬유증에 6세 이상은 1회 1포(200 mg)씩, 1일 3회, 2~5세는 1회 1/2 포(100 mg)씩, 1일 4회 소량의 물과 함께 복용합니다.
# invoke 실행 시간: 1.058978796005249 초
# 17 번째 답변 :  죄송합니다. 그 질문에 대한 정보를 찾을 수 없습니다.
# invoke 실행 시간: 2.378654956817627 초
# 18 번째 답변 :  이 약에 과민증 환자, 위•십이지장궤양, 2세 미만 영아는 이 약을 복용하지 마십시오. 이 약을 복용하기 전에 임부 또는 임신하고 있을 가능성이 있는 여성 및 수유부는 의사 또는 약사와 상담하십시오.
# invoke 실행 시간: 4.913527488708496 초
# 19 번째 답변 :  경구용 항생제(아목시실린, 세푸록심, 독시사이클린, 에리트로마이신, 티암페니콜)와 함께 복용 시 적어도 2시간 간격을 두고 복용하십시오.
# invoke 실행 시간: 52.296186208724976 초
# 20 번째 답변 :  죽상, 두통, 어지러움, 구역, 구토, 설사, 가려움, 발진, 발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진, 피부발진
# invoke 실행 시간: 1.2182424068450928 초
# 21 번째 답변 :  실온에서 보관하십시오. 어린이의 손이 닿지 않는 곳에 보관하십시오.
# invoke 실행 시간: 2.082628011703491 초
# 22 번째 답변 :  이 약은 급ㆍ만성기관지염, 기관지천식, 후두염, 부비동염, 낭성섬유증의 질환에서 객담배출곤란에 사용합니다.
# invoke 실행 시간: 5.758680105209351 초
# 23 번째 답변 :  급성질환에 성인은 1회 1캡슐(200 mg)씩, 1일 3회, 6~14세는 1회 1캡슐(200 mg)씩, 1일 2회 식전에 소량의 물과 함께 복용합니다. 만성질환에 성인은 1회 1캡슐(200 mg)씩, 1일 2회, 6~14세는 1회 1/2 캡슐(100 mg)씩, 1일 3회 식전에 소량의 물과 함께 복용합니다. 낭성섬유증에 6세 이상은 1회 1캡슐(200 mg)씩, 1일 3회 식전에 소량의 물과 함께 복용합니다.
# invoke 실행 시간: 1.7980468273162842 초
# 24 번째 답변 :  죄송합니다. 그 정보에는 뮤테란캡슐200밀리그램(아세틸시스테인)에 대한 내용이 포함되어 있지 않습니다.
# invoke 실행 시간: 3.2429134845733643 초
# 25 번째 답변 :  이 약에 과민증 환자, 위•십이지장궤양, 2세 미만 영아, 갈락토오스 불내성, Lapp 유당분해효소 결핍증 또는 포도당-갈락토오스 흡수장애 등의 유전적인 문제가 있는 환자는 이 약을 복용하지 마십시오. 이 약을 복용하기 전에 임부 또는 임신하고 있을 가능성이 있는 여성 및 수유부는 의사 또는 약사와 상담하십시오.
# invoke 실행 시간: 1.7381031513214111 초
# 26 번째 답변 :  경구용 항생제(아목시실린, 세푸록심, 독시사이클린, 에리트로마이신, 티암페니콜)와 함께 복용 시 적어도 2시간 간격을 두고 복용하십시오.
# invoke 실행 시간: 6.309467554092407 초
# 27 번째 답변 :  쇽 증상(호흡곤란, 전신조홍, 혈관부종, 두드러기), 천식발작, 과민증(홍반, 간지러움, 코막힘, 심장-호흡기 장애, 때때로 발진, 부종, 두드러기, 비염양 증상, 결막염), 드물게 독성표피괴사용해(리엘증후군), 피부점막안증후군(스티븐스-존슨증후군), 박탈성피부염, 재생불량성빈혈, 빈혈, 백혈구감소, 혈소판감소, 혈소판기능 저하(출혈시간의 지연), 귀에서 소리가 남, 귀 먹음, 어지러움, 두통, 흥분, 드물게 간장애, 매우 드물게 일시적인 간손상, 신장애, 급성신부전, 과호흡, 대사성 산증, 과도한 체온강하, 허탈, 사지냉각 등이 나타날 수 있습니다.
# invoke 실행 시간: 1.2404208183288574 초
# 28 번째 답변 :  실온에서 보관하십시오. 어린이의 손이 닿지 않는 곳에 보관하십시오.
# invoke 실행 시간: 1.5411367416381836 초
# 29 번째 답변 :  이 약은 소화불량, 식욕감퇴(식욕부진), 과식, 체함, 소화촉진, 소화불량으로 인한 위부팽만감에 사용합니다.
# invoke 실행 시간: 1.4348015785217285 초
# 30 번째 답변 :  성인 1회 1정을 1일 3회 식후에 복용합니다.
# invoke 실행 시간: 1.1571455001831055 초
# 31 번째 답변 :  죄송합니다, 베아제정에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 1.2973310947418213 초
# 32 번째 답변 :  죄송합니다, 제가 찾은 정보에는 '베아제정'에 대한 내용이 포함되어 있지 않습니다.
# invoke 실행 시간: 1.0916144847869873 초
# 33 번째 답변 :  죄송합니다, 제가 찾은 정보에는 "베아제정"에 대한 내용이 포함되어 있지 않습니다.
# invoke 실행 시간: 57.97080659866333 초
# 34 번째 답변 :  죽상, 혈액응고장애, 혈소판감소, 혈소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액소판감소, 혈액소판기능저하, 혈액소판증가, 혈액소판기능증가, 혈액
# invoke 실행 시간: 0.7288329601287842 초
# 35 번째 답변 :  저는 베아제정에 대한 정보를 찾을 수 없습니다.
# invoke 실행 시간: 2.787006378173828 초
# 36 번째 답변 :  이 약은 기관지천식, 만성기관지염, 기관지확장증, 폐결핵, 폐기종, 상기도염(인·후두염), 폐화농증, 폐렴, 낭성섬유증, 수술후 폐합병증의 객담배출곤란과 기관지조영, 기관지경 검사, 폐암 세포진, 기관절개술의 전·후 처치에 사용합니다.
# invoke 실행 시간: 2.9913523197174072 초
# 37 번째 답변 :  안면마스크, 마우스피스, 기관누공형성술을 이용한 분무요법은 1~10 mL를 2~6시간마다 분무합니다. 추천양은 3~5 mL를 1일 3~4회 분무하는 것이 권장됩니다. 직접 주입하는 경우 1~2 mL을 1시간마다 투여하며, 다양한 투여 방법에 따라 적절한 용법을 선택하여 사용해야 합니다.
# invoke 실행 시간: 1.7091000080108643 초
# 38 번째 답변 :  제공된 정보에는 "보령뮤코미스트액(아세틸시스테인)"에 대한 내용이 포함되어 있지 않습니다. 따라서 해당 약물에 대한 정보를 제공할 수 없습니다.
# invoke 실행 시간: 7.559820652008057 초
# 39 번째 답변 :  이 약은 기관지천식, 만성기관지염, 기관지확장증, 폐결핵, 폐기종, 상기도염(인·후두염), 폐화농증, 폐렴, 낭성섬유증, 수술후 폐합병증의 객담배출곤란과 기관지조영, 기관지경 검사, 폐암 세포진, 기관절개술의 전·후 처치에 사용됩니다. 사용 전에 기관지천식 또는 그 경험자, 심기능부전 환자, 신장, 간장애, 고혈압, 혈액 이상 또는 그 경험자, 출혈 경향이 있는 환자, 고령자, 말초동맥폐색증, 뇌혈관질환, 고지혈증, 당뇨병, 흡연자, 고초열, 코폴립, 만성 폐쇄성 폐질환, 임신 초기 및 중기의 임부, 체액저류, 심부전 환자는 의사나 약사와 상의해야 합니다.
# invoke 실행 시간: 1.1884772777557373 초
# 40 번째 답변 :  죄송합니다, 그에 대한 정보를 찾을 수 없습니다.
# invoke 실행 시간: 3.6294126510620117 초
# 41 번째 답변 :  쇽 증상(호흡곤란, 전신조홍, 혈관부종, 두드러기 등), 과민증(홍반, 간지러움, 코막힘, 심장-호흡기 장애, 때때로 발진, 부종, 두드러기, 비염양 증상, 결막염), 드물게 독성표피괴사용해(리엘증후군), 피부점막안증후군(스티븐스-존슨증후군) 등이 나타날 수 있습니다.
# invoke 실행 시간: 3.2605373859405518 초
# 42 번째 답변 :  보령뮤코미스트액(아세틸시스테인)은 직사광선을 피해 서늘하고 건조한 곳에 보관해야 합니다. 어린이 손이 닿지 않는 곳에 보관하고, 밀봉을 깨지 않도록 밀봉용 뚜껑을 닫아야 합니다.습기와 물기를 피해 보관하는 것이 좋습니다.
# invoke 실행 시간: 1.3826334476470947 초
# 43 번째 답변 :  이 약은 감기로 인한 발열 및 통증에 사용합니다.
# invoke 실행 시간: 2.7448511123657227 초
# 44 번째 답변 :  3~6세는 1회 2개, 1~2세는 1회 1~2개, 3~12개월은 1회 1개씩, 1일 2~3회 좌약의 둥근부분부터 직장내 깊이 삽입합니다. 직장 근육긴장으로 밀려나올 경우에는 양쪽대퇴부를 오므려 약 1분간 안아줍니다.
# invoke 실행 시간: 1.3946399688720703 초
# 45 번째 답변 :  죄송합니다, 복합써스펜좌약에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 1.4913687705993652 초
# 46 번째 답변 :  죄송합니다, 그 정보에는 "복합써스펜좌약"에 대한 내용이 포함되어 있지 않습니다.
# invoke 실행 시간: 3.2960474491119385 초
# 47 번째 답변 :  아세트아미노펜을 포함하는 다른 제품, 다른 소염진통제, 다른 해열진통제와 함께 사용하지 마십시오. 이 약을 사용하기 전에 바르비탈계 약물, 삼환계 항우울제, 알코올을 투여한 환자, 리튬, 티아지드계 이뇨제, 레보도파와 함께 사용 시 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 0.8054990768432617 초
# 48 번째 답변 :  죄송합니다, 그 정보를 제공할 수 없습니다.
# invoke 실행 시간: 0.7623822689056396 초
# 49 번째 답변 :  저는 그에 대한 정보를 갖고 있지 않습니다.
# invoke 실행 시간: 4.56385350227356 초
# 50 번째 답변 :  이 약은 류마티양 관절염, 연소성 류마티양 관절염, 골관절염(퇴행성 관절질환), 감기로 인한 발열 및 동통, 요통, 월경곤란증, 수술후 동통과 강직성 척추염, 두통, 치통, 근육통, 신경통, 급성통풍, 건선성 관절염, 연조직손상(염좌, 좌상), 비관절 류마티스질환(건염, 건초염, 활액낭염)에 사용됩니다.
# invoke 실행 시간: 2.2526695728302 초
# 51 번째 답변 :  11~14세는 1회 200~250 mg (10~13 mL), 7~10세는 1회 150~200 mg (8~10 mL), 3~6세는 1회 100~150 mg (5~8 mL), 1~ 2세는 1회 50~100 mg (3~5 mL)을 1일 3~4회 복용합니다.
# invoke 실행 시간: 3.275235414505005 초
# 52 번째 답변 :  어린이부루펜시럽(이부프로펜)을 사용하기 전에 알아야 할 내용은 다음과 같습니다: 이 약에 과민증 환자, 위장관궤양, 출혈, 간장애, 신장장애, 심장기능부전, 고혈압, 천식, 두드러기, 알레르기 반응 경험자, 임부, 수유부, 항암요법으로 고용량 메토트렉세이트를 투여 중인 환자 등은 이 약을 복용하지 말아야 합니다.
# invoke 실행 시간: 2.135669231414795 초
# 53 번째 답변 :  어린이부루펜시럽(이부프로펜)의 사용상 주의사항은 빛을 피해 실온에서 보관해야 합니다.성인은 1회 1정, 1일 1회 복용하며, 장용정이므로 충분한 물과 함께 식전에 복용할 수 있습니다.
# invoke 실행 시간: 4.3368823528289795 초
# 54 번째 답변 :  쇽(호흡곤란, 두드러기 등), 천식발작, 드물게 혈소판감소, 과립구감소, 용혈성빈혈, 메트헤모글로빈혈증, 청색증, 드물게 발진, 안면부종, 호흡곤란, 발한, 저혈압, 구역, 구토, 식욕부진, 설사, 변의, 피부점막안증후군(스티븐스-존슨증후군), 독성표피괴사용해(리엘증후군) 등이 나타날 수 있습니다. 사용 시 즉시 중지하고 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 5.25774359703064 초
# 55 번째 답변 :  쇽(호흡곤란, 혈압저하 등), 헤마토크리트감소, 헤모글로빈감소, 빈혈, 재생불량성빈혈, 용혈성빈혈, 무과립구증, 과립구감소, 백혈구감소, 혈소판감소, 혈소판기능저하 등의 혈액장애, 소화성궤양, 위장관궤양, 위장출혈, 천공(뚫림), 궤양성대장염, 혈변, 위염, 췌장염, 혈액구토, 크론병, 식욕부진, 구역, 구토, 복통, 소화불량, 설사, 위부불쾌감, 상복부통증, 구갈, 구내염, 복부팽만감, 구강궤양, 변비, 흑변, 피부점막안증후군(스티븐스-존슨증후군), 독성표피괴사용해 등의 이상반응이 나타날 수 있습니다. 부작용이 발생하면 즉시 의사나 약사와 상의해야 합니다.
# invoke 실행 시간: 1.567169427871704 초
# 56 번째 답변 :  습기와 빛을 피해 실온에서 보관하고 어린이의 손이 닿지 않는 곳에 보관해야 합니다.
# invoke 실행 시간: 2.131887197494507 초
# 57 번째 답변 :  이 약은 감기로 인한 발열 및 동통(통증), 두통, 신경통, 근육통, 월경통, 염좌통(삔 통증), 치통, 관절통, 류마티양 동통(통증)에 사용됩니다.
# invoke 실행 시간: 4.862699270248413 초
# 58 번째 답변 :  만 12세 이하의 소아는 1회 권장용량을 4-6시간마다 필요 시 복용합니다. 1일 5회(75 mg/kg)를 초과하여 복용하지 마십시오. 연령대별 권장용량은 허가사항을 참고하십시오.
# invoke 실행 시간: 2.482323408126831 초
# 59 번째 답변 :  아세트아미노펜에 과민증 환자, 천식 또는 경험자, 심한 간 또는 신장 기능장애, 혈액 이상 환자, 임부 또는 수유부는 이 약을 사용하지 말아야 합니다. 이 약을 사용하기 전에 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 6.590696573257446 초
# 60 번째 답변 :  이 약에 과민증, 소화성궤양, 심한 혈액 이상 환자, 심한 간장애, 심한 신장(콩팥)장애, 심한 심장기능저하, 아스피린 천식(비스테로이드성 소염(항염)제에 의한 천식발작 유발) 또는 경험자, 바르비탈계 약물 또는 삼환계 항우울제 복용한 환자, 알코올을 복용한 사람은 이 약을 복용하지 마십시오. 이 약을 복용하기 전에 간장애 환자 또는 경험자, 신장(콩팥)장애 환자 또는 경험자, 소화성궤양 경험자, 혈액이상 환자 또는 경험자, 출혈경향이 있는 환자, 심장기능이상이 있는 환자, 과민증의 경험자, 기관지천식 환자, 고령자(노인), 만 2세 미만의 소아, 임부 또는 수유부는 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 3.120425224304199 초
# 61 번째 답변 :  아세트아미노펜을 사용하는 동안 다른 해열진통제, 진정제, 멀미약, 프로베네시드, 설핀피라존, 디곡신, 페니토인, 바크로펜, 이뇨제, 항고혈압제, ACE 저해제(억제제), 푸로세미드, 아스피린, 리튬, 메토트렉세이트, 경구용 항응혈제(와파린 등)와 함께 복용하지 마십시오.
# invoke 실행 시간: 5.317647933959961 초
# 62 번째 답변 :  쇽 증상(호흡곤란, 온몸이 붉어짐, 혈관부기, 두드러기 등), 천식발작, 혈소판감소, 과립구감소, 용혈성빈혈, 메트헤모글로빈혈증, 혈소판기능 저하(출혈시간 연장), 청색증, 과민증상(얼굴부기, 땀이 남, 저혈압), 구역, 구토, 식욕부진, 위장출혈, 소화성궤양, 천공(뚦림), 발진, 피부점막안증후군(스티븐스-존슨증후군), 독성표피괴사증(리엘증후군), AST 상승, ALT 상승, 고정발진 등이 나타날 수 있습니다. 이러한 증상이 나타나면 즉시 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 1.2135610580444336 초
# 63 번째 답변 :  습기와 빛을 피해 실온에서 보관하십시오. 어린이의 손이 닿지 않는 곳에 보관하십시오.
# invoke 실행 시간: 2.0194714069366455 초
# 64 번째 답변 :  이 약은 코감기(급성비염), 알레르기성 비염 또는 부비동염에 의한 코막힘, 콧물, 재채기, 머리무거움의 완화에 사용합니다.
# invoke 실행 시간: 2.195765256881714 초
# 65 번째 답변 :  만 12세 이상의 청소년 또는 성인은 1일 3회의 범위 내에서, 1회 1번 각 비강(코안)에 뿌립니다. 적용 간격은 8시간 이상으로 합니다.
# invoke 실행 시간: 1.1549046039581299 초
# 66 번째 답변 :  죄송합니다, 그에 대한 정보를 찾을 수 없습니다.
# invoke 실행 시간: 1.0720887184143066 초
# 67 번째 답변 :  죄송합니다, 그 정보에 대한 내용은 제공되지 않았습니다.
# invoke 실행 시간: 1.2919456958770752 초
# 68 번째 답변 :  죄송합니다, 그 정보에 대한 내용은 제가 가지고 있지 않습니다.
# invoke 실행 시간: 4.5963215827941895 초
# 69 번째 답변 :  전염성 농가진, 모낭염, 칸디다증, 백선, 부스럼, 피부자극, 자통, 발열, 작열감(화끈감), 발진, 발적, 홍조, 가려움, 피부건조, 농포성피부염, 알레르기성 접촉피부염, 땀띠, 한진, 상처악화, 욕창, 농포증 등의 이상반응이 나타날 수 있습니다. 또한, 매우 드물게 두드러기, 피부박탈, 색소침착 변화, 적용 부위 자극/통증이 나타나는 경우 사용을 즉각 중지하고 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 1.7187976837158203 초
# 70 번째 답변 :  실온에서 보관하고 어린이의 손이 닿지 않는 곳에 보관해야 합니다.
# invoke 실행 시간: 1.9695985317230225 초
# 71 번째 답변 :  죄송합니다, 임팩타민프리미엄정에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 1.1743555068969727 초
# 72 번째 답변 :  죄송합니다, 임팩타민프리미엄정에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 1.313751220703125 초
# 73 번째 답변 :  죄송합니다, 그 정보에는 임팩타민프리미엄정에 대한 내용이 포함되어 있지 않습니다.
# invoke 실행 시간: 1.306358814239502 초
# 74 번째 답변 :  죄송합니다, 임팩타민프리미엄정에 대한 정보는 제공할 수 없습니다.
# invoke 실행 시간: 1.1487128734588623 초
# 75 번째 답변 :  죄송합니다, 임팩타민프리미엄정에 대한 정보가 없어서 도움을 드릴 수 없습니다.
# invoke 실행 시간: 1.1619844436645508 초
# 76 번째 답변 :  죄송합니다, 임팩타민프리미엄정에 대한 정보가 없어서 이상반응에 대해 알 수 없습니다.
# invoke 실행 시간: 1.0969429016113281 초
# 77 번째 답변 :  실온에서 보관하십시오.어린이의 손이 닿지 않는 곳에 보관하십시오.
# invoke 실행 시간: 2.310983419418335 초
# 78 번째 답변 :  이 약은 삠, 타박상, 근육통, 관절통, 골절통, 요(허리)통, 어깨결림, 신경통, 류마티스통증의 진통ㆍ소염(항염)에 사용합니다.
# invoke 실행 시간: 1.746419906616211 초
# 79 번째 답변 :  제일쿨파프의 사용 방법은 성인은 1회 1정, 1일 1회 복용하며, 장용정이므로 충분한 물과 함께 식전에 복용할 수 있습니다.
# invoke 실행 시간: 0.9941082000732422 초
# 80 번째 답변 :  제일쿨파프에 대한 정보를 찾을 수 없습니다.
# invoke 실행 시간: 12.736254692077637 초
# 81 번째 답변 :  이 약 또는 아스피린, 다른 비스테로이드성 소염진통제에 과민증 환자, 소화성궤양, 출혈, 아스피린 또는 다른 비스테로이드성 소염진통제에 의한 천식(천식발작 포함), 두드러기, 기관지경련, 비염 또는 경험자, 중증 심기능부전, 비스테로이드성 소염진통제, 항류마티스제에 의한 위장관 출혈 또는 천공, 중증 대장염, 중증 혈액 이상 환자, 불분명한 조혈장애, 중증 간장애, 중증 신장애, 임신 후기 3개월인 임부, 유전성 과당 불내증, 포도당-갈락토오스 흡수장애, 백당-이소말타아제 결핍증 환자는 이 약을 복용하지 마십시오.이 약을 복용하기 전에 기관지천식 또는 그 경험자, 심기능부전 환자 및 신장, 간장애, 고혈압, 혈액 이상 또는 그 경험자, 출혈 경향이 있는 환자, 고령자, 말초동맥폐색증, 뇌혈관질환, 고지혈증, 당뇨병, 흡연자, 고초열, 코폴립, 만성 폐쇄성 폐질환, 임신 초기 및 중기의 임부, 체액저류, 심부전 환자는 의사 또는 약사와 상의하십시오.이 약 복용 후 어지러움 및 시각장애가 나타날 수 있으므로 운전 및 기계조작 시 주의하십시오.
# invoke 실행 시간: 1.1497015953063965 초
# 82 번째 답변 :  제일쿨파프에 대한 정보가 없어서 답변드릴 수 없습니다.
# invoke 실행 시간: 4.6077892780303955 초
# 83 번째 답변 :  쇽(호흡곤란, 혈압저하 등), 헤마토크리트감소, 헤모글로빈감소, 빈혈, 재생불량성빈혈, 용혈성빈혈, 무과립구증, 과립구감소, 백혈구감소, 혈소판감소 등의 혈액장애, 소화성궤양, 위장관궤양, 위장출혈, 천공(뚫림), 궤양성대장염, 혈변, 위염, 췌장염, 혈액구토, 크론병, 식욕부진, 구역, 구토, 복통, 소화불량 등의 소화기 장애, 피부점막안증후군(스티븐스-존슨증후군) 등의 피부 반응이 나타날 수 있습니다.
# invoke 실행 시간: 0.9943208694458008 초
# 84 번째 답변 :  죄송합니다, 제일쿨파프에 대한 정보가 없어서 답변을 제공할 수 없습니다.
# invoke 실행 시간: 2.12308669090271 초
# 85 번째 답변 :  이 약은 계절성 및 다년성 알레르기성 비염, 알레르기성 결막염, 만성 특발성 두드러기, 피부가려움증과 하이드로코티손 외용제와 병용에 의한 습진, 피부염에 사용됩니다.
# invoke 실행 시간: 3.453101873397827 초
# 86 번째 답변 :  성인 및 6세 이상의 소아는 1일 1회 1정(10 mg)을 취침 전에 복용하고, 이상반응에 민감한 환자의 경우는 1/2정(5 mg)씩을 아침, 저녁에 분할 복용합니다. 연령, 증상에 따라 적절히 증감하며, 신장애 환자의 투여 간격은 환자의 신기능에 따라 조절되어야 합니다.
# invoke 실행 시간: 1.470292091369629 초
# 87 번째 답변 :  죄송합니다, 그 정보에는 "지르텍정(세티리진염산염)"에 대한 내용이 포함되어 있지 않습니다.
# invoke 실행 시간: 2.959118366241455 초
# 88 번째 답변 :  이 약 및 히드록시진 또는 피페라진 유도체에 과민증 환자, 신부전 환자, 신장애를 가진 소아 환자, 노인, 간질 및 발작 위험성이 있는 환자, 임부, 수유부는 의사 또는 약사와 상의해야 합니다. 이 약을 사용하는 동안 주의해야 할 점입니다.
# invoke 실행 시간: 3.480787515640259 초
# 89 번째 답변 :  콜키신, 에리스로마이신, 클라리스로마이신, 테리토마이신, 레보플록사신, 목시플록사신, 퀴놀론계 항균제, 푸로세미드 이뇨제, 경구용 항응혈제(와파린), 항고혈압제, 리튬제제, 미페프리스톤, 프로베네시드, 설핀피라존을 함께 복용하지 마십시오. (출처: 약품설명서)
# invoke 실행 시간: 5.744727849960327 초
# 90 번째 답변 :  쇽 증상(예: 호흡곤란, 전신조홍, 혈관부종, 두드러기), 천식발작, 과민증(홍반, 간지러움, 코막힘, 심장-호흡기 장애, 때때로 발진, 부종, 두드러기, 비염양 증상, 결막염) 등의 이상반응이 나타날 수 있습니다. 드물게 독성표피괴사용해(리엘증후군), 피부점막안증후군(스티븐스-존슨증후군), 박탈성피부염, 재생불량성빈혈, 빈혈, 백혈구감소, 혈소판감소, 혈소판기능 저하(출혈시간의 지연) 등의 이상반응도 있을 수 있습니다.식욕부진, 가슴쓰림, 위통, 구역, 구토 등의 증상도 나타날 수 있습니다.
# invoke 실행 시간: 1.283571481704712 초
# 91 번째 답변 :  실온에서 보관하십시오. 어린이의 손이 닿지 않는 곳에 보관하십시오.
# invoke 실행 시간: 4.139282941818237 초
# 92 번째 답변 :  케노펜겔(케토프로펜)의 효능은 퇴행성관절염(골관절염), 어깨관절주위염, 건ㆍ건초염, 건주위염, 상완골상과염(테니스 엘보우 등), 근육통, 외상후의 종창ㆍ동통의 진통ㆍ소염에 사용합니다.
# invoke 실행 시간: 3.104482889175415 초
# 93 번째 답변 :  케노펜겔(케토프로펜)은 증상에 따라 적당량을 1일 1~4회 환부에 바르고 잘 스며들도록 가볍게 문지릅니다.
# invoke 실행 시간: 7.233072519302368 초
# 94 번째 답변 :  케노펜겔(케토프로펜)을 사용하기 전에 반드시 알아야 할 내용은 과민증 환자, 아스피린 또는 다른 비스테로이드성 소염진통제에 과민증 환자, 소화성궤양, 심한 혈액이상, 심한 간장애, 심한 신장장애, 심한 심장기능부전, 심한 고혈압, 기관지천식, 관상동맥 우회술(CABG) 전후 통증발생 환자, 임부, 수유부, 2세 이하의 영아는 이 약을 사용하지 말아야 합니다. 이 약을 사용하기 전에 소화성궤양 경험자, 혈액이상, 출혈 경향이 있는 환자, 간장애, 신장애, 심기능 장애, 고혈압, 과민증 경험자, 기관지천식, 전신홍반루푸스 및 혼합 결합조직질환(MCTD), 고령자, 황색5호에 과민증 환자는 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 6.959131240844727 초
# 95 번째 답변 :  케노펜겔(케토프로펜)의 사용상 주의사항은 다음과 같습니다: 이 약에 과민증, 광과민증, 아스피린 또는 다른 소염진통제에 의한 천식 경험 환자, 티아프로펜산ㆍ페노피브레이트ㆍ베자피브레이트ㆍ시프로피브레이트ㆍ옥시벤존에 과민증, 임신기간 6개월 이상인 임부, 15세 미만의 소아는 이 약을 사용하지 마십시오. 이 약을 사용하기 전에 기관지천식, 임부, 수유부는 의사 또는 약사와 상의하십시오. 광과민증이 나타날 수 있으므로, 이 약을 사용 중이거나 사용 후 2주까지는 자외선을 피하십시오.
# invoke 실행 시간: 6.143723726272583 초
# 96 번째 답변 :  케토프로펜을 사용하는 동안 주의해야 할 약 또는 음식은 다른 비스테로이드성 소염진통제, 아스피린 등 혈소판 응집 억제제, 글루코코르티코이드, 칼륨보전이뇨제, 안지오텐신전환효소 억제제, 안지오텐신 II 길항제, 싸이클로스포린, 메토트렉세이트, 디곡신, 페니토인, 퀴놀론계 항균제, 푸로세미드 이뇨제, 경구용 항응혈제(예: 와파린), 항고혈압제, 리튬제제, 미페프리스톤, 프로베네시드, 설핀피라존을 함께 복용하지 마십시오.
# invoke 실행 시간: 3.793835163116455 초
# 97 번째 답변 :  케노펜겔(케토프로펜) 사용 시 드물게 쇽 증상(두드러기, 호흡곤란, 얼굴부기 등 과민성유사증상), 천식발작, 피부발진, 가려움, 수포, 짓무름, 자극감 및 종창 등의 이상반응이 나타날 수 있습니다. 만약 피부발진이 전신으로 확대될 경우 사용을 즉각 중지하고 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 2.3680882453918457 초
# 98 번째 답변 :  케노펜겔(케토프로펜)은 30도 미만의 실온에서 보관해야 합니다. 직사광선을 피하고 습기가 없는 곳에 보관하는 것이 좋습니다. 냉장 보관은 피해야 합니다.
# invoke 실행 시간: 2.5075244903564453 초
# 99 번째 답변 :  이 약은 퇴행성관절염(골관절염), 어깨관절주위염, 건·건초염, 건주위염, 상완골상과염(테니스 엘보우 등), 근육통, 외상후의 종창·동통의 진통·소염에 사용합니다.
# invoke 실행 시간: 1.0218751430511475 초
# 100 번째 답변 :  약면의 박리지를 떼어낸 후 환부(질환부위)에 부착합니다.
# invoke 실행 시간: 4.8933398723602295 초
# 101 번째 답변 :  케토톱플라스타(케토프로펜)을 사용하기 전에 알아야 할 내용은 다음과 같습니다: 이 약에 과민증, 아스피린 천식 또는 경험자, 티아프로펜산, 페노피브레이트, 베자피브레이트, 시프로피브레이트, 옥시벤존에 과민증 경험자, 임신기간 6개월 이상인 임부, 15세 미만의 소아, 눈 및 점막, 무좀, 백선 등에는 이 약을 사용하지 마십시오. 이 약을 사용하기 전에 기관지 천식 환자, 임부 또는 수유부는 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 5.370164394378662 초
# 102 번째 답변 :  이 약에 과민증, 아스피린 천식 또는 경험자, 티아프로펜산, 페노피브레이트, 베자피브레이트, 시프로피브레이트, 옥시벤존에 과민증 경험자, 임신기간 6개월 이상인 임부, 15세 미만의 소아, 눈 및 점막, 무좀, 백선 등에는 이 약을 사용하지 마십시오. 이 약을 사용하기 전에 기관지 천식 환자, 임부 또는 수유부는 의사 또는 약사와 상의하십시오. 1주일 정도 사용하여도 증상의 개선이 없을 경우 사용을 즉각 중지하고 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 5.070576906204224 초
# 103 번째 답변 :  케토톱플라스타(케토프로펜)을 사용하는 동안 주의해야 할 약 또는 음식은 다른 해열진통제, 감기약, 진통제, 멀미약, 프로베네시드, 설핀피라존, 디곡신, 페니토인, 바크로펜, 이뇨제, 항고혈압제, ACE 저해제(억제제), 푸로세미드, 아스피린, 리튬, 메토트렉세이트, 경구용 항응혈제(와파린 등)와 함께 복용하지 마십시오.
# invoke 실행 시간: 5.193612813949585 초
# 104 번째 답변 :  케토톱플라스타(케토프로펜)의 이상반응으로는 이 약에 과민증, 아스피린 천식 또는 경험자, 티아프로펜산, 페노피브레이트, 베자피브레이트, 시프로피브레이트, 옥시벤존에 과민증 경험자 등이 있습니다. 또한, 임신기간 6개월 이상인 임부, 15세 미만의 소아, 눈 및 점막, 무좀, 백선 등에는 이 약을 사용하지 말아야 합니다. 이 약을 사용 중이거나 사용 후 2주까지는 날씨에 관계없이 옥외활동을 피하고 이 약의 도포부위를 가려 자외선에 노출되지 않도록 해야 합니다.
# invoke 실행 시간: 2.7178151607513428 초
# 105 번째 답변 :  케토톱플라스타(케토프로펜)은 30도 미만의 실온에서 보관해야 합니다. 직사광선을 피하고 습기가 없는 곳에 보관하는 것이 좋습니다.어린이의 손이 닿지 않는 곳에 보관해야 합니다.
# invoke 실행 시간: 4.214173316955566 초
# 106 번째 답변 :  케펜텍플라스타(케토프로펜)의 효능은 퇴행성관절염(골관절염), 어깨관절주위염, 건(힘줄)ㆍ건초염(힘줄윤활막염), 건(힘줄)주위염, 상완골(위팔뼈)상과염(테니스 엘보우 등), 근육통, 외상(상처)후의 종창(부기)ㆍ동통(통증)의 진통ㆍ소염(항염)에 사용합니다.
# invoke 실행 시간: 1.142364740371704 초
# 107 번째 답변 :  약면의 박리지를 떼어낸 후 환부에 1일 2회 부착합니다.
# invoke 실행 시간: 3.6408538818359375 초
# 108 번째 답변 :  케펜텍플라스타(케토프로펜)을 사용하기 전에 반드시 알아야 할 내용은 다음과 같습니다: 기관지천식, 임부, 수유부는 의사 또는 약사와 상의해야 합니다. 광과민증이 나타날 수 있으므로 사용 중이거나 사용 후 2주 동안은 자외선을 피해야 합니다. 눈, 점막, 무좀, 백선에는 사용하지 말아야 합니다.
# invoke 실행 시간: 5.6057984828948975 초
# 109 번째 답변 :  케펜텍플라스타(케토프로펜)의 사용상 주의사항은 다음과 같습니다: 이 약에 과민증, 광과민증, 아스피린 천식 환자 또는 경험자, 티아프로펜산ㆍ페노피브레이트ㆍ베자피브레이트ㆍ시프로피브레이트ㆍ옥시벤존에 과민증, 임신기간 6개월 이상인 임부, 15세 미만의 소아는 이 약을 사용하지 마십시오. 이 약을 사용하기 전에 기관지천식, 임부, 수유부는 의사 또는 약사와 상의하십시오. 광과민증이 나타날 수 있으므로, 이 약을 사용 중이거나 사용 후 2주까지는 자외선을 피하십시오.
# invoke 실행 시간: 4.64688515663147 초
# 110 번째 답변 :  COX-2 저해제를 포함하여 다른 비스테로이드성 소염진통제, 아스피린 등 혈소판 응집 억제제, 글루코코르티코이드, 칼륨보전이뇨제, 안지오텐신전환효소 억제제, 안지오텐신 II 길항제, 싸이클로스포린, 메토트렉세이트, 디곡신, 페니토인, 퀴놀론계 항균제, 푸로세미드 이뇨제, 경구용 항응혈제(예: 와파린), 항고혈압제, 리튬제제, 미페프리스톤, 프로베네시드, 설핀피라존을 함께 복용하지 마십시오.
# invoke 실행 시간: 3.8712079524993896 초
# 111 번째 답변 :  케펜텍플라스타(케토프로펜)의 이상반응으로는 드물게 쇽 증상(두드러기, 호흡곤란, 얼굴부기 등 과민성유사증상)이 나타날 수 있으며, 천식발작(건성수포음, 천명, 호흡곤란) 등이 발생할 수 있습니다. 또한, 피부염, 광과민증, 피부발진 등의 증상이 나타날 경우 의사나 약사와 상의해야 합니다.
# invoke 실행 시간: 2.6159472465515137 초
# 112 번째 답변 :  케펜텍플라스타(케토프로펜)은 직사광선을 피하고 밀봉하여 보관해야 합니다. 30도 미만의 실온에서 보관하며, 어린이 손이 닿지 않는 곳에 보관하는 것이 좋습니다.습기와 물기를 피해 보관하는 것이 중요합니다.
# invoke 실행 시간: 1.7478623390197754 초
# 113 번째 답변 :  이 약은 개방각 녹내장 환자 또는 베타차단제에 불충분하게 반응하는 고안압 환자의 증가된 안압 감소에 사용합니다.
# invoke 실행 시간: 3.7085468769073486 초
# 114 번째 답변 :  성인은 1회 1방울씩, 1일 2회 질환이 있는 결막낭에 점안합니다. 다른 점안제를 사용하는 경우, 각 점안제를 최소 10분 이상 간격을 두고 사용합니다. 약 2분간 비루관을 막거나 눈을 감고 있으면 이 약의 전신 흡수가 줄어들어 투여부위에서의 국소적 효과를 높일 수 있습니다. 사용 전 환자는 손을 씻고 안약의 끝이 눈에 직접 닿지 않도록 주의합니다.
# invoke 실행 시간: 0.8554270267486572 초
# 115 번째 답변 :  코솝점안액에 대한 정보를 찾을 수 없습니다.
# invoke 실행 시간: 1.0455145835876465 초
# 116 번째 답변 :  코솝점안액에 대한 정보를 찾을 수 없습니다.
# invoke 실행 시간: 1.50462007522583 초
# 117 번째 답변 :  코솝점안액을 사용하는 동안 주의해야 할 약 또는 음식에 대한 정보를 찾을 수 없습니다.
# invoke 실행 시간: 2.1460957527160645 초
# 118 번째 답변 :  코솝점안액의 이상반응으로는 눈의 따가움, 가려움, 눈물, 눈의 붉음, 눈물이 나는 것, 눈물의 증가, 눈물의 분비, 눈물의 분비가 늘어나는 것 등이 나타날 수 있습니다.
# invoke 실행 시간: 1.1091773509979248 초
# 119 번째 답변 :  저는 코솝점안액에 대한 정보를 가지고 있지 않습니다.
# invoke 실행 시간: 2.6088993549346924 초
# 120 번째 답변 :  코앤쿨나잘스프레이는 코감기(급성비염), 알레르기성 비염 또는 부비동염에 의한 코막힘, 콧물, 재채기, 머리무거움의 완화에 사용됩니다.
# invoke 실행 시간: 2.416823387145996 초
# 121 번째 답변 :  만 12세 이상 및 성인은 1회 1번씩 1일 1~3회 비강에 분무합니다. 연령 및 증상에 따라 적절히 증감하되 1일 3회를 넘지 않도록 하며, 매회 최소 8시간 이상의 간격을 두고 적용합니다.
# invoke 실행 시간: 1.062556266784668 초
# 122 번째 답변 :  코앤쿨나잘스프레이에 대한 정보를 찾을 수 없습니다.
# invoke 실행 시간: 4.924365282058716 초
# 123 번째 답변 :  코앤쿨나잘스프레이의 사용상 주의사항은 다음과 같습니다: 이 약을 사용하기 전에 기관지천식 또는 그 경험자, 심기능부전 환자 및 신장, 간장애, 고혈압, 혈액 이상 또는 그 경험자, 출혈 경향이 있는 환자, 고령자, 말초동맥폐색증, 뇌혈관질환, 고지혈증, 당뇨병, 흡연자, 고초열, 코폴립, 만성 폐쇄성 폐질환, 임신 초기 및 중기의 임부, 체액저류, 심부전 환자는 의사 또는 약사와 상의해야 합니다. 이 약 복용 후 어지러움 및 시각장애가 나타날 수 있으므로 운전 및 기계조작 시 주의해야 합니다.
# invoke 실행 시간: 1.2588870525360107 초
# 124 번째 답변 :  코앤쿨나잘스프레이에 대한 정보가 없어서 정확한 답변을 제공할 수 없습니다.
# invoke 실행 시간: 1.3366692066192627 초
# 125 번째 답변 :  코앤쿨나잘스프레이에 대한 이상반응에 대한 정보를 찾지 못했습니다.
# invoke 실행 시간: 1.735440969467163 초
# 126 번째 답변 :  코앤쿨나잘스프레이는 실온에서 보관하십시오.습기와 빛을 피해 어린이의 손이 닿지 않는 곳에 보관하십시오.
# invoke 실행 시간: 1.8894264698028564 초
# 127 번째 답변 :  이 약은 안검염, 맥립종, 누낭염, 결막염, 검판선염, 각막염, 각막궤양, 안과 수술시의 무균화요법에 사용합니다.
# invoke 실행 시간: 1.370171308517456 초
# 128 번째 답변 :  1회 1방울씩, 1일 3회 점안합니다.
# invoke 실행 시간: 0.7725706100463867 초
# 129 번째 답변 :  저는 그 정보를 가지고 있지 않습니다.
# invoke 실행 시간: 1.644820213317871 초
# 130 번째 답변 :  죄송합니다, 그 정보에는 "크라비트점안액(레보플록사신 수화물)"에 대한 내용이 포함되어 있지 않습니다.
# invoke 실행 시간: 2.4211266040802 초
# 131 번째 답변 :  경구용 항생물질(아목시실린, 세푸록심, 독시사이클린, 에리스로마이신, 티암페니콜), 알코올, 중추신경억제제, 클로르페니라민과 함께 사용 시 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 75.96628904342651 초
# 132 번째 답변 :  쇽(호흡곤란, 혈압저하 등), 두드러기, 가려움증, 발진, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적, 발적,
# invoke 실행 시간: 1.2338252067565918 초
# 133 번째 답변 :  빛을 피해 실온에서 보관하십시오. 첫 개봉 후 28일을 초과하는 경우 사용하지 마십시오.
# invoke 실행 시간: 1.2539970874786377 초
# 134 번째 답변 :  이 약은 당뇨병에 의한 망막변성 및 눈의 혈관장애 개선과 야맹증에 사용됩니다.
# invoke 실행 시간: 1.1843197345733643 초
# 135 번째 답변 :  1회 1캡슐(170 mg)씩, 1일 2~3회 식후에 복용합니다.
# invoke 실행 시간: 1.1258339881896973 초
# 136 번째 답변 :  죄송합니다, 그 정보에 대한 내용은 제가 가지고 있지 않습니다.
# invoke 실행 시간: 0.9818408489227295 초
# 137 번째 답변 :  죄송합니다, 그 정보에 대한 내용은 제공되지 않았습니다.
# invoke 실행 시간: 1.6979243755340576 초
# 138 번째 답변 :  죄송합니다, 타겐에프연질캡슐(빌베리건조엑스)에 대한 정보가 제공된 문맥에 포함되어 있지 않습니다.
# invoke 실행 시간: 72.40748810768127 초
# 139 번째 답변 :  쇽 증상(호흡곤란, 혈압저하 등), 재생불량성빈혈, 용혈성빈혈, 혈액장애, 소화불량, 복부팽만, 속쓰림, 복통, 설사나 변비, 구토, 위장궤양, 천공, 혈변, 위염, 췌장염, 피부발진, 가려움, 천식발작, 두통, 어지러움, 우울증 등의 이상반응이 나타날 수 있습니다.양쪽 눈이나 코 주위에 발진, 가려움, 부어오름, 호흡곤란, 혈압저하, 천식발작, 두드러기, 발진, 가려움, 발적, 피부건조, 피부염, 피부발진, 피부박리, 피부색소침착, 피부염증, 피부통증, 피부흉터, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염, 피부피부염,
# invoke 실행 시간: 0.750126838684082 초
# 140 번째 답변 :  실온에서 보관하십시오.
# invoke 실행 시간: 1.864072322845459 초
# 141 번째 답변 :  가네카정은 코감기, 알레르기 및 혈관운동성 코염에 의한 재채기, 콧물, 코막힘, 눈물의 완화에 사용됩니다.
# invoke 실행 시간: 1.5838727951049805 초
# 142 번째 답변 :  성인은 1회 1정, 소아(12~14세)는 1회 1/2정을 1일 3회 매 식후에 복용합니다.
# invoke 실행 시간: 0.9604849815368652 초
# 143 번째 답변 :  죄송합니다, 그 정보에 대한 내용은 제공되지 않았습니다.
# invoke 실행 시간: 0.952444314956665 초
# 144 번째 답변 :  죄송합니다, 가네카정에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 3.6670994758605957 초
# 145 번째 답변 :  혈압강하제, 알코올, 중추신경억제제(수면제, 진정제, 안정제), MAO 억제제, 교감신경흥분제, 삼환계 항우울약, 구아네티딘, 브레틸리움, 베타나이드, 데브리소퀸, 메칠도파, 교감신경성약(충혈제거제, 식욕억제제, 암페타민류의 신경자극제), α 및 β 아드레날린 저해제(억제제)와 함께 복용하지 마십시오.
# invoke 실행 시간: 5.4570231437683105 초
# 146 번째 답변 :  죽상(예: 호흡곤란, 전신조홍, 혈관부종, 두드러기), 천식발작, 과민증(홍반, 간지러움, 코막힘, 심장-호흡기 장애, 때때로 발진, 부종, 두드러기, 비염양 증상, 결막염) 등의 이상반응이 나타날 수 있습니다. 드물게 독성표피괴사용해(리엘증후군), 피부점막안증후군(스티븐스-존슨증후군)와 같은 심각한 반응도 발생할 수 있습니다.복용 후 식욕부진, 가슴쓰림, 위통, 구역, 구토 등의 증상이 나타날 수 있습니다.
# invoke 실행 시간: 0.7109246253967285 초
# 147 번째 답변 :  저는 그 정보를 가지고 있지 않습니다.
# invoke 실행 시간: 1.2962548732757568 초
# 148 번째 답변 :  이 약은 만성 간질환, 간경변, 독성 간질환의 보조치료에 사용됩니다.
# invoke 실행 시간: 1.078719139099121 초
# 149 번째 답변 :  성인은 1회 1캡슐 1일 3회 복용합니다.
# invoke 실행 시간: 1.2123446464538574 초
# 150 번째 답변 :  죄송합니다, 그 정보에 대한 내용은 제공되지 않았습니다.
# invoke 실행 시간: 1.5704734325408936 초
# 151 번째 답변 :  죄송합니다, 가네탑골드연질캡슐에 대한 정보를 찾을 수 없어 사용상 주의사항을 알려드릴 수 없습니다.
# invoke 실행 시간: 1.2673723697662354 초
# 152 번째 답변 :  죄송합니다, 그 정보는 제공드릴 수 없습니다.
# invoke 실행 시간: 5.149660348892212 초
# 153 번째 답변 :  쇽 증상(예: 호흡곤란, 전신조홍, 혈관부종, 두드러기), 천식발작, 과민증(홍반, 간지러움, 코막힘, 심장-호흡기 장애, 때때로 발진, 부종, 두드러기, 비염양 증상, 결막염) 등의 이상반응이 나타날 수 있습니다. 드물게는 독성표피괴사용해(리엘증후군), 피부점막안증후군(스티븐스-존슨증후군), 박탈성피부염, 재생불량성빈혈, 빈혈, 백혈구감소, 혈소판감소, 혈소판기능 저하(출혈시간의 지연) 등의 이상반응이 있을 수 있습니다. 부작용이 나타날 경우 즉시 의사나 약사와 상의해야 합니다.
# invoke 실행 시간: 1.50626540184021 초
# 154 번째 답변 :  습기와 빛을 피해 실온에서 보관하십시오. 어린이의 손이 닿지 않는 곳에 보관하십시오.
# invoke 실행 시간: 1.602755069732666 초
# 155 번째 답변 :  가두벌크림은 벌레 물린데, 피부가려움, 습진, 두드러기, 피부염, 땀띠, 동창에 사용됩니다.
# invoke 실행 시간: 1.3759937286376953 초
# 156 번째 답변 :  1일 수회 환부에 적당량을 바릅니다.
# invoke 실행 시간: 2.276186466217041 초
# 157 번째 답변 :  가두벌크림을 사용하기 전에 반드시 알아야 할 내용은 다음과 같습니다: 혈전증과 같은 심각한 심혈관계 위험이 증가할 수 있어 경구피임제를 복용하는 여성은 흡연을 삼갑니다. 35세 이상 흡연자는 이 약을 복용하지 마십시오.
# invoke 실행 시간: 3.3705942630767822 초
# 158 번째 답변 :  이 약에 과민증 환자, 수유부, 소아는 이 약을 사용하지 마십시오. 이 약을 사용하기 전에 에이즈 또는 골수이식 등 면역결핍 환자, 임부 또는 임신하고 있을 가능성이 있는 여성, 프로필렌글리콜에 과민증 환자 또는 경험자는 의사 또는 약사와 상의하십시오. 치료는 가능한 한 초기에 시작하고, 재발성인 경우에는 전구증상 또는 병소가 처음 나타날 때 시작하십시오.
# invoke 실행 시간: 1.1051275730133057 초
# 159 번째 답변 :  죄송합니다, 가두벌크림에 대한 정보가 없어서 답변을 제공할 수 없습니다.
# invoke 실행 시간: 80.28292226791382 초
# 160 번째 답변 :  죽상(예: 피부발진, 가려움, 두드러기, 발진, 피부염, 피부건조, 피부통증, 피부염, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증, 피부통증,
# invoke 실행 시간: 0.7362658977508545 초
# 161 번째 답변 :  저는 그 정보를 알 수 없습니다.
# invoke 실행 시간: 3.2592546939849854 초
# 162 번째 답변 :  겟투겔(케토프로펜)은 퇴행성관절염(골관절염), 어깨관절주위염, 건ㆍ건초염, 건주위염, 상완골상과염(테니스 엘보우 등), 근육통, 외상후의 종창ㆍ동통의 진통ㆍ소염에 사용됩니다.
# invoke 실행 시간: 1.5282022953033447 초
# 163 번째 답변 :  증상에 따라 적당량을 1일 1~4회 환부에 바르고 잘 스며들도록 가볍게 문지릅니다.
# invoke 실행 시간: 1.103879451751709 초
# 164 번째 답변 :  죄송합니다, 그 정보에 대한 내용은 제공되지 않았습니다.
# invoke 실행 시간: 4.7508704662323 초
# 165 번째 답변 :  겟투겔(케토프로펜)의 사용상 주의사항은 다음과 같습니다: 이 약에 과민증, 광과민증, 아스피린 또는 다른 소염진통제에 의한 천식 경험 환자, 티아프로펜산ㆍ페노피브레이트ㆍ베자피브레이트ㆍ시프로피브레이트ㆍ옥시벤존에 과민증, 임신기간 6개월 이상인 임부, 15세 미만의 소아는 이 약을 사용하지 마십시오. 이 약을 사용하기 전에 기관지천식, 임부, 수유부는 의사 또는 약사와 상의하십시오. 광과민증이 나타날 수 있으므로, 이 약을 사용 중이거나 사용 후 2주까지는 자외선을 피하십시오.
# invoke 실행 시간: 1.6775717735290527 초
# 166 번째 답변 :  케토프로펜을 사용하는 동안 주의해야 할 약 또는 음식에 대한 정보를 찾을 수 없습니다.
# invoke 실행 시간: 4.589291334152222 초
# 167 번째 답변 :  드물게 쇽 증상(두드러기, 호흡곤란, 얼굴부기 등 과민성유사증상), 천식발작(건성수포음, 천명, 호흡곤란), 때때로 발적, 발진, 가려움, 수포, 짓무름, 자극감 및 종창 등의 접촉피부염이 나타날 수 있습니다. 또한 피부건조 및 색소침착, 직사일광에 의한 광과민증이 발생할 수 있습니다. 만약 피부발진이 전신으로 확대될 경우 사용을 즉각 중지하고 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 0.9435925483703613 초
# 168 번째 답변 :  저는 그 정보를 찾을 수 없습니다.
# invoke 실행 시간: 1.9759812355041504 초
# 169 번째 답변 :  이 약은 단순포진(물집) 바이러스 감염증(초기 및 재발성 생식기 포진(물집)과 구순포진(물집) 포함)에 사용합니다.
# invoke 실행 시간: 2.1534481048583984 초
# 170 번째 답변 :  약 4시간 간격으로 1일 5회 환부(질환 부위)에 발라야 합니다. 치료는 5일간 계속해야 하며, 5일간 사용 후에도 치료되지 않을 경우에는 5일간 더 사용할 수 있습니다.
# invoke 실행 시간: 3.587062120437622 초
# 171 번째 답변 :  이 약을 사용하기 전에 에이즈 또는 골수이식 등 면역결핍 환자, 임부 또는 임신하고 있을 가능성이 있는 여성, 프로필렌글리콜에 과민증 환자 또는 경험자는 의사 또는 약사와 상의하십시오.치료는 가능한 한 초기에 시작하고, 재발성인 경우에는 전구증상 또는 병소가 처음 나타날 때 시작하십시오.정해진 용법과 용량을 잘 지키십시오.
# invoke 실행 시간: 4.722776174545288 초
# 172 번째 답변 :  이 약에 과민증 환자, 수유부, 소아는 이 약을 사용하지 마십시오. 이 약을 사용하기 전에 에이즈 또는 골수이식 등 면역결핍 환자, 임부 또는 임신하고 있을 가능성이 있는 여성, 프로필렌글리콜에 과민증 환자 또는 경험자는 의사 또는 약사와 상의하십시오. 치료는 가능한 한 초기에 시작하고, 재발성인 경우에는 전구증상 또는 병소가 처음 나타날 때 시작하십시오.
# invoke 실행 시간: 1.3665759563446045 초
# 173 번째 답변 :  프로베네시드를 투여한 환자는 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 3.3226191997528076 초
# 174 번째 답변 :  압통 등의 불쾌감, 일시적인 작열감, 자통을 포함하는 가벼운 동통 및 접촉피부염, 홍반성 발진, 습진, 알레르기반응 및 때때로 도포부위의 자극감, 가려움, 외음염, 안면 부종, 피부 탈색, 두드러기, 발진, 소수포성 발진, 피부 벗겨짐 등이 나타날 수 있습니다.
# invoke 실행 시간: 1.413726568222046 초
# 175 번째 답변 :  이 약은 실온에서 보관해야 합니다.
# invoke 실행 시간: 1.5009894371032715 초
# 176 번째 답변 :  이 약은 습진, 피부염, 땀띠, 옻 등에 의한 피부염, 가려움, 벌레물림, 두드러기, 동창에 사용합니다.
# invoke 실행 시간: 1.009199619293213 초
# 177 번째 답변 :  1일 수회 환부에 적당량을 적용합니다.
# invoke 실행 시간: 1.3358163833618164 초
# 178 번째 답변 :  죄송합니다, 그 정보에는 계안겔(수출용)에 대한 내용이 포함되어 있지 않습니다.
# invoke 실행 시간: 3.648054599761963 초
# 179 번째 답변 :  30개월 이하의 유아, 눈 또는 눈 주위, 점막, 습진, 상처부위, 민감한 피부에는 이 약을 사용하지 마십시오. 이 약을 사용하기 전에 약 또는 화장품에 알레르기 증상(발진, 발적, 가려움, 옻 등에 의한 피부염 등) 경험자, 알레르기 체질, 습윤이나 짓무름, 염증이 심한 환자, 소아는 의사 또는 약사와 상의하십시오. 정해진 용법과 용량을 잘 지키십시오.
# invoke 실행 시간: 2.6909239292144775 초
# 180 번째 답변 :  죽상제, 항응고제, 혈소판응집억제제, 항고혈압제, ACE 억제제, 리튬제, 메토트렉세이트, 페니토인, 바크로펜, 이뇨제, 감기약, 해열진통제, 진정제, 멀미약, 프로베네시드, 설핀피라존, 디곡신과 함께 복용하지 마십시오.
# invoke 실행 시간: 3.216017484664917 초
# 181 번째 답변 :  발진, 발적, 가려움, 부종, 땀띠염증, 건조감, 자극감, 열감, 따끔따끔한 감각 등이 나타나는 경우 사용을 즉각 중지하고 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 0.8594377040863037 초
# 182 번째 답변 :  죄송합니다, 제가 그에 대한 정보를 찾지 못했습니다.
# invoke 실행 시간: 1.7643301486968994 초
# 183 번째 답변 :  이 약은 단순포진(물집) 바이러스 감염증(초기 및 재발성 생식기 포진(물집)과 구순포진(물집) 포함)에 사용합니다.
# invoke 실행 시간: 4.578249216079712 초
# 184 번째 답변 :  약 4시간 간격으로 1일 5회 환부(질환 부위)에 발라야 합니다. 치료는 5일간 계속해야 하며, 5일간 사용 후에도 치료되지 않을 경우에는 5일간 더 사용할 수 있습니다.
# invoke 실행 시간: 3.9086618423461914 초
# 185 번째 답변 :  이 약에 과민증 환자, 수유부, 소아는 이 약을 사용하지 마십시오. 이 약을 사용하기 전에 에이즈 또는 골수이식 등 면역결핍 환자, 임부 또는 임신하고 있을 가능성이 있는 여성, 프로필렌글리콜에 과민증 환자 또는 경험자는 의사 또는 약사와 상의하십시오. 치료는 가능한 한 초기에 시작하고, 재발성인 경우에는 전구증상 또는 병소가 처음 나타날 때 시작하십시오.
# invoke 실행 시간: 3.505319595336914 초
# 186 번째 답변 :  이 약에 과민증 환자, 수유부, 소아는 이 약을 사용하지 마십시오. 이 약을 사용하기 전에 에이즈 또는 골수이식 등 면역결핍 환자, 임부 또는 임신하고 있을 가능성이 있는 여성, 프로필렌글리콜에 과민증 환자 또는 경험자는 의사 또는 약사와 상의하십시오. 치료는 가능한 한 초기에 시작하고, 재발성인 경우에는 전구증상 또는 병소가 처음 나타날 때 시작하십시오.
# invoke 실행 시간: 1.2650997638702393 초
# 187 번째 답변 :  프로베네시드를 투여한 환자는 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 3.3285367488861084 초
# 188 번째 답변 :  압통 등의 불쾌감, 일시적인 작열감, 자통을 포함하는 가벼운 동통 및 접촉피부염, 홍반성 발진, 습진, 알레르기반응 및 때때로 도포부위의 자극감, 가려움, 외음염, 안면 부종, 피부 탈색, 두드러기, 발진, 소수포성 발진, 피부 벗겨짐 등이 나타날 수 있습니다.
# invoke 실행 시간: 1.0393257141113281 초
# 189 번째 답변 :  실온에서 보관하셔야 합니다.
# invoke 실행 시간: 1.8478724956512451 초
# 190 번째 답변 :  이 약은 삠, 타박상, 근육통, 골절통, 관절통, 요통, 어깨결림, 동창(언 상처)의 진통·소염(항염)에 사용합니다.
# invoke 실행 시간: 1.365936040878296 초
# 191 번째 답변 :  1일 1~2회, 1회 1매씩 환부(질환 부위)에 붙입니다.
# invoke 실행 시간: 3.895193576812744 초
# 192 번째 답변 :  광동동의한방고카타플라스마를 사용하기 전에 알아야 할 내용은 30개월 이하의 유아, 습진, 옻 등에 의한 피부염, 상처부위에는 사용하지 말아야 하며, 알레르기 체질이거나 알레르기 증상이 있는 환자, 습윤이나 미란이 심한 환자, 소아의 경우 의사나 약사와 상의해야 합니다. 정해진 용법과 용량을 잘 지키고 어린이에게 투여할 경우 보호자의 지도 감독하고, 증상 개선이 없을 시 의사나 약사와 상의해야 합니다.
# invoke 실행 시간: 0.9829587936401367 초
# 193 번째 답변 :  죄송합니다, 그 정보는 제가 가지고 있지 않습니다.
# invoke 실행 시간: 2.0386648178100586 초
# 194 번째 답변 :  죄송합니다, 제가 찾은 정보에는 "광동동의한방고카타플라스마을"에 대한 정보가 없습니다. 해당 제품에 대한 정보가 없어서 도움을 드리지 못하는 점 양해 부탁드립니다.
# invoke 실행 시간: 4.13205099105835 초
# 195 번째 답변 :  죽상증상(호흡곤란, 전신조홍, 혈관부종, 두드러기), 천식발작, 과민증(홍반, 간지러움, 코막힘, 심장-호흡기 장애, 때때로 발진, 부종, 두드러기, 비염양 증상, 결막염) 등의 이상반응이 나타날 수 있습니다. 드물게 독성표피괴사용해(리엘증후군), 피부점막안증후군(스티븐스-존슨증후군)와 같은 심각한 반응도 발생할 수 있습니다. 이러한 증상이 나타나면 즉시 의사나 약사와 상의해야 합니다.
# invoke 실행 시간: 1.842064380645752 초
# 196 번째 답변 :  습기와 빛을 피해 실온에서 보관하십시오. 어린이의 손이 닿지 않는 곳에 보관하십시오.
# invoke 실행 시간: 1.516474962234497 초
# 197 번째 답변 :  이 약은 치질로 인한 불쾌감, 작열감, 가려움의 일시적 완화에 사용합니다.
# invoke 실행 시간: 1.1659157276153564 초
# 198 번째 답변 :  성인은 1일 3회까지 환부에 직접 바르면 됩니다.
# invoke 실행 시간: 3.3055479526519775 초
# 199 번째 답변 :  프라목신염산염을 사용하기 전에 반드시 알아야 할 내용은 과민증 환자는 이 약을 사용하지 말아야 하며, 12세 이하의 소아, 임부 또는 임신 가능성이 있는 여성은 의사나 약사와 상의해야 합니다. 또한 정해진 용법과 용량을 잘 지켜야 하며 어린이에게 투여할 경우 보호자의 지도 감독하에 투여해야 합니다.
# invoke 실행 시간: 2.02250075340271 초
# 200 번째 답변 :  이 약에 과민증 환자는 이 약을 사용하지 마십시오. 이 약을 사용하기 전에 12세 이하의 소아, 임부 또는 임신하고 있을 가능성이 있는 여성은 의사 또는 약사와 상의하십시오. 정해진 용법과 용량을 잘 지키십시오.
# invoke 실행 시간: 1.868114948272705 초
# 201 번째 답변 :  죄송합니다, 광동프라목신크림(프라목신염산염)에 대한 정보가 없어서 해당 질문에 대한 답변을 제공할 수 없습니다.
# invoke 실행 시간: 1.5645525455474854 초
# 202 번째 답변 :  이 약은 발적, 부종, 자극감, 출혈이 나타날 수 있으며, 이러한 경우 사용을 즉각 중지하고 의사 또는 약사와 상의해아 합니다.
# invoke 실행 시간: 1.3955473899841309 초
# 203 번째 답변 :  습기와 빛을 피해 실온에서 보관하십시오. 어린이의 손이 닿지 않는 곳에 보관하십시오. 화기 근처에 두지 마십시오.
# invoke 실행 시간: 1.840437412261963 초
# 204 번째 답변 :  이 약은 알레르기성 비염(재채기, 코막힘, 가려움, 눈의 작열감), 만성 특발성(원인 불명의) 두드러기에 사용합니다.
# invoke 실행 시간: 2.501603364944458 초
# 205 번째 답변 :  성인 및 12세 이상의 소아는 1일 1회 1정(10 mg) 복용합니다. 6~12세 미만의 소아는 체중이 30 kg이상인 경우 1일 1회 1정(10 mg), 30 kg이하인 경우 1일 1회 1/2정(5 mg) 복용합니다. 연령, 증상에 따라 적절히 증감합니다.
# invoke 실행 시간: 2.6416609287261963 초
# 206 번째 답변 :  구주로라타딘정10밀리그람(수출명:로히스타정)을 사용하기 전에 알아야 할 내용은 다음과 같습니다: 이 약에 대한 알레르기 체험이 있는 경우, 장애가 있는 환자, 임부 또는 수유부, 12세 미만의 어린이, 심한 간장애 또는 심한 신장장애가 있는 환자는 의사와 상의해야 합니다.
# invoke 실행 시간: 3.036564826965332 초
# 207 번째 답변 :  이 약에 과민증 환자, 만 6세 미만의 소아, 임부 및 수유부, 갈락토오스 불내성, Lapp 유당분해효소 결핍증 또는 포도당-갈락토오스 흡수장애 등의 유전적인 문제가 있는 환자는 이 약을 복용하지 마십시오. 이 약을 복용하기 전에 간장애, 신부전 환자는 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 1.0190162658691406 초
# 208 번째 답변 :  죄송합니다, 그 정보에 대한 내용은 제공되지 않았습니다.
# invoke 실행 시간: 5.250601530075073 초
# 209 번째 답변 :  쇽 증상(예: 호흡곤란, 전신조홍, 혈관부종, 두드러기), 천식발작, 과민증(홍반, 간지러움, 코막힘, 심장-호흡기 장애, 때때로 발진, 부종, 두드러기, 비염양 증상, 결막염) 등의 이상반응이 나타날 수 있습니다. 드물게는 독성표피괴사용해(리엘증후군), 피부점막안증후군(스티븐스-존슨증후군)와 같은 심각한 반응도 발생할 수 있습니다.식욕부진, 가슴쓰림, 위통, 구역, 구토 등의 증상도 나타날 수 있습니다.
# invoke 실행 시간: 2.250000238418579 초
# 210 번째 답변 :  구주로라타딘정10밀리그람(수출명:로히스타정)은 25도 이하의 실온에서 보관해야 합니다. 직사광선을 피하고 습기가 없는 곳에 보관하는 것이 좋습니다.어린이의 손이 닿지 않는 곳에 보관해야 합니다.
# invoke 실행 시간: 1.8797595500946045 초
# 211 번째 답변 :  국제아시클로버크림의 효능은 단순포진(물집) 바이러스 감염증(초기 및 재발성 생식기 포진(물집)과 구순포진(물집) 포함)에 사용합니다.
# invoke 실행 시간: 2.1139743328094482 초
# 212 번째 답변 :  국제아시클로버크림은 약 4시간 간격으로 1일 5회 환부(질환 부위)에 발라야 합니다. 치료는 5일간 계속해야 하며, 5일간 사용 후에도 치료되지 않을 경우에는 5일간 더 사용할 수 있습니다.
# invoke 실행 시간: 1.836493730545044 초
# 213 번째 답변 :  혈전증과 같은 심각한 심혈관계 위험이 증가할 수 있어 경구피임제를 복용하는 여성은 흡연을 삼갑니다. 35세 이상 흡연자는 이 약을 복용하지 마십시오.
# invoke 실행 시간: 3.8889894485473633 초
# 214 번째 답변 :  이 약에 과민증 환자, 수유부, 소아는 이 약을 사용하지 마십시오. 이 약을 사용하기 전에 에이즈 또는 골수이식 등 면역결핍 환자, 임부 또는 임신하고 있을 가능성이 있는 여성, 프로필렌글리콜에 과민증 환자 또는 경험자는 의사 또는 약사와 상의하십시오. 치료는 가능한 한 초기에 시작하고, 재발성인 경우에는 전구증상 또는 병소가 처음 나타날 때 시작하십시오.
# invoke 실행 시간: 1.1691319942474365 초
# 215 번째 답변 :  프로베네시드를 투여한 환자는 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 5.245561361312866 초
# 216 번째 답변 :  쇽 증상(예: 호흡곤란, 전신조홍, 혈관부종, 두드러기), 천식발작, 과민증(홍반, 간지러움, 코막힘, 심장-호흡기 장애, 때때로 발진, 부종, 두드러기, 비염양 증상, 결막염) 등이 나타날 수 있습니다. 드물게 독성표피괴사용해(리엘증후군), 피부점막안증후군(스티븐스-존슨증후군), 박탈성피부염, 재생불량성빈혈, 빈혈, 백혈구감소 등도 발생할 수 있습니다.식욕부진, 가슴쓰림, 위통, 구역, 구토 등의 증상도 나타날 수 있습니다.
# invoke 실행 시간: 0.7564828395843506 초
# 217 번째 답변 :  저는 그 정보를 가지고 있지 않습니다.
# invoke 실행 시간: 2.6225130558013916 초
# 218 번째 답변 :  그날엔노즈플러스연질캡슐은 감기의 여러 증상(콧물, 코막힘, 재채기, 인후통, 오한, 발열, 두통, 관절통, 근육통)의 완화에 사용됩니다.
# invoke 실행 시간: 3.1390135288238525 초
# 219 번째 답변 :  그날엔노즈플러스연질캡슐은 만 15세 이상 및 성인은 1회 2캡슐씩, 1일 3회 식후 30분에 복용합니다. 정해진 용법과 용량을 잘 지키며 물과 함께 복용하고, 매일 대략 같은 시간에 복용해야 합니다.세잔 이상 정기적 음주자가 이 약을 복용할 때는 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 1.4403440952301025 초
# 220 번째 답변 :  죄송합니다. 그날엔노즈플러스연질캡슐에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 1.3230211734771729 초
# 221 번째 답변 :  죄송합니다, 그날엔노즈플러스연질캡슐에 대한 정보를 찾을 수 없습니다.
# invoke 실행 시간: 1.5323841571807861 초
# 222 번째 답변 :  죄송합니다, 그날엔노즈플러스연질캡슐에 대한 정보가 제공되지 않았습니다.
# invoke 실행 시간: 5.28366231918335 초
# 223 번째 답변 :  쇽 증상(예: 호흡곤란, 전신조홍, 혈관부종, 두드러기), 천식발작, 과민증(홍반, 간지러움, 코막힘, 심장-호흡기 장애, 때때로 발진, 부종, 두드러기, 비염양 증상, 결막염) 등이 나타날 수 있습니다. 드물게 독성표피괴사용해(리엘증후군), 피부점막안증후군(스티븐스-존슨증후군), 박탈성피부염, 재생불량성빈혈, 빈혈, 백혈구감소, 혈소판감소, 혈소판기능 저하(출혈시간의 지연) 등도 나타날 수 있습니다.
# invoke 실행 시간: 1.6552560329437256 초
# 224 번째 답변 :  습기와 빛을 피해 실온에서 보관하십시오. 어린이의 손이 닿지 않는 곳에 보관하십시오.
# invoke 실행 시간: 1.1245136260986328 초
# 225 번째 답변 :  제공된 정보에는 "그날엔정"에 대한 내용이 없습니다.
# invoke 실행 시간: 1.2673413753509521 초
# 226 번째 답변 :  죄송합니다, 그날엔정에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 1.5156786441802979 초
# 227 번째 답변 :  죄송합니다, 그날엔정에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 1.104691743850708 초
# 228 번째 답변 :  죄송합니다, 그날엔정에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 3.6080141067504883 초
# 229 번째 답변 :  다른 해열진통제, 감기약, 진정제, 멀미약, 프로베네시드, 설핀피라존, 디곡신, 페니토인, 바크로펜, 이뇨제, 항고혈압제, ACE 저해제(억제제), 푸로세미드, 아스피린, 리튬, 메토트렉세이트, 경구용 항응혈제(와파린 등)와 함께 복용하지 마십시오.
# invoke 실행 시간: 63.704882860183716 초
# ...
# invoke 실행 시간: 5.042414665222168 초
# 593 번째 답변 :  이 약을 복용하는 동안 다른 비스테로이드성 소염진통제, 아스피린, 고용량의 메토트렉세이트를 사용하지 마십시오. 이 약을 복용하기 전에 코르티코스테로이드, 알코올, 디곡신, 페니토인, 프로베네시드, 설핀피라존, 설포닐우레아제, ACE 억제제 또는 안지오텐신Ⅱ 수용체 길항제, 이뇨제, 리튬, 쿠마린계 항응고제(와르파린 등), 바클로펜, 면역억제제(시클로스포린, 타크로리무스, 시롤리무스)와 함께 사용 시 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 3.41938853263855 초
# 594 번째 답변 :  솔루펜연질캡슐(덱시부프로펜) 복용 시 드물하게 혈액장애, 소화불량, 복부팽만, 피부반응, 시각장애, 혈압 변화, 간기능 이상, 신장 문제, 두통, 우울증 등의 이상반응이 나타날 수 있습니다. 이러한 증상이 나타나면 즉시 의사나 약사와 상의하여야 합니다.
# invoke 실행 시간: 1.409825325012207 초
# 595 번째 답변 :  습기와 빛을 피해 실온에서 보관하십시오. 어린이의 손이 닿지 않는 곳에 보관하십시오.
# invoke 실행 시간: 3.0261073112487793 초
# 596 번째 답변 :  이 약은 두통, 치통, 발치후 동통(통증), 인후통, 귀의 통증, 관절통, 신경통, 요통, 근육통, 견통(어깨결림), 타박통, 골절통, 염좌통(삔 통증), 월경통(생리통), 외상통의 진통과 오한, 발열시의 해열에 사용합니다.
# invoke 실행 시간: 1.6859238147735596 초
# 597 번째 답변 :  만 15세 이상 및 성인은 1회 1정, 1일 3회 공복을 피해 복용합니다. 복용간격은 4시간 이상이 되도록합니다.
# invoke 실행 시간: 1.1853795051574707 초
# 598 번째 답변 :  죄송합니다, 수프리정에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 3.419389247894287 초
# 599 번째 답변 :  수프리정의 사용상 주의사항은 매일 세잔 이상 정기적 음주자가 이 약을 복용할 때 의사나 약사와 상의해야 하며, 아세트아미노펜으로 일일 최대 용량(4,000 mg)을 초과하여 복용하지 말아야 합니다. 또한, 이 약을 복용 후 피부발진이나 다른 과민반응의 징후가 나타나면 즉시 복용을 중단해야 합니다.
# invoke 실행 시간: 1.3182315826416016 초
# 600 번째 답변 :  죄송합니다, 수프리정에 대한 정보가 없어서 해당 질문에 대한 답변을 제공할 수 없습니다.
# invoke 실행 시간: 3.1294522285461426 초
# 601 번째 답변 :  수프리정을 복용할 때 나타날 수 있는 이상반응은 발진, 가려움, 구역, 구토, 식욕부진, 변비, 어지러움, 부종, 쇽 증상, 피부점막안증후군, 독성표피괴사용해 등이 있습니다. 만약 이러한 증상이 나타나면 즉시 복용을 중지하고 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 1.9337027072906494 초
# 602 번째 답변 :  습기와 빛을 피해 실온에서 보관하십시오. 어린이의 손이 닿지 않는 곳에 보관하십시오.
# invoke 실행 시간: 2.1660103797912598 초
# 603 번째 답변 :  이 약은 감기의 제증상(여러증상)(인후(목구멍)통, 오한(춥고 떨리는 증상), 발열, 두통, 관절통, 근육통)의 완화에 사용합니다.
# invoke 실행 시간: 1.3513634204864502 초
# 604 번째 답변 :  죄송합니다, 순갈근탕에이액에 대한 정보는 제공할 수 없습니다.
# invoke 실행 시간: 2.847792863845825 초
# 605 번째 답변 :  순갈근탕에이액을 사용하기 전에 알아야 할 내용은 성인은 1회 1정, 1일 1회 복용하며, 충분한 물과 함께 식전에 복용해야 한다는 것입니다. 이 약은 장용정이므로 식전에 복용하는 것이 중요하며, 복용 시 주의해야 할 사항들이 있습니다.
# invoke 실행 시간: 1.117997169494629 초
# 606 번째 답변 :  죄송합니다, 그 정보는 제가 가지고 있지 않습니다.
# invoke 실행 시간: 1.2612800598144531 초
# 607 번째 답변 :  죄송합니다, 순갈근탕에이액에 대한 정보가 없어서 해당 질문에 대한 답변을 제공할 수 없습니다.
# invoke 실행 시간: 1.2445764541625977 초
# 608 번째 답변 :  순갈근탕에이액에 대한 정보가 없습니다.
# invoke 실행 시간: 0.7112996578216553 초
# 609 번째 답변 :  저는 그 정보를 가지고 있지 않습니다.
# invoke 실행 시간: 1.7190742492675781 초
# 610 번째 답변 :  순앤로션2.5%(히드로코르티손)은 습진ㆍ피부염군, 피부가려움, 벌레물린데에 사용됩니다.
# invoke 실행 시간: 1.8343422412872314 초
# 611 번째 답변 :  사용 전 잘 흔들어 섞은 후 1일 1~3회 적당량을 환부(질환 부위)에 바르고 증상에 따라 적절히 증감합니다. 이 약의 치료기간은 7일 이내로 제한합니다.
# invoke 실행 시간: 3.447211980819702 초
# 612 번째 답변 :  순앤로션2.5%(히드로코르티손)을 사용하기 전에 반드시 알아야 할 내용은 현지 염증 반응이나 알레르기 반응을 유발할 수 있으므로 사용 중 피부 상태를 지속적으로 관찰해야 합니다. 눈, 입, 점막 등에는 사용하지 말아야 하며, 사용 후에는 손을 깨끗이 씻어야 합니다. 피부 상태가 악화되거나 부작용이 나타날 경우 즉시 의사와 상의해야 합니다.
# invoke 실행 시간: 4.9309210777282715 초
# 613 번째 답변 :  순앤로션2.5%(히드로코르티손)의 사용상 주의사항은 다음과 같습니다: 이 약에 과민증 환자, 피부감염증, 고막 천공이 있는 습진성 외이도염, 궤양, 제2도 심재성 이상의 화상 및 동상, 입주위피부염, 보통여드름, 주사 환자, 비염증성 가려움 환자는 사용하지 말아야 합니다. 임부 또는 임신 가능성이 있는 여성, 수유부, 유ㆍ소아(특히 2세 미만), 고령자는 의사 또는 약사와 상의해야 합니다. 또한 안과용으로 사용하거나 밀봉붕대법을 사용하지 말아야 합니다.
# invoke 실행 시간: 1.4461379051208496 초
# 614 번째 답변 :  순앤로션2.5%(히드로코르티손)을 사용하는 동안 주의해야 할 약 또는 음식에 대한 정보를 찾을 수 없습니다.
# invoke 실행 시간: 4.717177391052246 초
# 615 번째 답변 :  순앤로션2.5%(히드로코르티손) 사용 시 전염성 농가진, 모낭염, 칸디다증, 백선, 부스럼, 피부자극, 자통, 발열, 작열감(화끈감), 발진, 발적, 홍조, 가려움, 피부건조 등의 이상반응이 나타날 수 있습니다. 또한, 농포성피부염, 알레르기성 접촉피부염, 땀띠, 한진, 상처악화, 욕창, 농포증 등의 이상반응이 발생할 수 있습니다. 만약 피부에 자극이나 통증이 나타난다면 즉시 사용을 중지하고 의사나 약사와 상의해야 합니다.
# invoke 실행 시간: 2.5355968475341797 초
# 616 번째 답변 :  순앤로션2.5%(히드로코르티손)은 30도 미만의 실온에서 보관해야 합니다. 직사광선을 피하고 어린이의 손이 닿지 않는 곳에 보관하는 것이 좋습니다. 뚜껑을 꼭 닫아서 보관하는 것이 중요합니다.
# invoke 실행 시간: 2.4481937885284424 초
# 617 번째 답변 :  쉐러콜에스연질캡슐은 감기의 여러 증상(콧물, 코막힘, 재채기, 인후통, 기침, 가래, 오한(춥고 떨리는 증상), 발열, 두통, 관절통, 근육통)의 완화에 사용됩니다.
# invoke 실행 시간: 1.2385177612304688 초
# 618 번째 답변 :  성인은 1회 2캡슐씩, 1일 3회 식후 30분에 복용합니다.
# invoke 실행 시간: 1.1328988075256348 초
# 619 번째 답변 :  쉐러콜에스연질캡슐에 대한 정보를 찾을 수 없습니다.
# invoke 실행 시간: 1.5159502029418945 초
# 620 번째 답변 :  쉐러콜에스연질캡슐에 대한 정보가 없어 쉐러콜에스연질캡슐의 사용상 주의사항에 대해 알 수 없습니다.
# invoke 실행 시간: 1.0281827449798584 초
# 621 번째 답변 :  쉐러콜에스연질캡슐에 대한 정보를 찾지 못했습니다.
# invoke 실행 시간: 1.3793118000030518 초
# 622 번째 답변 :  쉐러콜에스연질캡슐에 대한 정보가 제공되지 않았기 때문에 이에 대한 구체적인 답변을 제공할 수 없습니다.
# invoke 실행 시간: 1.4401891231536865 초
# 623 번째 답변 :  습기와 빛을 피해 실온에서 보관하십시오.어린이의 손이 닿지 않는 곳에 보관하십시오.
# invoke 실행 시간: 2.299299716949463 초
# 624 번째 답변 :  이 약은 감기의 여러 증상(기침, 가래, 인후(목구멍)통, 오한(춥고 떨리는 증상), 발열, 두통, 관절통, 근육통)의 완화에 사용합니다.
# invoke 실행 시간: 1.2281224727630615 초
# 625 번째 답변 :  성인은 1회 1회정씩, 1일 3회 식후 30분에 복용합니다.
# invoke 실행 시간: 3.9336276054382324 초
# 626 번째 답변 :  슈가린정을 사용하기 전에 반드시 알아야 할 내용은 만 3개월 미만의 영아, MAO 억제제를 복용하고 있거나 중단한 후 2주 이내의 사람은 이 약을 복용하지 말아야 하며, 수두 또는 인플루엔자에 감염되어 있거나 의심되는 영아 및 만 15세 미만의 어린이, 만 2세 미만의 영아, 그리고 다양한 질환을 가진 환자들은 의사나 약사와 상의해야 합니다.
# invoke 실행 시간: 4.938586950302124 초
# 627 번째 답변 :  슈가린정의 사용상 주의사항은 다음과 같습니다: 이 약에 과민증 환자 및 경험자, 다른 해열진통제, 감기약 복용 시 천식 경험자, 만 3개월 미만의 영아, MAO억제제(항우울제, 항정신병제, 감정조절제, 항파킨슨제 등)를 복용하고 있거나 복용을 중단한 후 2주 이내의 사람은 이 약을 복용하지 마십시오. 이 약을 복용하기 전에 수두 또는 인플루엔자에 감염되어 있거나 또는 의심되는 영아 및 만 15세 미만의 어린이, 만 3개월 이상 및 만 2세 미만의 영아, 유아, 알레르기 등을 일으키기 쉬운 체질에 대해 주의가 필요합니다.
# invoke 실행 시간: 5.471961736679077 초
# 628 번째 답변 :  아세트아미노펜을 포함하는 다른 제품, MAO 억제제(항우울제, 항정신병제, 감정조절제, 항파킨슨제 등), 진해거담제(가래약), 다른 감기약, 해열진통제, 진정제, 항히스타민제를 함유하는 내복약(비염용 경구제, 멀미약, 알레르기용약)와 함께 복용하지 마십시오. 이 약을 복용하기 전에 바르비탈계 약물, 삼환계 항우울제, 알코올, 당뇨약, 통풍약, 관절염약, 항응고제, 스테로이드제 등 다른 약품과 함께 사용 시 의사 또는 약사와 상의하십시오. 복용 중에는 음주하지 마십시오.
# invoke 실행 시간: 4.7329747676849365 초
# 629 번째 답변 :  쇽 증상(예: 호흡곤란, 전신조홍, 혈관부종, 두드러기), 천식발작, 과민증(홍반, 간지러움, 코막힘, 심장-호흡기 장애, 때때로 발진, 부종, 두드러기, 비염양 증상, 결막염) 등이 나타날 수 있습니다. 드물게 독성표피괴사용해(리엘증후군), 피부점막안증후군(스티븐스-존슨증후군) 등의 심각한 이상반응도 있을 수 있습니다.식욕부진, 가슴쓰림, 위통, 구역, 구토 등의 증상도 나타날 수 있습니다.
# invoke 실행 시간: 0.7680811882019043 초
# 630 번째 답변 :  실온에서 보관하십시오.
# invoke 실행 시간: 2.3498053550720215 초
# 631 번째 답변 :  슈가펜에스정은 감기의 여러 증상(기침, 가래, 인후(목구멍)통, 오한(춥고 떨리는 증상), 발열, 두통, 관절통, 근육통)의 완화에 사용됩니다.
# invoke 실행 시간: 1.149930477142334 초
# 632 번째 답변 :  성인은 1회 1회정씩, 1일 3회 식후 30분에 복용합니다.
# invoke 실행 시간: 1.5507588386535645 초
# 633 번째 답변 :  죄송합니다, 그 정보에는 "슈가펜에스정"에 대한 내용이 포함되어 있지 않습니다.
# invoke 실행 시간: 3.8134512901306152 초
# 634 번째 답변 :  슈가펜에스정의 사용상 주의사항은 다음과 같습니다: 이 약에 과민증 환자 및 경험자, 다른 해열진통제, 감기약 복용 시 천식 경험자, 만 3개월 미만의 영아, MAO 억제제를 복용하고 있거나 복용을 중단한 후 2주 이내의 사람은 이 약을 복용하지 말아야 합니다. 또한, 다양한 질환 및 상태를 가진 환자들은 의사나 약사와 반드시 상의해야 합니다.복용 중에는 음주하지 말아야 합니다.
# invoke 실행 시간: 5.228620529174805 초
# 635 번째 답변 :  아세트아미노펜을 포함하는 다른 제품, MAO 억제제(항우울제, 항정신병제, 감정조절제, 항파킨슨제 등), 진해거담제(가래약), 다른 감기약, 해열진통제, 진정제, 항히스타민제를 함유하는 내복약(비염용 경구제, 멀미약, 알레르기용약)와 함께 복용하지 마십시오. 이 약을 복용하기 전에 바르비탈계 약물, 삼환계 항우울제, 알코올, 당뇨약, 통풍약, 관절염약, 항응고제, 스테로이드제 등 다른 약품과 함께 사용 시 의사 또는 약사와 상의하십시오. 복용 중에는 음주하지 마십시오.
# invoke 실행 시간: 4.476438283920288 초
# 636 번째 답변 :  죽상(예: 호흡곤란, 전신조홍, 혈관부종, 두드러기), 천식발작, 과민증(홍반, 간지러움, 코막힘, 심장-호흡기 장애, 때때로 발진, 부종, 두드러기, 비염양 증상, 결막염) 등의 이상반응이 나타날 수 있습니다. 드물게 독성표피괴사용해(리엘증후군), 피부점막안증후군(스티븐스-존슨증후군) 등의 심각한 반응도 있을 수 있습니다.식욕부진, 가슴쓰림, 위통, 구역, 구토 등의 증상도 나타날 수 있습니다.
# invoke 실행 시간: 1.3844497203826904 초
# 637 번째 답변 :  습기와 빛을 피해 실온에서 보관하십시오. 어린이의 손이 닿지 않는 곳에 보관하십시오.
# invoke 실행 시간: 1.570796251296997 초
# 638 번째 답변 :  이 약은 감기의 여러 증상(기침, 가래, 인후통, 오한, 발열, 두통, 관절통, 근육통)의 완화에 사용합니다.
# invoke 실행 시간: 1.273069143295288 초
# 639 번째 답변 :  성인은 1회 1정씩, 1일 3회 식후 30분에 복용합니다.
# invoke 실행 시간: 1.5226752758026123 초
# 640 번째 답변 :  슈리머정을 사용하기 전에 반드시 알아야 할 내용은 성인은 1회 1정씩, 1일 3회 식후 30분에 복용해야 한다는 것입니다.
# invoke 실행 시간: 5.430904865264893 초
# 641 번째 답변 :  슈리머정의 사용상 주의사항은 다음과 같습니다: 이 약을 복용하기 전에 과민증 환자, 다른 해열진통제나 감기약을 복용 시 천식 경험자, 만 3개월 미만의 영아, MAO억제제를 복용하고 있거나 중단한 후 2주 이내의 사람, 갈락토오스 불내성, Lapp 유당분해효소 결핍증 등의 유전적인 문제가 있는 환자는 이 약을 복용하지 말아야 합니다. 또한, 이 약을 복용하는 동안 주의해야 할 사항으로는 다른 제품과 함께 복용하지 말아야 하며, 음주를 피해야 합니다.
# invoke 실행 시간: 4.587960958480835 초
# 642 번째 답변 :  아세트아미노펜을 포함하는 다른 제품, MAO억제제(항우울제, 항정신병제, 감정조절제, 항파킨슨제 등), 진해(기침을 그치게 함)거담제(가래약), 다른 감기약, 해열진통제, 진정제, 항히스타민제를 함유하는 내복약(비염용 경구제, 멀미약, 알레르기용약)과 함께 복용하지 마십시오. 바르비탈계 약물, 삼환계 항우울제 및 알코올을 투여한 환자는 의사 또는 약사와 상의하십시오. 복용 중에는 음주하지 마십시오.
# invoke 실행 시간: 4.006586313247681 초
# 643 번째 답변 :  죽상·발적(충혈되어 붉어짐), 가려움, 구역, 구토, 식욕부진, 변비, 어지러움, 부종(부기), 쇽 증상(두드러기, 부기, 가슴답답함, 창백, 수족냉증, 식은땀, 숨쉬기 곤란함), 피부점막안증후군(스티븐스-존슨증후군) 등이 나타날 수 있습니다.복용 후 천식, 전신의 나른함, 황달 등이 나타나면 즉시 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 0.7302522659301758 초
# 644 번째 답변 :  실온에서 보관하십시오.
# invoke 실행 시간: 3.6977264881134033 초
# 645 번째 답변 :  이 약은 류마티양 관절염, 골관절염(퇴행성 관절질환), 강직성 척추염, 건염(힘줄염), 급성통풍, 월경곤란증과 활액(윤활)낭염, 골격근장애(염좌(삠), 좌상(타박상), 외상(상처), 요천통(허리통증)), 수술후 동통(통증), 편두통, 발치(이를 뽑음)후 통증에 사용합니다.
# invoke 실행 시간: 3.1966593265533447 초
# 646 번째 답변 :  성인은 류마티양 관절염, 골관절염, 강직성 척추염에 성인은 1회 1~2정(275~550 mg), 1일 2회(12시간마다) 복용하며, 편두통에는 초회량으로 3정(825 mg)을 복용하고 필요에 따라 추가 복용할 수 있습니다. 이 약은 식사와 함께 복용하거나 식사 후 복용하는 것이 좋습니다.
# invoke 실행 시간: 4.4173805713653564 초
# 647 번째 답변 :  스노핀정275밀리그램(나프록센나트륨)을 사용하기 전에 알아야 할 내용은 다른 비스테로이드성 소염진통제 및 나프록센 유도체, 아스피린, 고용량의 메토트렉세이트와 함께 복용하지 말아야 하며, 히단토인계 항간질제, 설파제, 설포닐요소계 혈당강하제, 프로프라놀롤 등과 함께 복용 시 의사나 약사와 상의해야 합니다. 또한, 이 약을 복용하는 동안 주의해야 할 약 또는 음식에 대해서도 알아야 합니다.
# invoke 실행 시간: 8.583276987075806 초
# 648 번째 답변 :  이 약에 과민증 환자, 소화성궤양, 심한 혈액이상, 심한 간장애, 심한 심기능부전, 심한 신장애, 심한 고혈압, 아스피린 등 비스테로이드성 소염진통제에 과민증 환자, 아스피린이나 다른 비스테로이드성 소염진통제(COX-2 저해제 포함)에 의하여 천식, 비염(코염), 코의 용종, 두드러기, 알레르기 반응 또는 경험자, 관상동맥(심장동맥) 우회로술 전후에 발생하는 통증의 치료 및 갈락토오스 불내성, Lapp 유당분해효소 결핍증 또는 포도당-갈락토오스 흡수장애 등의 유전적인 문제가 있는 환자는 이 약을 복용하지 마십시오. 이 약을 복용하기 전에 소화성궤양 경험자, 혈액이상 경험자, 출혈경향이 있는 환자, 간장애 또는 경험자, 신장애 또는 경험자, 심기능장애, 고혈압, 기관지천식, 전신성홍반성루푸스 및 혼합결합조직질환 환자, 고령자는 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 5.867123126983643 초
# 649 번째 답변 :  다른 비스테로이드성 소염진통제 및 나프록센 유도체, 아스피린, 고용량의 메토트렉세이트와 함께 복용하지 마십시오. 히단토인계 항간질제, 설파제, 설포닐요소계 혈당강하제, 프로프라놀롤 및 다른 β-차단제, ACE 저해제(억제제)(캅토프릴 등), 루프계 이뇨제 및 티아지드계 이뇨제, 프로베네시드, 리튬, 저용량 메토트렉세이트, 쿠마린계 항응혈제(혈액응고저지제)(와파린 등), 지도부딘, 뉴퀴놀론계 항생물질(에녹사신 등)과 함께 복용 시 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 2.176919460296631 초
# 650 번째 답변 :  이 약의 이상반응으로는 혈액장애, 소화관 장애, 피부반응, 간장애, 신장애, 호흡기 장애, 중추신경계 장애 등이 나타날 수 있습니다. 이러한 증상이 나타나면 즉시 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 1.0083305835723877 초
# 651 번째 답변 :  실온에서 보관하십시오. 어린이의 손이 닿지 않는 곳에 보관하십시오.
# invoke 실행 시간: 1.1933660507202148 초
# 652 번째 답변 :  이 약은 인후염의 단기 증상 완화에 사용합니다.
# invoke 실행 시간: 2.3697612285614014 초
# 653 번째 답변 :  성인, 12세 이상 어린이 및 청소년은 이 약 1개를 입안에서 서서히 녹여서 복용합니다. 국소 자극을 피하기 위해 입안에서 굴리면서 복용하며, 필요시 3~6시간 간격으로 1일 최대 5개를 복용하고 최대 3일간 사용하십시오.
# invoke 실행 시간: 8.335364580154419 초
# 654 번째 답변 :  이 약 또는 아스피린, 다른 비스테로이드성 소염진통제에 과민증 환자, 소화성궤양, 출혈, 아스피린 또는 다른 비스테로이드성 소염진통제에 의한 천식(천식발작 포함), 두드러기, 기관지경련, 비염 또는 경험자, 중증 심기능부전, 비스테로이드성 소염진통제, 항류마티스제에 의한 위장관 출혈 또는 천공, 중증 대장염, 중증 혈액 이상 환자, 불분명한 조혈장애, 중증 간장애, 중증 신장애, 임신 후기 3개월인 임부, 유전성 과당 불내증, 포도당-갈락토오스 흡수장애, 백당-이소말타아제 결핍증 환자는 이 약을 복용하지 마십시오. 이 약을 복용하기 전에 기관지천식 또는 그 경험자, 심기능부전 환자 및 신장, 간장애, 고혈압, 혈액 이상 또는 그 경험자, 출혈 경향이 있는 환자, 고령자, 말초동맥폐색증, 뇌혈관질환, 고지혈증, 당뇨병, 흡연자, 고초열, 코폴립, 만성 폐쇄성 폐질환, 임신 초기 및 중기의 임부, 체액저류, 심부전 환자는 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 11.284754276275635 초
# 655 번째 답변 :  이 약 또는 아스피린, 다른 비스테로이드성 소염진통제에 과민증 환자, 소화성궤양, 출혈, 아스피린 또는 다른 비스테로이드성 소염진통제에 의한 천식(천식발작 포함), 두드러기, 기관지경련, 비염 또는 경험자, 중증 심기능부전, 비스테로이드성 소염진통제, 항류마티스제에 의한 위장관 출혈 또는 천공, 중증 대장염, 중증 혈액 이상 환자, 불분명한 조혈장애, 중증 간장애, 중증 신장애, 임신 후기 3개월인 임부, 유전성 과당 불내증, 포도당-갈락토오스 흡수장애, 백당-이소말타아제 결핍증 환자는 이 약을 복용하지 마십시오.이 약을 복용하기 전에 기관지천식 또는 그 경험자, 심기능부전 환자 및 신장, 간장애, 고혈압, 혈액 이상 또는 그 경험자, 출혈 경향이 있는 환자, 고령자, 말초동맥폐색증, 뇌혈관질환, 고지혈증, 당뇨병, 흡연자, 고초열, 코폴립, 만성 폐쇄성 폐질환, 임신 초기 및 중기의 임부, 체액저류, 심부전 환자는 의사 또는 약사와 상의하십시오.이 약 복용 후 어지러움 및 시각장애가 나타날 수 있으므로 운전 및 기계조작 시 주의하십시오.
# invoke 실행 시간: 4.556127309799194 초
# 656 번째 답변 :  COX-2 저해제를 포함하여 다른 비스테로이드성 소염진통제, 아스피린 등 혈소판 응집 억제제, 글루코코르티코이드, 칼륨보전이뇨제, 안지오텐신전환효소 억제제, 안지오텐신 II 길항제, 싸이클로스포린, 메토트렉세이트, 디곡신, 페니토인, 퀴놀론계 항균제, 푸로세미드 이뇨제, 경구용 항응혈제(예: 와파린), 항고혈압제, 리튬제제, 미페프리스톤, 프로베네시드, 설핀피라존을 함께 복용하지 마십시오.
# invoke 실행 시간: 3.979799747467041 초
# 657 번째 답변 :  드물게 쇽 증상(두드러기, 호흡곤란, 얼굴부기 등 과민성유사증상), 천식발작(건성수포음, 천명, 호흡곤란), 때때로 발적, 발진, 가려움, 수포, 짓무름, 자극감 및 종창 등의 접촉피부염이 나타날 수 있습니다. 피부건조 및 색소침착, 직사일광에 의한 광과민증, 피부발진이 전신으로 확대될 경우 사용을 즉각 중지하고 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 1.117628812789917 초
# 658 번째 답변 :  실온에서 보관하고 어린이의 손이 닿지 않는 곳에 보관해야 합니다.
# invoke 실행 시간: 2.385488986968994 초
# 659 번째 답변 :  이 약은 습진, 피부염군(진행성 지장각피증, 만성단순태선 포함), 양진(가려움발진)군(구진두드러기 포함), 벌레물린데, 건선, 손바닥 및 발바닥 농포증에 사용합니다.
# invoke 실행 시간: 1.3357713222503662 초
# 660 번째 답변 :  1일 수회 적당량을 환부에 바르고 증상에 따라 적절히 증감합니다.
# invoke 실행 시간: 0.9814317226409912 초
# 661 번째 답변 :  죄송합니다, 그 정보를 찾을 수 없습니다.
# invoke 실행 시간: 3.005769729614258 초
# 662 번째 답변 :  스몰크림(프레드니솔론발레로아세테이트)의 사용상 주의사항은 다음과 같습니다: 이 약을 사용하는 동안 주의해야 할 약 또는 음식은 프로베네시드를 투여한 환자는 의사 또는 약사와 상의해야 합니다. 이 약은 전염성 농가진, 모낭염, 칸디다증, 백선, 부스럼, 피부자극 등의 이상반응이 나타날 수 있습니다.
# invoke 실행 시간: 1.6636433601379395 초
# 663 번째 답변 :  죄송합니다. 스몰크림(프레드니솔론발레로아세테이트)에 대한 정보가 없어서 해당 질문에 대한 답변을 제공할 수 없습니다.
# invoke 실행 시간: 4.537631273269653 초
# 664 번째 답변 :  전염성 농가진, 모낭염, 칸디다증, 백선, 부스럼, 피부자극, 자통(통증), 발열, 작열감(화끈감), 발진, 발적(충혈되어 붉어짐), 홍조, 가려움, 피부건조, 농포성피부염, 알레르기성 접촉피부염, 땀띠, 상처악화, 욕창, 농포증 등이 나타날 수 있습니다. 안검피부에 사용 시 안압 상승, 녹내장, 국소 코르티코이드의 전신 흡수로 인해 가역적인 쿠싱증후군, 과혈당증, 당뇨 등이 나타날 수 있습니다.
# invoke 실행 시간: 1.3382701873779297 초
# 665 번째 답변 :  습기와 빛을 피해 실온에서 보관하십시오. 어린이의 손이 닿지 않는 곳에 보관하십시오.
# invoke 실행 시간: 3.655247449874878 초
# 666 번째 답변 :  이 약은 습진ㆍ피부염군, 피부가려움, 벌레물린데에 사용합니다.
# invoke 실행 시간: 2.121774911880493 초
# 667 번째 답변 :  사용 전 잘 흔들어 섞은 후 1일 1~3회 적당량을 환부(질환 부위)에 바르고 증상에 따라 적절히 증감합니다. 이 약의 치료기간은 7일 이내로 제한합니다.
# invoke 실행 시간: 1.5735251903533936 초
# 668 번째 답변 :  죄송합니다, 그 정보에는 "스무스케어로션2.5%(히드로코르티손)"에 대한 내용이 포함되어 있지 않습니다.
# invoke 실행 시간: 1.264646053314209 초
# 669 번째 답변 :  죄송합니다, 제가 찾은 정보에는 "스무스케어로션2.5%(히드로코르티손)"에 대한 정보가 없습니다.
# invoke 실행 시간: 1.9947564601898193 초
# 670 번째 답변 :  죄송합니다, 제가 찾은 정보에는 '스무스케어로션2.5%(히드로코르티손)'에 대한 정보가 없습니다. 해당 제품에 대한 정보가 없어서 도움을 드리지 못합니다.
# invoke 실행 시간: 5.297472953796387 초
# 671 번째 답변 :  전염성 농가진, 모낭염, 칸디다증, 백선, 부스럼, 피부자극, 자통, 발열, 작열감(화끈감), 발진, 발적, 홍조, 가려움, 피부건조, 농포성피부염, 알레르기성 접촉피부염, 땀띠, 한진, 상처악화, 욕창, 농포증, 매우 드물게 두드러기, 피부박탈, 색소침착 변화, 적용 부위 자극/통증이 나타날 수 있습니다. 사용을 즉시 중지하고 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 3.0603339672088623 초
# 672 번째 답변 :  스무스케어로션2.5%(히드로코르티손)은 직사광선을 피하고 30도 미만의 실온에서 보관해야 합니다. 냉장고에 보관하지 않고 어린이 손이 닿지 않는 곳에 보관하는 것이 좋습니다.습기와 물기를 피해 보관하는 것이 중요합니다.
# invoke 실행 시간: 1.023569107055664 초
# 673 번째 답변 :  이 약은 안면 다한증(땀과다증)에 사용합니다.
# invoke 실행 시간: 2.6055784225463867 초
# 674 번째 답변 :  성인은 1일 1회, 이 약 1매를 눈, 코, 입을 제외한 안면 환부(질환 부위)에 가볍게 5회 정도 문지릅니다.이 약은 적용하기 전에 환부를 깨끗이 씻고 충분히 건조시켜야 하며, 적용 후 4시간 이내에는 환부를 씻지 말아야 합니다.
# invoke 실행 시간: 1.5076501369476318 초
# 675 번째 답변 :  죄송합니다. 제가 찾은 정보에는 '스웨트롤패드액(글리코피롤레이트)'에 대한 내용이 포함되어 있지 않습니다.
# invoke 실행 시간: 4.631790637969971 초
# 676 번째 답변 :  이 약 또는 항콜린제에 과민증 환자, 녹내장 환자, 임부 또는 임신하고 있을 가능성이 있는 여성 및 수유부는 이 약을 사용하지 마십시오. 이 약을 사용하기 전에 폐쇄성 요로질환, 폐쇄성 위장관질환, 마비성 장폐색증, 장관이완증, 심장혈관부전증, 중증 궤양성 대장염 및 이에 합병된 거대결장 환자, 중증 근무력증 환자는 의사 또는 약사와 상의하십시오. 눈, 코, 입 점막, 벗겨지거나 손상된 피부, 최근에 면도한 부위에 사용하지 않으며 약액이 묻지 않도록 주의하십시오.
# invoke 실행 시간: 1.1154234409332275 초
# 677 번째 답변 :  죄송합니다, 그 정보에 대한 내용은 제공되지 않았습니다.
# invoke 실행 시간: 2.0784223079681396 초
# 678 번째 답변 :  죄송합니다, 제가 찾은 정보에는 '스웨트롤패드액(글리코피롤레이트)'에 대한 이상반응 정보가 포함되어 있지 않습니다.
# invoke 실행 시간: 1.2373323440551758 초
# 679 번째 답변 :  습기와 빛을 피해 실온에서 보관하고, 어린이의 손이 닿지 않는 곳에 보관해야 합니다.
# invoke 실행 시간: 1.7995476722717285 초
# 680 번째 답변 :  이 약은 위장관계 질환의 발작성 동통 또는 담도계, 비뇨기계, 월경곤란증 등 여성 생식기계의 기능장애 및 경련성 동통에 사용합니다.
# invoke 실행 시간: 1.176032543182373 초
# 681 번째 답변 :  성인은 1회 1~2정 1일 3회 복용합니다. 1일 최대용량은 6정을 초과하지 마십시오.
# invoke 실행 시간: 1.842651605606079 초
# 682 번째 답변 :  매일 세잔 이상 정기적 음주자가 이 약 또는 다른 해열진통제를 복용할 때는 의사 또는 약사와 상의하십시오. 간손상을 일으킬 수 있습니다.
# invoke 실행 시간: 5.045893669128418 초
# 683 번째 답변 :  이 약에 의한 과민증(발진, 붉은 반점, 가려움, 후두, 눈꺼풀, 입술 등의 부종)의 경험자, 다른 감기약 또는 해열진통제에 의한 천식 경험자, 심한 증상 신장애, 글루코스-6-인산탈수소효소 결핍증 환자 등은 이 약을 복용하지 말아야 합니다. 이 약을 복용하기 전에 세균성설사 환자, 간장애 또는 그 경험자, 길버트증후군, 심장기능이상, 소화성궤양의 경험자 등은 의사나 약사와 상의해야 합니다.운전 및 기계조작 시 주의가 필요합니다.
# invoke 실행 시간: 3.577158212661743 초
# 684 번째 답변 :  아세트아미노펜을 포함하는 다른 제품, 바르비탈계 약물, 삼환계 항우울약 및 알코올을 복용한 사람은 이 약을 복용하지 마십시오. 와파린, 리튬, 티아지드계 이뇨제, 삼환계 항우울약, 항히스타민제, 항정신병약, 퀴니딘, 아만타딘, 디소피라미드 및 기타 항콜린약물과 함께 복용 시 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 3.6042301654815674 초
# 685 번째 답변 :  혈소판감소증, 무과립구증, 청색증, 백혈구감소증, 과립구감소, 용혈성(적혈구 파괴성)빈혈, 메트헤모글로빈혈증 등의 이상반응이 나타날 수 있습니다. 또한 홍조, 피부 반응, 땀분비이상, 가려움증, 피부건조, 두드러기, 붉은 반점, 쇼크를 포함한 혈압저하 등이 있을 수 있습니다.
# invoke 실행 시간: 0.7742822170257568 초
# 686 번째 답변 :  저는 그 정보를 가지고 있지 않습니다.

# %%
question = test_data['question']
test_output = pd.DataFrame({"question": question,
                            "answer" : answer})
test_output.to_excel("e약은요 4차 테스트 결과_jhgan임베딩_문서3개.xlsx",index = False)

# %% [markdown]
# ### db 초기화
# ```python
# # To cleanup, you can delete the collection
# vectordb.delete_collection()
# vectordb.persist()
# ```
