# %%
from langchain_openai import ChatOpenAI
import os
import openai
import getpass
import tiktoken
from langchain.chains import RetrievalQA
from langchain.chat_models import ChatOpenAI
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.embeddings import HuggingFaceEmbeddings

# %%
os.environ["OPENAI_API_KEY"] = getpass.getpass()

# %%
tokenizer = tiktoken.get_encoding("cl100k_base")

def tiktoken_len(text):
    tokens = tokenizer.encode(text)
    return len(tokens)

# %%
from langchain_community.document_loaders.csv_loader import CSVLoader

loader = CSVLoader(file_path='e약은요.csv')
data = loader.load()

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size = 1000, chunk_overlap = 200, length_function=tiktoken_len)
texts = text_splitter.split_documents(data)

# %%
model_name = "jhgan/ko-sbert-nli"
model_kwargs = {'device': 'cuda'}
encode_kwargs = {'normalize_embeddings': True}
hf = HuggingFaceEmbeddings(
    model_name=model_name,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs
)
# Out:
# c:\Users\Admin\anaconda3\envs\sba\lib\site-packages\torch\_utils.py:776: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()

# %%
#save to disk
emed_db = Chroma.from_documents(texts, hf,persist_directory="./e약은요db")

# %%
#벡터db의 데이터가 in-memory가 아니라 persistent storage인 disk에 저장되게 선언
emed_db.persist()
emed_db = None

# %%
# load from disk
emed_db = Chroma(persist_directory="./e약은요db",embedding_function=hf)

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain.chains import create_history_aware_retriever, create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_community.chat_message_histories import ChatMessageHistory
from langchain_core.chat_history import BaseChatMessageHistory

openai = ChatOpenAI(model = "gpt-3.5-turbo",temperature=0)

retriever = emed_db.as_retriever(search_type="similarity", search_kwargs={'k':5})#search_type = "mmr",

def format_docs(docs):
    return "\n\n".join([d.page_content for d in docs])

contextualize_q_system_prompt = """Given a chat history and the latest user question \
which might reference context in the chat history, formulate a standalone question \
which can be understood without the chat history. Do NOT answer the question, \
just reformulate it if needed and otherwise return it as is."""

contextualize_q_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", contextualize_q_system_prompt),
        MessagesPlaceholder("chat_history"),
        ("human","{input}"),
    ]
)

history_aware_retriever = create_history_aware_retriever(
    openai, retriever, contextualize_q_prompt
)

#답변 생성
qa_system_prompt = """You are an assistant for question-answering tasks. \
ONLY USE the following pieces of retrieved context to answer the question. \
If you don't know the answer, just say that you don't know. \
Use three sentences maximum and keep the answer concise.\

{context}"""

qa_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", qa_system_prompt),
        MessagesPlaceholder("chat_history"),
        ("human", "{input}"),
    ]
)
question_answer_chain = create_stuff_documents_chain(openai, qa_prompt)

rag_chain = create_retrieval_chain(history_aware_retriever,question_answer_chain)

# chat history 관리
store = {}

def get_session_history(session_id : str) -> BaseChatMessageHistory:
    if session_id not in store:
        store[session_id] = ChatMessageHistory()
    return store[session_id]

conversational_rag_chain = RunnableWithMessageHistory(
    rag_chain,
    get_session_history,
    input_messages_key= "input",
    history_messages_key= "chat_history",
    output_messages_key= "answer",
)
# Out:
# c:\Users\Admin\anaconda3\envs\sba\lib\site-packages\langchain_core\_api\deprecation.py:119: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(

# %%
id = "0"
query1 = "게보린정 효능 알려줘"
conversational_rag_chain.invoke(
    {"input": query1},
    config={
        "configurable": {"session_id":id}
    },
)["answer"]
# Out:
# '게보린정은 두통, 치통, 발치 후 동통, 인후통, 귀의 통증, 관절통, 신경통, 요통, 근육통, 견통, 타박통, 골절통, 염좌통, 월경통, 외상통의 진통과 오한, 발열시의 해열에 사용됩니다.'

# %% [markdown]
# # Test 수행

# %%
import pandas as pd

# %%
test_data = pd.read_excel("data preprocessing\e약은요 테스트용 질문 데이터셋.xlsx")
test_data.head()
# Out:
#                                  question  \
# 0                      닥터베아제정의 효능은 무엇입니까?
# 1                      닥터베아제정은 어떻게 사용합니까?
# 2    닥터베아제정을 사용하기 전에 반드시 알아야 할 내용은 무엇입니까?
# 3                닥터베아제정의 사용상 주의사항은 무엇입니까?
# 4  닥터베아제정을 사용하는 동안 주의해야 할 약 또는 음식은 무엇입니까?
#
#                                               answer
# 0  이 약은 소화불량, 식욕감퇴(식욕부진), 과식, 체함, 소화촉진, 소화불량으로 인한...
# 1                         성인 1회 1정을 1일 3회 식후에 복용합니다.
# 2                                                NaN
# 3  만 7세 이하의 소아는 이 약을 복용하지 마십시오.이 약을 복용하기 전에 알레르기 ...
# 4                                                NaN

# %% [markdown]
# ### 참고사항
# 추후에 특정 의약품에 대한 질문을 이어서했을때의 정확도를 살피고자 할때는 session_id로 제공되는 부분에 의약품명을 넣으면 된다.
#
# 의약품명을 넣는 방법은 애초에 데이터셋을 만들때 의약품명 열을 하나 추가하면 된다

# %%
import time
def measure_time(func):
    def wrapper(*args, **kwargs):
        start_time = time.time()
        result = func(*args, **kwargs)
        end_time = time.time()
        elapsed_time = end_time - start_time
        print(f"{func.__name__} 실행 시간: {elapsed_time} 초")
        return result
    return wrapper

# %%
@measure_time
def invoke(id, input):
    answer = conversational_rag_chain.invoke(
        {"input": input},
        config={
            "configurable": {"session_id":id}
        },
    )["answer"]

    return answer

# %%
answer = [] #llm의 응답을 저장할 리스트
for i, row in test_data.iterrows():
    answer.append(invoke(row.question, row.question))
    print(i+1,'번째 답변 : ',answer[i])
# Out:
# invoke 실행 시간: 2.9079980850219727 초
# 0 번째 답변 :  제공된 정보에는 "닥터베아제정"에 대한 정보가 없습니다. 따라서 해당 제품의 효능에 대해 알 수 없습니다.
# invoke 실행 시간: 2.1877541542053223 초
# 1 번째 답변 :  죄송합니다, "닥터베아제정" 제품에 대한 정보가 제공된 문서에는 포함되어 있지 않습니다.
# invoke 실행 시간: 4.637258768081665 초
# 2 번째 답변 :  죄송합니다, "닥터베아제정"에 대한 정보는 제공된 문맥에서 찾을 수 없습니다.
# invoke 실행 시간: 2.6425600051879883 초
# 3 번째 답변 :  죄송합니다, "닥터베아제정"에 대한 정보가 제공된 문서 중에는 존재하지 않습니다.
# invoke 실행 시간: 9.274980545043945 초
# 4 번째 답변 :  닥터베아제정을 사용하는 동안 주의해야 할 약은 스테로이드제, 항생물질, 항암제, 아졸계 항진균제, 다른 위장약과 함께 복용하지 말아야 합니다. 또한 테트라사이클린계 항생물질(테트라사이클린 등), 뉴-퀴놀론계 항균제(오플록사신 등)를 함께 사용 시 의사 또는 약사와 상의해야 합니다. 복용 중에는 음주하지 말아야 합니다.
# invoke 실행 시간: 5.22075080871582 초
# 5 번째 답변 :  닥터베아제정을 복용할 때 나타날 수 있는 이상반응은 적용부위에 화상, 결막염, 눈자극, 눈물흘림 증가, 탈모, 지각과민, 모낭염, 고름물집, 발진, 압통, 여드름, 탈모, 피부건조, 피부장애, 머릿결 이상, 머리카락 색 변화, 모낭염, 미각이상, 두드러기 등이 있습니다. 만약 과민증상이나 자극감이 나타나면 즉시 의사나 약사와 상의해야 합니다.
# invoke 실행 시간: 1.7697908878326416 초
# 6 번째 답변 :  실온에서 보관하십시오.
# invoke 실행 시간: 2.7982797622680664 초
# 7 번째 답변 :  맥시부펜시럽(덱시부프로펜)의 효능은 "급성 상기도 감염으로 인한 발열 시 해열에 사용합니다"입니다.
# invoke 실행 시간: 2.0413153171539307 초
# 8 번째 답변 :  죄송합니다. 맥시부펜시럽(덱시부프로펜)에 대한 정보를 찾을 수 없습니다.
# invoke 실행 시간: 3.018104314804077 초
# 9 번째 답변 :  맥시부펜시럽(덱시부프로펜)을 사용하기 전에 반드시 알아야 할 내용은 제공된 정보에는 포함되어 있지 않습니다.
# invoke 실행 시간: 7.151857376098633 초
# 10 번째 답변 :  맥시부펜시럽(덱시부프로펜)의 사용상 주의사항은 다음과 같습니다:
# - 이 약에 과민증, 19세 미만 환자, 탈모증 이외의 사람, 갈락토오스 불내성, Lapp 유당분해효소 결핍증 또는 포도당-갈락토오스 흡수장애 등의 유전적인 문제가 있는 환자는 이 약을 복용하지 마십시오.
# - 이 약을 복용하기 전에 임부 또는 임신하고 있을 가능성이 있는 여성 및 수유부, 약물에 의한 알레르기 증상 경험자는 의사 또는 약사와 상의하십시오.
# - 6주 정도 복용하여도 증상의 개선이 없을 경우 복용을 즉각 중지하고 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 2.953965663909912 초
# 11 번째 답변 :  저는 죄송합니다. 맥시부펜시럽(덱시부프로펜)에 대한 정보를 제공할 수 없습니다.
# invoke 실행 시간: 2.826669931411743 초
# 12 번째 답변 :  죄송합니다. 맥시부펜시럽(덱시부프로펜)에 대한 이상반응에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 2.958674430847168 초
# 13 번째 답변 :  맥시부펜시럽(덱시부프로펜)은 실온에서 보관해야 합니다. 어린이의 손이 닿지 않는 곳에 보관하십시오.
# invoke 실행 시간: 3.4601492881774902 초
# 14 번째 답변 :  뮤테론캡슐200밀리그램(아세틸시스테인)의 효능은 급·만성기관지염, 기관지천식, 후두염, 부비동염, 낭성섬유증의 객담배출곤란에 사용합니다.
# invoke 실행 시간: 4.762194871902466 초
# 15 번째 답변 :  뮤테란과립200밀리그램(아세틸시스테인)은 급성질환에 성인은 1회 200 mg씩, 1일 3회, 만 6~14세의 소아는 1회 200 mg씩, 1일 2회 식전에 소량의 물과 함께 복용합니다. 만성질환에 성인은 1회 200 mg씩, 1일 2회, 만 6~14세의 소아는 1회 100 mg씩, 1일 3회 식전에 소량의 물과 함께 복용합니다.
# invoke 실행 시간: 4.836322784423828 초
# 16 번째 답변 :  뮤테란과립200밀리그램(아세틸시스테인)을 사용하기 전에 반드시 알아야 할 내용은 아래와 같습니다:
# - 이 약을 사용하기 전에 알레르기 반응이 있는 경우 의사와 상의해야 합니다.
# - 정확한 용법과 용량을 준수해야 합니다.
# - 어린이에게 투여할 경우 보호자의 지도 감독하에 사용해야 합니다.
# invoke 실행 시간: 3.2178328037261963 초
# 17 번째 답변 :  죄송합니다, 뮤테란과립200밀리그램(아세틸시스테인)에 대한 정보는 현재 제공된 내용에 포함되어 있지 않습니다.
# invoke 실행 시간: 5.978533029556274 초
# 18 번째 답변 :  뮤테란과립200밀리그램(아세틸시스테인)을 사용하는 동안 주의해야 할 약은 다른 비스테로이드성 소염진통제, 아스피린, 고용량(15 mg/주 이상)의 메토트렉세이트와 함께 사용하지 마십시오. 이 약을 복용하기 전에 다양한 약물과 함께 복용 시 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 7.0332887172698975 초
# 19 번째 답변 :  뮤테란과립200밀리그램(아세틸시스테인)을 복용할 때 나타날 수 있는 이상반응은 홍반, 피부발진, 가려움, 전신권태, 호흡곤란 등의 알레르기 증상 및 아나필락시스 반응, 식욕부진, 구역ㆍ구토, 부종, 체중감소, 위장관장애, 수면변화, 집중부족, 과잉행동, 과민성, 흥분, 우울증, 혼란, 판단력 장애 등의 중추신경장애 등이 있습니다. 만약 이러한 증상이 나타나면 즉시 의사나 약사와 상의해야 합니다.
# invoke 실행 시간: 3.403670072555542 초
# 20 번째 답변 :  뮤테란과립200밀리그램(아세틸시스테인)은 실온에서 보관해야 합니다. 어린이의 손이 닿지 않는 곳에 보관하십시오.
# invoke 실행 시간: 4.484207391738892 초
# 21 번째 답변 :  뮤테란캡슐200밀리그램(아세틸시스테인)의 효능은 급·만성기관지염, 기관지천식, 후두염, 부비동염, 낭성섬유증의 객담배출곤란에 사용됩니다.
# invoke 실행 시간: 6.503549575805664 초
# 22 번째 답변 :  뮤테론캡슐200밀리그램(아세틸시스테인)은 급성질환에 성인은 1회 200 mg씩, 1일 3회, 만 6~14세의 소아는 1회 200 mg씩, 1일 2회 식전에 소량의 물과 함께 복용합니다. 만성질환에 성인은 1회 200 mg씩, 1일 2회, 만 6~14세의 소아는 1회 100 mg씩, 1일 3회 식전에 소량의 물과 함께 복용합니다. 낭성섬유증에 만 6세 이상 소아는 1회 200 mg씩, 1일 3회 식전에 소량의 물과 함께 복용합니다.
# invoke 실행 시간: 1.7687883377075195 초
# 23 번째 답변 :  뮤테란캡슐200밀리그램(아세틸시스테인)을 사용하기 전에 반드시 알아야 할 내용은 제공된 정보에는 없습니다.
# invoke 실행 시간: 1.5967648029327393 초
# 24 번째 답변 :  뮤테란캡슐200밀리그램(아세틸시스테인)의 사용상 주의사항은 알려지지 않았습니다.
# invoke 실행 시간: 4.842880487442017 초
# 25 번째 답변 :  뮤테란캡슐200밀리그램(아세틸시스테인)을 사용하는 동안 주의해야 할 약 또는 음식은 아스피린이나 다른 비스테로이드성 소염진통제, 천식, 두드러기 또는 알레르기 반응을 일으킬 수 있는 약물입니다. 또한, 위장관 궤양, 출혈 경험이 있는 환자, 심한 간장애, 신장장애, 심장기능부전, 고혈압, 임신 중인 여성, 고령자, 혈액응고장애가 있는 환자 등도 주의해야 합니다. 이러한 경우에는 의사나 약사와 상의해야 합니다.
# invoke 실행 시간: 4.040398836135864 초
# 26 번째 답변 :  뮤테란캡슐200밀리그램(아세틸시스테인)을 복용할 때 드물게 구역, 구토, 구내염, 가슴쓰림, 설사, 두드러기, 가려움, 발진, 두통, 이명, 기관지경련(특히 천식 환자), 빈맥, 고혈압 등의 이상반응이 나타날 수 있습니다. 이러한 증상이 나타나면 즉시 복용을 중지하고 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 2.007488489151001 초
# 27 번째 답변 :  뮤테란캡슐200밀리그램(아세틸시스테인)은 실온에서 보관해야 합니다. 어린이의 손이 닿지 않는 곳에 보관하시기 바랍니다.
# invoke 실행 시간: 1.4022278785705566 초
# 28 번째 답변 :  저는 "베아제정"에 대한 정보를 찾을 수 없습니다. 제공된 정보에는 "베아제정"에 대한 내용이 없습니다.
# invoke 실행 시간: 2.024667501449585 초
# 29 번째 답변 :  죄송합니다, "베아제정"에 대한 정보가 제공된 문맥에서 찾을 수 없습니다. 해당 제품에 대한 정보가 없기 때문에 사용 방법에 대해 알 수 없습니다.
# invoke 실행 시간: 4.847823619842529 초
# 30 번째 답변 :  베아제정을 사용하기 전에 반드시 알아야 할 내용은 과민증 환자, 갈락토오스 불내성, Lapp 유당분해효소 결핍증 또는 포도당-갈락토오스 흡수장애 등의 유전적인 문제가 있는 환자는 이 약을 복용하지 말아야 하며, 임부 및 수유부는 의사 또는 약사와 상의해야 합니다. 또한, 정해진 용법과 용량을 잘 지켜야 하며, 1개월 정도 복용하여도 증상의 개선이 없을 경우 즉시 중지하고 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 4.152712821960449 초
# 31 번째 답변 :  베아제정의 사용상 주의사항은 중증 신기능 장애, 간성혼수, 시스틴뇨증, 갈락토오스 불내성, Lapp 유당분해효소 결핍증 또는 포도당-갈락토오스 흡수장애 등의 유전적인 문제가 있는 환자는 이 약을 복용하지 말아야 하며, 정해진 용법과 용량을 잘 지켜야 합니다. 또한, 1개월 정도 복용하여도 증상의 개선이 없을 경우 즉각 중지하고 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 4.135774612426758 초
# 32 번째 답변 :  베아제정을 사용하는 동안 주의해야 할 약은 경구용 항응고제(쿠마린계 약물), 살리실산염, 아스피린, 철분제, 페니토인, 일부 항전간제, 에스트로겐이 포함된 경구용 피임약, 테트라사이클린계 항생제, 플루페나진, 오르리스타트, 바르비탈산 유도체, 코르티코스테로이드제입니다. 또한, 과도한 음주나 흡연을 삼가해야 합니다.
# invoke 실행 시간: 5.344935655593872 초
# 33 번째 답변 :  베아제정을 복용할 때 나타날 수 있는 이상반응으로는 쇽 증상(호흡곤란, 전신홍조, 혈관부종, 두드러기), 천식발작, 과민증(홍반, 가려움, 코막힘, 심장-호흡기 장애, 때때로 두드러기, 비염양 증상, 결막염) 등이 있습니다. 또한 드물게 간장애, 신장애, 혈액학적 이상(빈혈, 백혈구 감소, 혈소판 감소 등), 식욕부진, 가슴쓰림, 위통, 구토 등의 증상이 나타날 수 있습니다. 만약 이러한 증상이 나타나면 즉시 의사나 약사와 상의해야 합니다.
# invoke 실행 시간: 1.459381341934204 초
# 34 번째 답변 :  죄송합니다, "베아제정"에 대한 정보가 제공된 문맥에서 찾을 수 없습니다.
# invoke 실행 시간: 1.912522792816162 초
# 35 번째 답변 :  제공된 정보에는 "보령뮤코미스트액(아세틸시스테인)"에 대한 정보가 없습니다. 따라서 해당 제품의 효능에 대해 알 수 없습니다.
# invoke 실행 시간: 2.260880470275879 초
# 36 번째 답변 :  죄송합니다, 제가 찾은 정보에는 "보령뮤코미스트액(아세틸시스테인)"에 대한 정보가 포함되어 있지 않습니다. 해당 제품의 사용 방법에 대해 알려드릴 수 없습니다.
# invoke 실행 시간: 3.1098170280456543 초
# 37 번째 답변 :  아세틸시스테인을 사용하기 전에 다른 약물에 알레르기 반응이 있는 경우 의사나 약사와 상의해야 합니다. 또한, 심한 간질환 또는 신장질환 환자는 주의해야 합니다. 이 약은 식사 중 또는 식사 후에 복용할 수 있지만, 산성 약물과 함께 복용할 때는 주의해야 합니다.
# invoke 실행 시간: 2.0793066024780273 초
# 38 번째 답변 :  제공된 정보에는 "보령뮤코미스트액(아세틸시스테인)"에 대한 내용이 포함되어 있지 않습니다. 따라서 해당 제품의 사용상 주의사항에 대한 정보는 제공할 수 없습니다.
# invoke 실행 시간: 4.063246965408325 초
# 39 번째 답변 :  보령뮤코미스트액(아세틸시스테인)을 사용하는 동안 주의해야 할 약은 파라세타몰, 카페인, 이미프라민, 옥사제팜, 펜타조신, 프로프라놀롤, 테오필린, 와파린, 에스트로겐, 리그노카인, 페나세틴, 인슐린, 아드레날린성 길항제 등입니다. 음식에 대한 특별한 주의사항은 제공되지 않았습니다.
# invoke 실행 시간: 1.7688486576080322 초
# 40 번째 답변 :  보령뮤코미스트액(아세틸시스테인)의 사용상 주의사항에 따르면, 이 약에 과민증 환자는 이 약을 사용하지 말아야 합니다.
# invoke 실행 시간: 2.560863494873047 초
# 41 번째 답변 :  보령뮤코미스트액(아세틸시스테인)은 습기와 빛을 피해 실온에서 보관해야 합니다. 어린이의 손이 닿지 않는 곳에 보관하고, 개봉 후 즉시 사용하고 남은 액은 버려야 합니다.
# invoke 실행 시간: 1.4625279903411865 초
# 42 번째 답변 :  제공된 정보에는 "복합써스펜좌약"에 대한 정보가 없습니다. 따라서 해당 제품의 효능에 대한 정보를 제공할 수 없습니다.
# invoke 실행 시간: 1.7755224704742432 초
# 43 번째 답변 :  죄송합니다, 제공된 정보에서 "복합써스펜좌약"에 대한 정보를 찾을 수 없습니다.
# invoke 실행 시간: 1.8942255973815918 초
# 44 번째 답변 :  복합써스펜좌약에 대한 정보가 제공되지 않았기 때문에 해당 제품에 대한 사용 전 반드시 알아야 할 내용을 파악할 수 없습니다.
# invoke 실행 시간: 0.8273110389709473 초
# 45 번째 답변 :  죄송합니다, 그 정보는 제공되지 않았습니다.
# invoke 실행 시간: 3.873669385910034 초
# 46 번째 답변 :  복합써스펜좌약을 사용하는 동안 주의해야 할 약은 아세트아미노펜을 포함하는 다른 제품, 다른 소염진통제, 다른 해열진통제와 함께 사용하지 말아야 합니다. 또한 바르비탈계 약물, 삼환계 항우울제, 알코올을 투여한 환자, 리튬, 티아지드계 이뇨제와 함께 복용 시 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 5.7063820362091064 초
# 47 번째 답변 :  복합써스펜좌약을 복용하는 동안 나타날 수 있는 이상반응은 피부점막안증후군(스티븐스-존슨증후군), 독성표피괴사용해(리엘증후군) 같은 심각한 피부 손상, 열, 가려움, 비염, 기침 및 인후염과 같은 비특이적 인플루엔자-유사 전구증상 등이 있습니다. 또한, 흔하게 구역, 흔하지 않게 구토, 설사, 소화불량, 복통, 가슴쓰림, 구강건조, 위부불쾌감, 위·복부팽만감, 변비, 식욕부진, 두드러기, 피부 발진 등의 증상이 나타날 수 있습니다.
# invoke 실행 시간: 0.9409141540527344 초
# 48 번째 답변 :  복합써스펜좌약은 실온에서 보관하십시오.
# invoke 실행 시간: 5.432149887084961 초
# 49 번째 답변 :  어린이부루펜시럽(이부프로펜)의 효능은 알레르기성 비염, 비강염, 비강 충혈, 비강 붓기, 비강 가려움증, 비강 콧물, 인후통, 기침, 목의 통증, 발열, 두통, 근육통, 관절통, 치통, 생리통, 감기, 인플루엔자, 인후염, 편도염, 중이염, 두드러기, 통풍, 염좌, 관절염, 근육염, 신경통, 통증, 염증, 발적, 종창, 자극감 등의 증상 완화에 사용됩니다.
# invoke 실행 시간: 3.8445849418640137 초
# 50 번째 답변 :  어린이부루펜시럽(이부프로펜)은 생후 6개월 이상의 소아에게 1회 0.4~0.6 mL/kg(5 ~ 7 mg/kg)의 용량을 4~6시간 간격으로 필요시에 복용하며, 1일 최대 4회(28 mg/kg)를 넘지 않습니다. 체중이 30kg 이하인 소아에게는 1일 최대 25 mL(300 mg)을 초과하지 않도록 합니다. 연령대별 1회 권장용량은 허가사항을 참고하시면 됩니다.
# invoke 실행 시간: 4.368425607681274 초
# 51 번째 답변 :  어린이부루펜시럽(이부프로펜)을 사용하기 전에 반드시 알아야 할 내용은 다음과 같습니다: 이 약에 과민증 환자는 사용하지 말아야 하며, 다른 알레르기 치료를 받고 있는 사람, 알레르기 증상 경험자, 가려움을 동반한 눈의 통증, 알레르기 증상이 분명하지 않은 사람, 임부 또는 수유부는 의사나 약사와 상의해야 합니다.
# invoke 실행 시간: 3.755305767059326 초
# 52 번째 답변 :  어린이부루펜시럽(이부프로펜)의 사용상 주의사항은 다음과 같습니다: 이 약에 과민증 환자는 이 약을 사용하지 마십시오. 이 약을 사용하기 전에 약물 또는 화장품등에 의한 알레르기 증상 경험자, 심한 습윤이나 진무름 환자는 의사 또는 환자와 상의하십시오. 어린이에게 사용할 경우 보호자의 지도감독하에 사용하십시오.
# invoke 실행 시간: 6.36505913734436 초
# 53 번째 답변 :  어린이부루펜시럽(이부프로펜)을 사용하는 동안 주의해야 할 약 또는 음식은 과도한 음주나 흡연을 삼가해야 하며, 이 약을 복용하기 전에 다른 비스테로이드성 소염진통제, 아스피린, 메토트렉세이트, 코르티코스테로이드, 알코올, 디곡신, 페니토인, 프로베네시드, 설핀피라존, 설포닐우레아제, ACE 억제제 또는 안지오텐신Ⅱ 수용체 길항제, 이뇨제, 리튬, 쿠마린계 항응고제(와르파린 등), 바클로펜, 면역억제제(시클로스포린, 타크로리무스, 시롤리무스) 등을 함께 복용할 때는 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 5.821725845336914 초
# 54 번째 답변 :  어린이부루펜시럽(이부프로펜) 복용 시 나타날 수 있는 이상반응은 피부점막안증후군(스티븐스-존슨증후군), 독성표피괴사용해(리엘증후군)과 같은 심각한 피부 손상, 열, 가려움, 비염, 기침, 인후염 등의 비특이적 인플루엔자-유사 전구증상이 포함됩니다. 또한, 흔하게 구역, 흔하지 않게 구토, 설사, 소화불량, 복통, 가슴쓰림, 구강건조, 위부불쾌감, 위·복부팽만감, 변비, 식욕부진, 두드러기, 피부 발진 등의 이상반응이 나타날 수 있습니다.
# invoke 실행 시간: 2.3950977325439453 초
# 55 번째 답변 :  어린이부루펜시럽(이부프로펜)은 15도~30도의 실온에서 보관해야 합니다. 직사광선을 피하고 습기가 없는 곳에 보관하는 것이 좋습니다. 어린이의 손이 닿지 않는 곳에 보관해야 합니다.
# invoke 실행 시간: 0.9816787242889404 초
# 56 번째 답변 :  죄송합니다. 그 질문에 대한 정보는 제공할 수 없습니다.
# invoke 실행 시간: 1.0669901371002197 초
# 57 번째 답변 :  죄송합니다, 그 정보는 제공되지 않았습니다.
# invoke 실행 시간: 2.5393569469451904 초
# 58 번째 답변 :  아세트아미노펜을 사용하기 전에 반드시 알아야 할 내용은 만 6세 이하의 어린이가 과량 복용시 중독성 사망을 일으킬 수 있으므로 어린이의 손에 닿지 않는 곳에 보관해야 합니다.
# invoke 실행 시간: 4.774565696716309 초
# 59 번째 답변 :  아세트아미노펜을 포함한 약물을 사용하기 전에 과민증 환자, 만 2세 미만의 영아, 그리고 다른 특정 유전적 문제가 있는 환자는 사용하지 말아야 합니다. 또한, 임부 또는 임신 가능성이 있는 여성, 알레르기 체질, 고혈압, 심장질환, 당뇨병, 갑상선질환 등의 환자는 의사나 약사와 상의해야 합니다. 7일 이상 계속 사용하지 말아야 하며, 어린이에게 투여할 경우 보호자의 지도 감독하에 투여해야 합니다.
# invoke 실행 시간: 4.265509128570557 초
# 60 번째 답변 :  어린이타이레놀현탁액(아세트아미노펜)을 사용하는 동안 아스피린, 다른 비스테로이드성 소염진통제, 항암요법으로 사용하는 고용량(15 mg/주 이상)의 메토트렉세이트를 사용하지 말아야 합니다. 또한 코르티코스테로이드, 알코올, 디곡신, 페니토인, 프로베네시드, 설핀피라존 등과 함께 사용하기 전에 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 4.568791151046753 초
# 61 번째 답변 :  어린이타이레놀현탁액(아세트아미노펜)을 복용할 때 나타날 수 있는 이상반응은 피부점막안증후군(스티븐스-존슨증후군), 다형홍반, 구역, 구토, 속쓰림, 설사, 상복부 또는 복부 통증, 두통, 어지럼, 발열, 전신 발적, 발진, 가려움, 두드러기 등의 과민반응이 있습니다. 이러한 증상이 나타날 경우 즉시 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 2.916918992996216 초
# 62 번째 답변 :  어린이타이레놀현탁액(아세트아미노펜)은 서늘하고 건조한 곳에 보관해야 합니다. 직사광선을 피하고 어린이의 손이 닿지 않는 곳에 보관하십시오.습기를 피해 실온에서 보관하는 것이 좋습니다.
# invoke 실행 시간: 1.431081771850586 초
# 63 번째 답변 :  죄송합니다, 그 정보는 제공되지 않았습니다.
# invoke 실행 시간: 1.1901416778564453 초
# 64 번째 답변 :  죄송합니다, 그 제품에 대한 정보는 제공할 수 없습니다.
# invoke 실행 시간: 3.228316307067871 초
# 65 번째 답변 :  오트리빈멘톨0.1%분무제(자일로메타졸린염산염)을 사용하기 전에 반드시 알아야 할 내용은 약에 과민증 환자는 의사 또는 약사와 상의하십시오. 정해진 용법과 용량을 잘 지키십시오. 어린이에게 투여할 경우 보호자의 지도 감독하에 투여하십시오.
# invoke 실행 시간: 4.60068678855896 초
# 66 번째 답변 :  이 약에 과민증 환자, 만 12세 미만의 어린이, MAO 억제제를 복용하고 있거나 복용을 중단한 후 2주 이내의 사람은 이 약을 사용하지 말아야 합니다. 또한 알레르기 체질, 고혈압, 심장질환, 당뇨병, 갑상선질환, 녹내장 환자, 임부 또는 임신 가능성이 있는 여성, 흡연자, 천식, 만성 기관지염, 폐기종, 과도한 가래가 동반되는 기침 등의 환자는 의사나 약사와 상의해야 합니다.
# invoke 실행 시간: 0.9946589469909668 초
# 67 번째 답변 :  저는 그 정보를 가지고 있지 않습니다.
# invoke 실행 시간: 2.3596062660217285 초
# 68 번째 답변 :  제공된 정보에는 "오트리빈멘톨0.1%분무제(자일로메타졸린염산염)"에 대한 정보가 없습니다. 따라서 해당 제품의 이상반응에 대한 정보를 확인할 수 없습니다.
# invoke 실행 시간: 0.7557971477508545 초
# 69 번째 답변 :  저는 그 정보를 찾을 수 없습니다.
# invoke 실행 시간: 1.4657831192016602 초
# 70 번째 답변 :  죄송합니다, 임팩타민프리미엄정에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 1.4944899082183838 초
# 71 번째 답변 :  죄송합니다, 임팩타민프리미엄정에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 1.5445659160614014 초
# 72 번째 답변 :  임팩타민프리미엄정에 대한 정보가 제공되지 않았기 때문에 해당 제품에 대한 사전 정보를 파악할 수 없습니다.
# invoke 실행 시간: 1.0992655754089355 초
# 73 번째 답변 :  저는 임팩타민프리미엄정에 대한 정보를 찾을 수 없습니다.
# invoke 실행 시간: 8.220115423202515 초
# 74 번째 답변 :  임팩타민프리미엄정을 사용하는 동안 주의해야 할 사항으로는 과민증 환자, 아스피린이나 다른 비스테로이드성 소염진통제에 천식, 두드러기 또는 알레르기 반응 경험자, 위장관 궤양, 출혈 경험자, 심한 혈액이상, 간장애, 신장장애, 심장기능부전, 고혈압, 관상동맥 우회술 전후 통증발생 환자, 임부, 수유부, 염증성장질환 환자, 혈액응고장애가 있는 환자 등이 있습니다. 또한 약물 상호작용을 피하기 위해 의사나 약사와 상의하고, 운전 및 기계조작 시 주의하며, 급성질환에 장기 복용할 경우 5일 이내로 합니다.
# invoke 실행 시간: 4.928503036499023 초
# 75 번째 답변 :  임팩타민프리미엄정을 복용할 때 나타날 수 있는 이상반응은 적용부위에 화상, 결막염, 눈자극, 눈물흘림 증가, 탈모, 지각과민, 모낭염, 고름물집, 발진, 압통, 여드름, 탈모, 피부건조, 피부장애, 머릿결 이상, 머리카락 색 변화, 모낭염, 미각이상, 두드러기 등이 있습니다. 만약 과민증상이나 자극감이 나타나면 즉시 의사나 약사와 상의해야 합니다.
# invoke 실행 시간: 1.0634915828704834 초
# 76 번째 답변 :  임팩타민프리미엄정은 실온에서 보관하셔야 합니다.
# invoke 실행 시간: 2.6944174766540527 초
# 77 번째 답변 :  제일쿨파프의 효능은 삠, 타박상, 근육통, 관절통, 골절통, 요(허리)통, 어깨결림, 신경통, 류마티스통증의 진통ㆍ소염(항염)에 사용됩니다.
# invoke 실행 시간: 1.5577571392059326 초
# 78 번째 답변 :  제일쿨파프는 1일 1~2회 환부(질환 부위)에 붙이는 것이 권장됩니다.
# invoke 실행 시간: 4.134979248046875 초
# 79 번째 답변 :  제일쿨파프를 사용하기 전에 알아야 할 내용은 다음과 같습니다: 음식을 삼키기 어렵거나 삼킬 때 통증이 있는 경우, 토혈(혈액구토)이나 혈변이 있는 경우, 속쓰림 증상이 3개월 이상 지속되는 경우, 현기증(어지러움) 또는 졸림, 식은땀이 함께 나타나는 경우, 짧은 호흡과 함께 가슴 또는 어깨 통증을 동반하는 경우 등이 있습니다.
# invoke 실행 시간: 7.910034894943237 초
# 80 번째 답변 :  제일쿨파프의 사용상 주의사항은 이 약에 과민증 환자, 심한 증상의 간 및 신기능 장애, 심한 증상의 관상 심장 질환, 잔뇨 형성을 수반하는 배뇨(소변을 눔)장애, 고혈압 및 관상동맥(심장동맥)질환, 임부 또는 임신하고 있을 가능성이 있는 여성, 수유부, 2세 이하의 영아(갓난아기), MAO 억제제를 투여 중인 환자, 갈락토오스 불내성, Lapp 유당분해효소 결핍증 또는 포도당-갈락토오스 흡수장애 등의 유전적인 문제가 있는 환자는 이 약을 복용하지 마십시오. 이 약을 복용하기 전에 12세 미만의 소아, 천식, 녹내장, 심질환, 부정맥, 당뇨병, 갑상샘기능항진증, 전립선비대로 인한 배뇨장애 환자는 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 1.8678817749023438 초
# 81 번째 답변 :  제일쿨파프에 대한 정보가 제공되지 않았기 때문에 해당 제품에 대한 주의해야 할 약 또는 음식에 대한 정보를 제공할 수 없습니다.
# invoke 실행 시간: 4.3720011711120605 초
# 82 번째 답변 :  제일쿨파프를 복용할 때 나타날 수 있는 이상반응은 두드러기, 가려움, 햇빛 노출시 피부 과민반응, 복부ㆍ위통증, 위 경련, 위부불쾌감, 구토, 설사, 구역, 식욕부진, 변비, 흑변, 치아변색, 열, 혼수, 진단 또는 검사 시 AST, ALT의 상승, ALP 상승 등이 있습니다. 이러한 증상이 나타날 경우 즉시 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 3.527663230895996 초
# 83 번째 답변 :  습기와 빛을 피해 상온에서 보관하십시오. 어린이의 손이 닿지 않는 곳에 보관하십시오.
# invoke 실행 시간: 2.7292933464050293 초
# 84 번째 답변 :  지르텍정(세티리진염산염)은 계절성 및 다년성 알레르기성 비염, 알레르기성 결막염, 만성 특발성 두드러기, 피부가려움증과 하이드로코티손 외용제와 병용에 의한 습진, 피부염에 사용됩니다.
# invoke 실행 시간: 3.262228488922119 초
# 85 번째 답변 :  성인 및 6세 이상의 소아는 1일 1회 1정(10 mg)을 취침 전에 복용하고, 이상반응에 민감한 환자의 경우는 1/2정(5 mg)씩을 아침, 저녁에 분할 복용합니다. 연령, 증상에 따라 적절히 증감하며, 신장애 환자의 투여 간격은 환자의 신기능에 따라 조절되어야 합니다.
# invoke 실행 시간: 3.684114933013916 초
# 86 번째 답변 :  세티리진염산염을 사용하기 전에 알아야 할 내용은 효능/효과, 용법/용량, 주의사항, 부작용/이상반응, 보관방법 등이 있습니다.세티리진염산염을 사용하기 전에 의사 또는 약사와 상의하여야 하며, 정확한 용법 및 용량을 준수해야 합니다. 또한 약물에 알레르기 반응이 있는 경우 주의해야 합니다.
# invoke 실행 시간: 3.89601993560791 초
# 87 번째 답변 :  지르텍정(세티리진염산염)의 사용상 주의사항은 이 약 및 히드록시진 또는 피페라진 유도체에 과민증 환자, 신부전 환자, 신장애 환자, 노인, 간질 및 발작 위험성이 있는 환자, 소변고임의 선행요인이 있는 환자, 임부, 수유부는 의사 또는 약사와 상의해야 합니다. 테오필린, 리토나비르와 함께 복용하지 말아야 합니다.
# invoke 실행 시간: 2.761603832244873 초
# 88 번째 답변 :  지르텍정(세티리진염산염)을 사용하는 동안 주의해야 할 약은 에리트로마이신, 세팔렉신, 옥시테트라사이클린, 아목시실린, 세퓨록심, 독시사이클린 등의 항생제와 함께 복용 시 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 3.148801803588867 초
# 89 번째 답변 :  지르텍정(세티리진염산염)을 복용하는 동안 흔히 나타나는 이상반응은 졸음, 두통, 어지러움, 피로감, 건조한 입구, 소화불량 등이 있을 수 있습니다. 그러나 이러한 이상반응이 모두 발생하는 것은 아니며 각 개인의 상황에 따라 다를 수 있습니다.
# invoke 실행 시간: 2.1571712493896484 초
# 90 번째 답변 :  약을 보관할 때는 원래 용기에 보관하고, 빛과 습기를 피해 실온(15-25도)에서 보관해야 합니다. 냉장고에 보관할 필요는 없습니다.
# invoke 실행 시간: 2.9065699577331543 초
# 91 번째 답변 :  케노펜겔(케토프로펜)의 효능은 위부불쾌감, 위부팽만감, 위통, 위산과다, 속쓰림, 신트림, 과식, 체함, 소화불량, 소화촉진, 식욕부진, 구역, 구토에 사용됩니다.
# invoke 실행 시간: 2.4525182247161865 초
# 92 번째 답변 :  케노펜겔(케토프로펜)은 증상에 따라 적당량을 1일 1~4회 환부에 바르고 잘 스며들도록 가볍게 문지르면 됩니다.
# invoke 실행 시간: 3.238213539123535 초
# 93 번째 답변 :  케토프로펜을 사용하기 전에 반드시 알아야 할 내용은 다음과 같습니다: 과민증 환자는 케토프로펜을 사용하지 말아야 합니다. 임부 또는 임신 가능성이 있는 여성, 수유부는 의사 또는 약사와 상의해야 합니다. 정해진 용법과 용량을 잘 지켜야 하며, 증상의 개선이 없을 경우 즉시 의사나 약사와 상의해야 합니다.
# invoke 실행 시간: 6.18376088142395 초
# 94 번째 답변 :  케토프로펜을 사용하기 전에 과민증 환자, 만 12세 미만의 소아, 천식, 비스테로이드성 소염진통제에 과민증이 있는 환자, 흡인성 또는 비흡인성 천식, 아스피린 또는 다른 비스테로이드성 소염진통제에 알레르기 반응을 보인 환자는 사용하지 말아야 합니다. 또한, 소화성궤양, 만성궤양성대장염, 심장ㆍ순환기계기능장애, 신장장애, 저단백혈증, 임부 또는 수유부는 의사 또는 약사와 상의해야 합니다. 사용 중 졸음이나 진정작용이 나타날 수 있으므로 운전 및 기계조작 시 조심해야 합니다.
# invoke 실행 시간: 6.327895164489746 초
# 95 번째 답변 :  케노펜겔(케토프로펜)을 사용하는 동안 주의해야 할 약은 다른 비스테로이드성 소염진통제, 아스피린, 메토트렉세이트, 코르티코스테로이드, 알코올, 디곡신, 페니토인, 프로베네시드, 설핀피라존, 설포닐우레아제, ACE 억제제, 안지오텐신Ⅱ 수용체 길항제 등입니다. 또한, 함께 복용 시 주의해야 할 약으로는 CYP2C8, CYP2C9의 유도제, 항혈소판제, 선택적 세로토닌 재흡수 억제제가 있습니다. 음식에 대한 특별한 언급은 없습니다.
# invoke 실행 시간: 4.249520778656006 초
# 96 번째 답변 :  케노펜겔(케토프로펜) 복용 시 홍반, 피부발진, 가려움, 전신권태, 호흡곤란 등의 알레르기 증상 및 아나필락시스 반응, 식욕부진, 구역ㆍ구토, 부종, 체중감소, 위장관장애, 수면변화, 집중부족, 과잉행동, 과민성, 흥분, 우울증, 혼란, 판단력 장애 등의 중추신경장애가 나타날 수 있습니다. 이러한 증상이 발생할 경우 즉시 복용을 중지하고 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 2.3039448261260986 초
# 97 번째 답변 :  케노펜겔(케토프로펜)은 습기와 빛을 피해 실온에서 보관해야 합니다. 어린이의 손이 닿지 않는 곳에 보관하는 것이 좋습니다.
# invoke 실행 시간: 4.481825828552246 초
# 98 번째 답변 :  케토톱플라스타(케토프로펜)의 효능은 퇴행성관절염(골관절염), 어깨관절주위염, 건·건초염, 건주위염, 상완골상과염(테니스 엘보우 등), 근육통, 외상후의 종창·동통의 진통·소염에 사용됩니다.
# invoke 실행 시간: 3.2984981536865234 초
# 99 번째 답변 :  케토톱플라스타(케토프로펜)은 외용으로 사용되며, 피부에 붙이는 방식으로 사용됩니다. 사용량 및 빈도는 제품에 따라 다를 수 있으므로 제품 안내나 의사의 지시에 따라 사용해야 합니다. 사용 전에 반드시 제품 안내나 의사와 상담하여 올바르게 사용해야 합니다.
# invoke 실행 시간: 2.6122829914093018 초
# 100 번째 답변 :  케토톱플라스타(케토프로펜)을 사용하기 전에 반드시 알아야 할 내용은 제품의 주성분, 사용 방법, 사용상 주의사항, 주의해야 할 약 또는 음식, 그리고 이상반응에 대한 정보입니다.
# invoke 실행 시간: 5.762959003448486 초
# 101 번째 답변 :  케토톱플라스타(케토프로펜)의 사용상 주의사항은 다음과 같습니다: 이 약에 과민증, 아스피린 천식 또는 경험자, 티아프로펜산, 페노피브레이트, 베자피브레이트, 시프로피브레이트, 옥시벤존에 과민증 경험자, 임신기간 6개월 이상인 임부, 15세 미만의 소아, 눈 및 점막, 무좀, 백선 등에는 이 약을 사용하지 마십시오. 이 약을 사용하기 전에 기관지 천식 환자, 임부 또는 수유부는 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 1.9294655323028564 초
# 102 번째 답변 :  케토톱플라스타(케토프로펜)을 사용하는 동안 주의해야 할 약 또는 음식에 대한 정보는 제공된 문서에 포함되어 있지 않습니다.
# invoke 실행 시간: 5.198700189590454 초
# 103 번째 답변 :  케토톱플라스타(케토프로펜) 사용 시 과민증, 아스피린 천식 또는 경험자, 그리고 티아프로펜산, 페노피브레이트, 베자피브레이트, 시프로피브레이트, 옥시벤존에 과민증이 있는 경우 이상반응이 나타날 수 있습니다. 또한, 임신기간 6개월 이상인 임부, 15세 미만의 소아, 눈 및 점막, 무좀, 백선 등에 사용 시 주의가 필요합니다.
# invoke 실행 시간: 2.4939146041870117 초
# 104 번째 답변 :  케토톱플라스타(케토프로펜)를 보관할 때는 습기와 빛을 피해 실온에서 보관해야 합니다. 또한 어린이의 손이 닿지 않는 곳에 보관해야 합니다.
# invoke 실행 시간: 4.466321229934692 초
# 105 번째 답변 :  케펜텍플라스타(케토프로펜)의 효능은 퇴행성관절염(골관절염), 어깨관절주위염, 건(힘줄)ㆍ건초염(힘줄윤활막염), 건(힘줄)주위염, 상완골(위팔뼈)상과염(테니스 엘보우 등), 근육통, 외상(상처)후의 종창(부기)ㆍ동통(통증)의 진통ㆍ소염(항염)에 사용됩니다.
# invoke 실행 시간: 1.7526776790618896 초
# 106 번째 답변 :  케펜텍플라스타(케토프로펜)은 약면의 박리지를 떼어낸 후 환부에 1일 2회 부착합니다.
# invoke 실행 시간: 82.63291049003601 초
# 107 번째 답변 :  케펜텍플라스타(케토프로펜)을 사용하기 전에 반드시 알아야 할 내용은 다음과 같습니다: 이 약에 과민증 환자, 아스피린이나 다른 비스테로이드성 소염진통제에 과민증이 있는 환자, 천식, 코골이, 코막힘, 코피부종, 만성 기침, 비염, 코중견, 코혈, 비강염, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비강통증, 비강부종, 비강건조증, 비강염증, 비
# invoke 실행 시간: 6.787652492523193 초
# 108 번째 답변 :  케펜텍플라스타(케토프로펜)의 사용상 주의사항은 다음과 같습니다: 이 약에 과민증, 광과민증, 아스피린 천식(비스테로이드성 소염진통제 등에 의한 천식)환자 또는 경험자, 티아프로펜산ㆍ페노피브레이트ㆍ베자피브레이트ㆍ시프로피브레이트ㆍ옥시벤존에 과민증, 임신기간 6개월 이상인 임부, 15세 미만의 소아는 이 약을 사용하지 마십시오. 이 약을 사용하기 전에 기관지천식, 임부, 수유부는 의사 또는 약사와 상의하십시오. 광과민증이 나타날 수 있으므로, 이 약을 사용 중이거나 사용 후 2주까지는 자외선을 피하십시오.
# invoke 실행 시간: 7.538731336593628 초
# 109 번째 답변 :  케펜텍플라스타(케토프로펜)을 사용하는 동안 주의해야 할 약 또는 음식은 파라세타몰, 카페인, 이미프라민, 옥사제팜, 펜타조신, 프로프라놀롤, 테오필린, 와파린, 에스트로겐, 리그노카인, 페나세틴, 인슐린, 아드레날린성 길항제(프라조신, 라베탈롤 등), 플레카이니드, 아드레날린성 효능제(이소프레날린, 페닐레프린), 프로폭시펜, 푸로세미드 이뇨제, H2길항제, 베타차단제, 테오필린, 타크린, 클로자핀, 로피니롤과 함께 사용 시 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 5.899869203567505 초
# 110 번째 답변 :  케펜텍플라스타(케토프로펜) 복용 시 홍반, 피부발진, 가려움, 전신권태, 호흡곤란 등의 알레르기 증상 및 아나필락시스 반응, 식욕부진, 구역ㆍ구토, 부종, 체중감소, 위장관장애, 수면변화, 집중부족, 과잉행동, 과민성, 흥분, 우울증, 혼란, 판단력 장애 등의 중추신경장애가 나타날 수 있습니다. 이러한 증상이 발생할 경우 즉시 복용을 중지하고 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 2.3361141681671143 초
# 111 번째 답변 :  케펜텍플라스타(케토프로펜)인 KEFEN은 습기와 빛을 피해 실온에서 보관해야 합니다. 또한 어린이의 손이 닿지 않는 곳에 보관해야 합니다.
# invoke 실행 시간: 1.3455665111541748 초
# 112 번째 답변 :  코솝점안액의 효능에 대한 정보는 제공된 문서 중에 포함되어 있지 않습니다.
# invoke 실행 시간: 1.5168862342834473 초
# 113 번째 답변 :  코솝점안액에 대한 정보가 제공되지 않았습니다. 제가 도와드릴 수 있는 다른 질문이 있으시면 알려주세요.
# invoke 실행 시간: 1.1486194133758545 초
# 114 번째 답변 :  코솝점안액에 대한 정보를 제공받지 못했습니다.
# invoke 실행 시간: 3.7349894046783447 초
# 115 번째 답변 :  코솝점안액에 대한 사용상 주의사항은 다음과 같습니다: 점막 및 손상된 피부에는 사용하지 마십시오. 정해진 용법과 용량을 잘 지키십시오. 어린이에게 투여할 경우 보호자의 지도 감독하에 투여하십시오.
# invoke 실행 시간: 3.036383867263794 초
# 116 번째 답변 :  코솝점안액을 사용하는 동안 주의해야 할 약은 과산화수소와 함께 사용하지 말아야 하며, 리튬제제, 클로르헥시딘, 설파디아진ㆍ은화합물, 알칼리, 수은을 함유한 제제, 효소성분의 상처치료제와 함께 사용 시 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 5.214755535125732 초
# 117 번째 답변 :  코솝점안액을 복용할 때 나타날 수 있는 이상반응에는 쇽 증상(호흡곤란, 전신조홍, 혈관부종, 두드러기), 천식발작, 과민증(홍반, 간지러움, 코막힘, 심장-호흡기 장애, 때때로 발진, 부종, 두드러기, 비염양 증상, 결막염) 등이 포함됩니다. 또한 드물게 독성표피괴사용해(리엘증후군), 피부점막안증후군(스티븐스-존슨증후군)와 같은 심각한 반응도 발생할 수 있습니다. 만약 이러한 증상이 나타나면 즉시 의사나 약사와 상의해야 합니다.
# invoke 실행 시간: 0.9111137390136719 초
# 118 번째 답변 :  코솝점안액은 실온에서 보관하셔야 합니다.
# invoke 실행 시간: 9.635334968566895 초
# 119 번째 답변 :  코앤쿨나잘스프레이의 효능은 코감기(급성비염(코염)), 알레르기성 비염(코염) 또는 부비동염에 의한 코막힘, 콧물, 재채기, 머리무거움의 완화에 사용됩니다.
# invoke 실행 시간: 2.944410562515259 초
# 120 번째 답변 :  코앤쿨나잘스프레이는 1회 사용 시 1~2회 좌우 비강에 분무하며, 1일 3회 사용합니다. 연령 및 증상에 따라 적절히 증감하되 1일 3회를 넘지 않도록 합니다. 매회 최소 8시간 이상의 간격을 두고 적용합니다.
# invoke 실행 시간: 2.1893928050994873 초
# 121 번째 답변 :  코앤쿨나잘스프레이을 사용하기 전에 반드시 알아야 할 내용은 다른 질병이 있는 경우 의사 또는 약사와 상의해야 한다는 것입니다.
# invoke 실행 시간: 3.3290891647338867 초
# 122 번째 답변 :  코앤쿨나잘스프레이의 사용상 주의사항은 다음과 같습니다: 이 약에 과민증 환자는 이 약을 사용하지 마십시오. 이 약은 코에만 사용하고 내복하거나 눈 및 귀에 사용하지 않아야 합니다. 코에 적용하는 다른 제품을 함께 사용할 경우, 30분 이상의 간격을 두며 이 약을 마지막에 사용해야 합니다.
# invoke 실행 시간: 2.587278127670288 초
# 123 번째 답변 :  코앤쿨나잘스프레이를 사용하는 동안 다른 디클로페낙 제제, 비스테로이드 소염제를 함께 사용하지 마십시오. 뉴퀴놀론계 항균제(에녹사신 등)와 함께 사용 시 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 5.511772155761719 초
# 124 번째 답변 :  코앤쿨나잘스프레이의 이상반응으로는 드물게 발진, 가려움, 기관지천식, 후두부종(후두부기), 혈압저하, 기관지경련, 인두부종(인두부기), 호흡곤란 등이 나타날 수 있습니다. 또한, 두통, 졸음, 어지럼, 무력증, 저림, 단기간의 무증상 심실성 빈맥, 여성형유방증, 발한(땀이 남) 등의 이상반응이 있을 수 있습니다. 만약 이러한 증상이 나타나면 즉시 의사나 약사와 상의해야 합니다.
# invoke 실행 시간: 1.67568039894104 초
# 125 번째 답변 :  코앤쿨나잘스프레이는 습기와 빛을 피해 실온에서 보관하고, 어린이의 손이 닿지 않는 곳에 보관해야 합니다.
# invoke 실행 시간: 1.3098833560943604 초
# 126 번째 답변 :  죄송합니다, 그 정보는 제가 가지고 있는 정보에는 포함되어 있지 않습니다.
# invoke 실행 시간: 1.7408175468444824 초
# 127 번째 답변 :  크라비트점안액(레보플록사신 수화물)은 1회 1방울씩, 1일 3회 점안하여 사용합니다.
# invoke 실행 시간: 4.023181438446045 초
# 128 번째 답변 :  크라비트점안액(레보플록사신 수화물)을 사용하기 전에 알아야 할 내용은 다음과 같습니다: 이 약에 과민증 환자, 2개월 이하의 영아는 사용하지 말아야 합니다. 수술기구 소독, 뇌, 척수, 눈, 귀, 점막에 사용하지 말아야 합니다. 또한, 알레르기 체질인 환자, 상처난 피부, 점막, 미성숙 피부의 넓은 부위에 적용 시 의사나 약사와 상의해야 합니다.
# invoke 실행 시간: 1.616931676864624 초
# 129 번째 답변 :  저는 크라비트점안액(레보플록사신 수화물)에 대한 정보를 찾을 수 없습니다.
# invoke 실행 시간: 6.6389381885528564 초
# 130 번째 답변 :  크라비트점안액(레보플록사신 수화물)을 사용하는 동안 주의해야 할 약은 위장진통, 진경제와 함께 복용하지 말아야 합니다. 또한 칼륨함유제제, 감초함유제제, 글리시리진산 혹은 그 염류 함유제제, 루프계 이뇨제, 또는 티아지드계 이뇨제와 함께 복용 시 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 4.450008153915405 초
# 131 번째 답변 :  크라비트점안액(레보플록사신 수화물)을 복용할 때 나타날 수 있는 이상반응은 쇽(호흡곤란, 혈압저하 등), 혈액장애, 소화관 장애, 피부 반응, 시각장애, 청각장애, 두통, 뇌혈관사고, 신장장애, 부종 등이 있습니다. 이러한 증상이 나타날 경우 즉시 의사나 약사와 상의하여야 합니다.
# invoke 실행 시간: 1.1548945903778076 초
# 132 번째 답변 :  크라비트점안액(레보플록사신 수화물)은 실온에서 보관하셔야 합니다.
# invoke 실행 시간: 1.659315586090088 초
# 133 번째 답변 :  죄송합니다. 타겐에프연질캡슐(빌베리건조엑스)에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 1.7655010223388672 초
# 134 번째 답변 :  죄송합니다, 제공된 정보에서 "타겐에프연질캡슐(빌베리건조엑스)"에 대한 정보를 찾을 수 없습니다.
# invoke 실행 시간: 1.488459825515747 초
# 135 번째 답변 :  저는 타겐에프연질캡슐(빌베리건조엑스)에 대한 정보를 찾을 수 없습니다.
# invoke 실행 시간: 1.4978785514831543 초
# 136 번째 답변 :  죄송합니다, 타겐에프연질캡슐(빌베리건조엑스)에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 10.963281393051147 초
# 137 번째 답변 :  타겐에프연질캡슐(빌베리건조엑스)을 사용하는 동안 주의해야 할 약 또는 음식은 다른 비스테로이드성 소염진통제, 아스피린, 메토트렉세이트, 코르티코스테로이드, 알코올, 디곡신, 페니토인, 프로베네시드, 설핀피라존, 설포닐우레아제, ACE 억제제 또는 안지오텐신Ⅱ 수용체 길항제, 이뇨제, 리튬, 쿠마린계 항응고제(와르파린 등), 바클로펜, 면역억제제(시클로스포린, 타크로리무스, 시롤리무스), 혈전용해제, 티클로피딘, 항혈전제, 혈중 칼륨농도를 증가시키는 약물(예: 칼륨 저류형 이뇨제, ACE 억제제, 안지오텐신-Ⅱ 수용체 길항제, 시클로스포린과 타크로리무스와 같은 면역억제제, 트리메토프림, 헤파린 등), CYP2C8, CYP2C9의 유도제(예: 리팜피신, 페노바르비탈), 항혈소판제 및 선택적 세로토닌 재흡수 억제제(SSRI)를 함께 복용하는 경우 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 2.136802911758423 초
# 138 번째 답변 :  저는 타겐에프연질캡슐(빌베리건조엑스)에 대한 정보를 찾을 수 없습니다. 이에 대해 확실한 답변을 드릴 수 없습니다.
# invoke 실행 시간: 1.781360149383545 초
# 139 번째 답변 :  습기와 빛을 피해 실온에서 보관하십시오. 어린이의 손이 닿지 않는 곳에 보관하십시오.
# invoke 실행 시간: 1.4181909561157227 초
# 140 번째 답변 :  죄송합니다, 가네카정에 대한 정보는 제공된 문맥에서 찾을 수 없습니다.
# invoke 실행 시간: 1.4858641624450684 초
# 141 번째 답변 :  제공된 정보에서 "가네카정"에 대한 정보가 없기 때문에 사용 방법에 대한 정보를 제공할 수 없습니다.
# invoke 실행 시간: 1.399421215057373 초
# 142 번째 답변 :  가네카정을 사용하기 전에 반드시 알아야 할 내용은 현재 제공된 정보에는 포함되어 있지 않습니다.
# invoke 실행 시간: 1.1489272117614746 초
# 143 번째 답변 :  죄송합니다, 가네카정에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 4.717930793762207 초
# 144 번째 답변 :  가네카정을 사용하는 동안 주의해야 할 약 또는 음식은 다른 비스테로이드성 소염진통제, 아스피린, 메토트렉세이트, 코르티코스테로이드, 알코올, 디곡신, 페니톤, 프로베네시드, 설핀피라존, 설포닐우레아제, ACE 억제제 또는 안지오텐신Ⅱ 수용체 길항제 등입니다. 또한, CYP2C8, CYP2C9의 유도제를 함께 복용하는 경우 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 4.686443090438843 초
# 145 번째 답변 :  가네카정을 복용할 때 나타날 수 있는 이상반응으로는 아나필락시스 쇽, 두드러기, 혈관신경부종, 발진, 발열, 기관지경련, 저혈압, 흉통, 과립구감소증 등이 있습니다. 또한, 혈청크레아티닌치 상승, 백혈구감소증, 혈소판감소증, 간기능장애, 두통, 피부발진, 다형혼반, 등 다양한 이상반응이 있을 수 있습니다. 만약 이러한 증상이 나타나면 즉시 의사나 약사와 상의해야 합니다.
# invoke 실행 시간: 1.7507069110870361 초
# 146 번째 답변 :  제공된 정보에는 "가네카정"에 대한 내용이 포함되어 있지 않습니다. 따라서 "가네카정"에 대한 보관 방법에 대한 정보는 제공할 수 없습니다.
# invoke 실행 시간: 1.1283752918243408 초
# 147 번째 답변 :  가네탑골드연질캡슐에 대한 정보가 제공되지 않았습니다.
# invoke 실행 시간: 1.9491782188415527 초
# 148 번째 답변 :  가네탑골드연질캡슐에 대한 정보는 제공되지 않았습니다. 해당 제품에 대한 용법 및 용량 정보가 없기 때문에 정확한 사용 방법을 알 수 없습니다.
# invoke 실행 시간: 1.7486743927001953 초
# 149 번째 답변 :  가네탑골드연질캡슐에 대한 정보를 제공받지 못했기 때문에 해당 제품에 대한 내용을 알 수 없습니다.
# invoke 실행 시간: 1.2664942741394043 초
# 150 번째 답변 :  죄송합니다, 가네탑골드연질캡슐에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 3.8457067012786865 초
# 151 번째 답변 :  가네탑골드연질캡슐을 사용하는 동안 주의해야 할 약 또는 음식은 다른 한약(생약)제제, 칼륨함유제제, 감초함유제제, 글리시리진산 또는 그 염류 함유제제, 루프계 이뇨제(푸로세미드, 에타크린산) 또는 티아지드계 이뇨제(트리클로르메티아지드)와 함께 복용 시 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 5.0504491329193115 초
# 152 번째 답변 :  가네탑골드연질캡슐을 복용할 때 나타날 수 있는 이상반응은 적용부위에 화상, 결막염, 눈자극, 눈물흘림 증가, 탈모, 지각과민, 모낭염, 고름물집, 발진, 압통, 여드름, 탈모, 피부건조, 피부장애, 머릿결 이상, 머리카락 색 변화, 모낭염, 미각이상, 두드러기 등이 있습니다. 만약 과민증상이나 자극감이 나타나면 즉시 의사나 약사와 상의해야 합니다.
# invoke 실행 시간: 1.8923215866088867 초
# 153 번째 답변 :  저는 '가네탑골드연질캡슐'에 대한 정보를 찾을 수 없습니다. 해당 제품에 대한 정보가 없기 때문에 보관 방법에 대해 알 수 없습니다.
# invoke 실행 시간: 1.64205002784729 초
# 154 번째 답변 :  가두벌크림은 벌레 물림, 피부가려움, 습진, 두드러기, 피부염, 땀띠, 동창에 사용됩니다.
# invoke 실행 시간: 2.8149681091308594 초
# 155 번째 답변 :  가두벌크림(아모롤핀염산염)은 1일 1회(저녁) 환부에 적당량 바르며, 치료기간은 보통 최소 2~3주간 사용합니다. 사용 전에 반드시 사용법을 숙지하고, 의사나 약사의 지시에 따라 사용해야 합니다.
# invoke 실행 시간: 1.9322726726531982 초
# 156 번째 답변 :  가두벌크림에 대한 정보가 제공되지 않았기 때문에 가두벌크림을 사용하기 전에 반드시 알아야 할 내용에 대한 정보를 제공할 수 없습니다.
# invoke 실행 시간: 1.360490322113037 초
# 157 번째 답변 :  가두벌크림에 대한 정보가 제공되지 않았기 때문에 사용상 주의사항에 대한 정보를 제공할 수 없습니다.
# invoke 실행 시간: 2.540440320968628 초
# 158 번째 답변 :  가두벌크림을 사용하는 동안 다른 디클로페낙 제제, 비스테로이드 소염제를 함께 사용하지 마십시오. 뉴퀴놀론계 항균제(에녹사신 등)와 함께 사용 시 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 7.053582668304443 초
# 159 번째 답변 :  가두벌크림을 사용할 때 나타날 수 있는 이상반응은 전염성농가진, 모낭염, 바이러스성 감염증, 부스럼, 피부자극, 자통, 발열, 작열감, 발진, 발적, 홍조, 가려움, 부종, 구진, 소수포, 피부건조, 농포성피부염, 알레르기성 접촉피부염, 2차감염, 피부거칠어짐, 땀띠, 상처악화, 욕창, 농포증, 안검피부에 사용시 안압 상승, 녹내장 등이 있습니다. 이러한 증상이 나타날 경우 즉시 사용을 중지하고 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 0.7128682136535645 초
# 160 번째 답변 :  실온에서 보관하십시오.
# invoke 실행 시간: 3.2277133464813232 초
# 161 번째 답변 :  겟투겔(케토프로펜)의 효능은 퇴행성관절염(골관절염), 어깨관절주위염, 건ㆍ건초염, 건주위염, 상완골상과염(테니스 엘보우 등), 근육통, 외상후의 종창ㆍ동통의 진통ㆍ소염에 사용됩니다.
# invoke 실행 시간: 1.9291365146636963 초
# 162 번째 답변 :  겟투겔(케토프로펜)은 증상에 따라 적당량을 1일 1~4회 환부에 바르고 잘 스며들도록 가볍게 문지릅니다.
# invoke 실행 시간: 1.691025972366333 초
# 163 번째 답변 :  겟투겔(케토프로펜)을 사용하기 전에 반드시 알아야 할 내용은 현재 제공된 정보에는 포함되어 있지 않습니다.
# invoke 실행 시간: 1.4948322772979736 초
# 164 번째 답변 :  케토프로펜에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 4.03874945640564 초
# 165 번째 답변 :  겟투겔(케토프로펜)을 사용하는 동안 주의해야 할 약은 경구용 항응고제(쿠마린계 약물), 살리실산염, 아스피린, 철분제, 페니토인, 일부 항전간제, 에스트로겐이 포함된 경구용 피임약, 테트라사이클린계 항생제, 플루페나진, 오르리스타트, 바르비탈산 유도체, 코르티코스테로이드제입니다. 또한, 과도한 음주나 흡연을 삼가해야 합니다.
# invoke 실행 시간: 5.364953994750977 초
# 166 번째 답변 :  쇽 증상(호흡곤란, 전신조홍, 혈관부종, 두드러기), 천식발작, 과민증(홍반, 간지러움, 코막힘, 심장-호흡기 장애, 때때로 발진, 부종, 두드러기, 비염양 증상, 결막염) 등의 이상반응이 나타날 수 있습니다. 드물게 독성표피괴사용해(리엘증후군), 피부점막안증후군(스티븐스-존슨증후군), 박탈성피부염, 재생불량성빈혈, 빈혈, 백혈구감소, 혈소판감소 등의 심각한 반응도 있을 수 있습니다.
# invoke 실행 시간: 2.7022182941436768 초
# 167 번째 답변 :  겟투겔(케토프로펜)은 직사광선을 피하고 습기가 없는 서늘한 곳에 보관해야 합니다. 어린이 손이 닿지 않는 곳에 보관하고, 밀봉하여 보관하는 것이 좋습니다. 온도 조건은 제품에 명시된 것을 따라야 합니다.
# invoke 실행 시간: 1.80918550491333 초
# 168 번째 답변 :  제공된 정보에는 "경남아시클로버크림(아시클로버)"에 대한 정보가 포함되어 있지 않습니다. 따라서 해당 제품의 효능에 대한 정보를 제공할 수 없습니다.
# invoke 실행 시간: 1.6473536491394043 초
# 169 번째 답변 :  죄송합니다. 제공된 정보에는 "경남아시클로버크림(아시클로버)" 제품에 대한 정보가 포함되어 있지 않습니다.
# invoke 실행 시간: 4.031481027603149 초
# 170 번째 답변 :  아시클로버크림을 사용하기 전에 알아야 할 내용은 다음과 같습니다: 이 약에 과민증 환자, 눈 또는 눈 주위에는 사용하지 말아야 합니다. 또한 약물 또는 화장품에 의한 알레르기 증상 경험자, 습윤이나 짓무름이 심한 사람, 프로필렌글리콜 과민증 또는 알레르기 반응 경험자는 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 4.340081453323364 초
# 171 번째 답변 :  경남아시클로버크림(아시클로버)의 사용상 주의사항은 다음과 같습니다: 과민증 환자는 사용하지 마십시오. 눈, 눈 주위에는 사용하지 마십시오. 이 약을 사용하기 전에 약물 또는 화장품 등에 의해 알레르기 증상의 병력이 있는 환자, 습윤이나 짓무름이 심한 사람, 프로필렌글리콜에 과민증 환자 또는 경험자는 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 5.675378084182739 초
# 172 번째 답변 :  경남아시클로버크림(아시클로버)을 사용하는 동안 주의해야 할 약은 파라세타몬, 카페인, 이미프라민, 옥사제팜, 펜타조신, 프로프라놀롤, 테오필린, 와파린, 에스트로겐, 리그노카인, 페나세틴, 인슐린, 아드레날린성 길항제(프라조신, 라베탈롤 등), 플레카이니드, 아드레날린성 효능제(이소프레날린, 페닐레프린), 프로폭시펜, 푸로세미드 이뇨제, H2길항제, 베타차단제, 테오필린, 타크린, 클로자핀, 로피니롤과 함께 사용 시 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 4.737839460372925 초
# 173 번째 답변 :  경남아시클로버크림(아시클로버)을 사용할 때 나타날 수 있는 이상반응은 국소자극감, 피부염, 발적(충혈되어 붉어짐), 홍반(붉은 반점), 균열(갈라짐), 인설(비늘), 가려움, 미란(짓무름), 건조, 과민반응 등이 있습니다. 또한, 발진, 작열감(화끈감), 드물게 알레르기 반응도 나타날 수 있습니다. 만약 이러한 증상이 나타나면 즉시 사용을 중지하고 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 2.107330560684204 초
# 174 번째 답변 :  경남아시클로버크림(아시클로버)은 습기와 빛을 피해 실온에서 보관해야 합니다. 또한 어린이의 손이 닿지 않는 곳에 보관해야 합니다.
# invoke 실행 시간: 1.716142177581787 초
# 175 번째 답변 :  제공된 정보에는 "계안겔(수출용)"에 대한 정보가 없습니다. 따라서 해당 제품의 효능에 대해 알 수 없습니다.
# invoke 실행 시간: 1.580312967300415 초
# 176 번째 답변 :  계안겔(수출용)은 1일 수회 환부에 적당량을 적용하여 사용합니다.
# invoke 실행 시간: 1.5018866062164307 초
# 177 번째 답변 :  계안겔(수출용)에 대한 정보가 제공되지 않았기 때문에 해당 제품에 대한 내용을 파악할 수 없습니다.
# invoke 실행 시간: 1.4243674278259277 초
# 178 번째 답변 :  죄송합니다, 제공된 정보에는 "계안겔(수출용)"에 대한 내용이 포함되어 있지 않습니다.
# invoke 실행 시간: 4.771860837936401 초
# 179 번째 답변 :  계안겔(수출용)을 사용하는 동안 주의해야 할 약은 위장진통, 진경제와 함께 복용하지 말아야 합니다. 또한 칼륨함유제제, 감초함유제제, 글리시리진산 혹은 그 염류 함유제제, 루프계 이뇨제 또는 티아지드계 이뇨제와 함께 복용 시 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 3.2166571617126465 초
# 180 번째 답변 :  드물게 아나필락시양 증상(호흡곤란, 조홍, 두드러기 등), 요오드진, 때때로 동통, 가려움, 자극감, 발진, 발적, 피부염, 드물게 작열감, 피부궤양, 접촉피부염, 피부변색이 나타날 수 있습니다. 이러한 경우 사용을 즉시 중지하고 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 1.0208539962768555 초
# 181 번째 답변 :  저는 계안겔(수출용)에 대한 정보를 찾을 수 없습니다.
# invoke 실행 시간: 2.6184942722320557 초
# 182 번째 답변 :  제공된 정보에는 "고려아시클로버크림(아시클로버)" 또는 "바이락스크림(VIRAXCream)" 또는 "이노바이락스5%크림(INNOVIRAX5%Cream)"에 대한 정보가 없습니다. 따라서 해당 제품의 효능에 대한 정보를 제공할 수 없습니다.
# invoke 실행 시간: 2.204261302947998 초
# 183 번째 답변 :  제품명이 "고려아시클로버크림(아시클로버)"가 아닌 다른 제품들의 정보만 제공되었기 때문에 "고려아시클로버크림(아시클로버)"의 사용 방법에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 84.36800265312195 초
# 184 번째 답변 :  고려아시클로버크림(아시클로버)(수출명:바이락스크림(VIRAXCream)이노바이락스5%크림(INNOVIRAX5%Cream)을 사용하기 전에 반드시 알아야 할 내용은 다음과 같습니다: 이 약에 알레르기 체질인 사람, 알레르기 반응 경험자, 눈의 통증이 심한 환자, 눈의 결막염 환자, 눈의 피로, 눈의 가려움, 눈의 붉음, 눈의 붓음, 눈의 누래, 눈의 불편감, 눈의 따가움, 눈의 건조감, 눈의 불쾌감, 눈의 분비물, 눈의 분비물의 증가, 눈의 분비물의 변화, 눈의 분비물의 색깔의 변화, 눈의 분비물의 양의 변화, 눈의 분비물의 특성의 변화, 눈의 분비물의 특성의 변화의 증가, 눈의 분비물의 특성의 변화의 감소, 눈의 분비물의 특성의 변화의 변화, 눈의 분비물의 특성의 변화의 변화의 증가, 눈의 분비물의 특성의 변화의 변화의 감소, 눈의 분비물의 특성의 변화의 변화의 변화, 눈의 분비물의 특성의 변화의 변화의 증가, 눈의 분비물의 특성의 변화의 변화의 감소, 눈의 분비물의 특성의 변화의 변화의 변화, 눈의 분비물의 특성의 변화의 변화의 증가, 눈의 분비물의 특성의 변화의 변화의 감소, 눈의 분비물의 특성의 변화의 변화의 변화, 눈의 분비물의 특성의 변화의 변화의 증가, 눈의 분비물의 특성의 변화의 변화의 감소, 눈의 분비물의 특성의 변화의 변화의 변화, 눈의 분비물의 특성의 변화의 변화의 증가, 눈의 분비물의 특성의 변화의 변화의 감소, 눈의 분비물의 특성의 변화의 변화의 변화, 눈의 분비물의 특성의 변화의 변화의 증가, 눈의 분비물의 특성의 변화의 변화의 감소, 눈의 분비물의 특성의 변화의 변화의 변화, 눈의 분비물의 특성의 변화의 변화의 증가, 눈의 분비물의 특성의 변화의 변화의 감소, 눈의 분비물의 특성의 변화의 변화의 변화, 눈의 분비물의 특성의 변화의 변화의 증가, 눈의 분비물의 특성의 변화의 변화의 감소, 눈의 분비물의 특성의 변화의 변화의 변화, 눈의 분비물의 특성의 변화의 변화의 증가, 눈의 분비물의 특성의 변화의 변화의 감소, 눈의 분비물의 특성의 변화의 변화의 변화, 눈의 분비물의 특성의 변화의 변화의 증가, 눈의 분비물의 특성의 변화의 변화의 감소, 눈의 분비물의 특성의 변화의 변화의 변화, 눈의 분비물의 특성의 변화의 변화의 증가, 눈의 분비물의 특성의 변화의 변화의 감소, 눈의 분비물의 특성의 변화의 변화의 변화, 눈의 분비물의 특성의 변화의 변화의 증가, 눈의 분비물의 특성의 변화의 변화의 감소, 눈의 분비물의 특성의 변화의 변화의 변화, 눈의 분비물의 특성의 변화의 변화의 증가, 눈의 분비물의 특성의 변화의 변화의 감소, 눈의 분비물의 특성의 변화의 변화의 변화, 눈의 분비물의 특성의 변화의 변화의 증가, 눈의 분비물의 특성의 변화의 변화의 감소, 눈의 분비물의 특성의 변화의 변화의 변화, 눈의 분비물의 특성의 변화의 변화의 증가, 눈의 분비물의 특성의 변화의 변화의 감소, 눈의 분비물의 특성의 변화의 변화의 변화, 눈의 분비물의 특성의 변화의 변화의 증가, 눈의 분비물의 특성의 변화의 변화의 감소, 눈의 분비물의 특성의 변화의 변화의 변화, 눈의 분비물의 특성의 변화의 변화의 증가, 눈의 분비물의 특성의 변화의 변화의 감소, 눈의 분비물의 특성의 변화의 변화의 변화, 눈의 분비물의 특성의 변화의 변화의 증가, 눈의 분비물의 특성의 변화의 변화의 감소, 눈의 분비물의 특성의 변화의 변화의 변화, 눈의 분비물의 특성의 변화의 변화의 증가, 눈의 분비물의 특성의 변화의 변화의 감소, 눈의 분비물의 특성의 변화의 변화의 변화, 눈의 분비물의 특성의 변화의 변화의 증가, 눈의 분비물의 특성의 변화의 변화의 감소, 눈의 분비물의 특성의 변화의 변화의 변화, 눈의 분비물의 특성의 변화의 변화의 증가, 눈의 분비물의 특성의 변화의 변화의 감소, 눈의 분비물의 특성의 변화의 변화의 변화, 눈의 분비물의 특성의 변화의 변화의 증가, 눈의 분비물의 특성의 변화의 변화의 감소, 눈의 분비물의 특성의 변화의 변화의 변화, 눈의 분비물의 특성의 변화의 변화의 증가, 눈의 분비물의 특성의 변화의 변화의 감소, 눈의 분비물의 특성의 변화의 변화의 변화, 눈의 분비물의 특성의 변화의 변화의 증가, 눈의 분비물의 특성의 변화의 변화의 감소, 눈의 분비물의 특성의 변화의 변화의 변화, 눈의 분비물의 특성의 변화의 변화의 증가, 눈의 분비물의 특성의 변화의 변화의 감소, 눈의 분비물의 특성의 변화의 변화의 변화, 눈의 분비물의 특성의 변화의 변화의 증가, 눈의 분비물의 특성의 변화의 변화의 감소, 눈의 분비물의 특성의 변화의 변화의 변화, 눈
# invoke 실행 시간: 2.404240131378174 초
# 185 번째 답변 :  점안용으로만 사용하며, 눈에 직접 접촉하지 않도록 합니다. 눈에 들어갈 경우 즉시 물로 헹구고 의사와 상의해야 합니다.어린이의 손이 닿지 않는 곳에 보관해야 합니다.
# invoke 실행 시간: 0.7617056369781494 초
# 186 번째 답변 :  저는 그 정보를 찾을 수 없습니다.
# invoke 실행 시간: 4.431385517120361 초
# 187 번째 답변 :  고려아시클로버크림(아시클로버) 또는 바이락스크림(VIRAXCream)이노바이락스5%크림(INNOVIRAX5%Cream)의 이상반응으로는 피부 발진, 가려움, 부종, 피부의 발적(충혈되어 붉어짐), 눈의 충혈, 눈의 가려움 등이 나타날 수 있습니다. 이러한 증상이 나타나면 즉시 사용을 중지하고 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 2.1186559200286865 초
# 188 번째 답변 :  고려아시클로버크림(아시클로버)은 습기와 빛을 피해 실온에서 보관해야 합니다. 또한 어린이의 손이 닿지 않는 곳에 보관해야 합니다.
# invoke 실행 시간: 2.414543628692627 초
# 189 번째 답변 :  광동동의한방고카타플라스마의 효능은 삠, 타박상, 근육통, 골절통, 관절통, 요통, 어깨결림, 동창(언 상처)의 진통·소염(항염)에 사용됩니다.
# invoke 실행 시간: 1.6917331218719482 초
# 190 번째 답변 :  광동동의한방고카타플라스마는 1일 1~2회, 1회 1매씩 환부(질환 부위)에 붙입니다.
# invoke 실행 시간: 1.9225924015045166 초
# 191 번째 답변 :  저는 '광동동의한방고카타플라스마을'에 대한 정보를 찾을 수 없습니다. 해당 제품에 대한 내용이 없어서 정확한 답변을 제공할 수 없습니다.
# invoke 실행 시간: 1.7324576377868652 초
# 192 번째 답변 :  저는 '광동동의한방고카타플라스마'에 대한 정보를 찾을 수 없습니다. 해당 제품에 대한 정보가 없기 때문에 사용상 주의사항을 알려드릴 수 없습니다.
# invoke 실행 시간: 4.762096166610718 초
# 193 번째 답변 :  광동동의한방고카타플라스마을을 사용하는 동안 주의해야 할 약 또는 음식은 경구용 항응고제(쿠마린계 약물), 살리실산염, 아스피린, 철분제, 페니토인 및 일부 항전간제, 에스트로겐이 포함된 경구용 피임약, 테트라사이클린계 항생제, 플루페나진, 오르리스타트, 바르비탈산 유도체, 코르티코스테로이드제를 복용하는 경우 의사 또는 약사와 상의해야 합니다. 또한, 과도한 음주나 흡연을 삼가해야 합니다.
# invoke 실행 시간: 7.928501605987549 초
# 194 번째 답변 :  광동동의한방고카타플라스마 복용 시 나타날 수 있는 이상반응은 피부점막안증후군(스티븐스-존슨증후군), 독성표피괴사용해(리엘증후군)과 같은 심각한 피부 손상, 열, 가려움, 비염, 기침, 인후염 등의 비특이적 전구증상, 구역, 구강 감각저하, 구토, 설사, 소화불량, 복통, 가슴쓰림, 구강건조, 인후부 건조, 위부불쾌감, 위·복부팽만감, 변비, 식욕부진, 두드러기, 피부 발진, 아나필락시스 반응(아나필락시스 쇼크 포함), 두드러기모양 홍반, 혈관부종, 가려움, 기타 과민반응 등이 있습니다.
# invoke 실행 시간: 1.4024887084960938 초
# 195 번째 답변 :  습기와 빛을 피해 실온에서 보관하십시오. 어린이의 손이 닿지 않는 곳에 보관하십시오.
# invoke 실행 시간: 2.370222568511963 초
# 196 번째 답변 :  광동프라목신크림(프라목신염산염)의 효능은 치질로 인한 불쾌감, 작열감, 가려움의 일시적 완화에 사용됩니다.
# invoke 실행 시간: 1.135045051574707 초
# 197 번째 답변 :  죄송합니다, 그 정보는 제공되지 않았습니다.
# invoke 실행 시간: 3.473024845123291 초
# 198 번째 답변 :  광동프라목신크림(프라목신염산염)을 사용하기 전에 알아야 할 내용은 다음과 같습니다: 약에 과민증 환자는 이 약을 사용하지 말아야 합니다. 12세 이하의 소아, 임부 또는 임신 가능성이 있는 여성은 의사나 약사와 상의해야 합니다. 정해진 용법과 용량을 잘 지켜야 합니다.
# invoke 실행 시간: 4.0762810707092285 초
# 199 번째 답변 :  광동프라목신크림(프라목신염산염)의 사용상 주의사항은 다음과 같습니다: 과민증 환자는 이 약을 사용하지 마십시오. 12세 이하의 소아, 임부 또는 임신하고 있을 가능성이 있는 여성은 의사 또는 약사와 상의하십시오. 정해진 용법과 용량을 잘 지키십시오. 어린이에게 투여할 경우 보호자의 지도 감독하에 투여하십시오. 이 약은 항문 부위에만 사용하고 안과용으로는 사용하지 마십시오.
# invoke 실행 시간: 4.019239187240601 초
# 200 번째 답변 :  광동프라목신크림(프라목신염산염)을 사용하는 동안 주의해야 할 약 또는 음식은 다른 한약(생약)제제, 칼륨함유제제, 감초함유제제, 글리시리진산 또는 그 염류 함유제제, 루프계 이뇨제(푸로세미드, 에타크린산) 또는 티아지드계 이뇨제(트리클로르메티아지드)와 함께 복용 시 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 5.089560031890869 초
# 201 번째 답변 :  프라목신염산염을 함유한 광동프라목신크림의 이상반응으로는 가려움, 발적, 종창, 구진, 소수포, 일시적인 작열감, 때때로 발진, 약한 동통 및 자극 등이 나타날 수 있습니다. 또한, 중증의 다리궤양 환자에 적용시 통증이 나타날 수 있으며, 이러한 경우 사용을 즉각 중지하고 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 1.6840615272521973 초
# 202 번째 답변 :  프라목신크림은 습기와 빛을 피해 실온에서 보관해야 합니다. 또한 어린이의 손이 닿지 않는 곳에 보관하는 것이 좋습니다.
# invoke 실행 시간: 1.9230828285217285 초
# 203 번째 답변 :  죄송합니다. 그 정보는 제공된 문서에 포함되어 있지 않습니다.
# invoke 실행 시간: 2.272087335586548 초
# 204 번째 답변 :  구주로라타딘정10밀리그람(수출명:로히스타정)은 구강에서 사용하는 약으로, 1일 1회 1정을 섭취합니다. 식사와 관계없이 물 없이 구강에서 삼킵니다.
# invoke 실행 시간: 6.771358013153076 초
# 205 번째 답변 :  로히스타정(구주로라타딘정10밀리그람)을 사용하기 전에 알아야 할 내용은 다음과 같습니다: 이 약 또는 다른 H2 수용체 길항제에 과민증 환자, 갈락토오스 불내성, Lapp 유당분해효소 결핍증 또는 포도당-갈락토오스 흡수장애 등의 유전적인 문제가 있는 환자는 이 약을 복용하지 말아야 합니다. 또한, 음식을 삼키기 어렵거나 삼킬 때 통증이 있는 경우, 토혈이나 혈변이 있는 경우, 속쓰림 증상이 3개월 이상 지속되는 경우, 현기증(어지러움) 또는 졸림, 식은땀이 함께 나타나는 경우 등의 증상이 있을 때 의사나 약사와 상의해야 합니다.
# invoke 실행 시간: 7.083303928375244 초
# 206 번째 답변 :  구주로라타딘정10밀리그람(수출명:로히스타정)의 사용상 주의사항은 다음과 같습니다: 이 약에 과민증 환자, 만 6세 미만의 소아, 임부 및 수유부, 갈락토오스 불내성, Lapp 유당분해효소 결핍증 또는 포도당-갈락토오스 흡수장애 등의 유전적인 문제가 있는 환자는 이 약을 복용하지 마십시오. 이 약을 복용하기 전에 간장애, 신부전 환자는 의사 또는 약사와 상의하십시오. 이 약을 복용하는 동안 시메티딘, 에리트로마이신, 케토코나졸, 퀴니딘, 플루코나졸, 플루옥세틴, 간 대사를 억제하는 약물을 함께 복용하지 마십시오.
# invoke 실행 시간: 2.761070489883423 초
# 207 번째 답변 :  구주로라타딘정을 사용하는 동안 시메티딘, 에리트로마이신, 케토코나졸, 퀴니딘, 플루코나졸, 플루옥세틴, 간 대사를 억제하는 약물을 함께 복용하지 말아야 합니다.
# invoke 실행 시간: 1.0286047458648682 초
# 208 번째 답변 :  죄송합니다, 그에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 1.021846055984497 초
# 209 번째 답변 :  저는 그 정보를 찾을 수 없습니다.
# invoke 실행 시간: 1.4014737606048584 초
# 210 번째 답변 :  죄송합니다. 국제아시클로버크림에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 1.5681297779083252 초
# 211 번째 답변 :  죄송합니다, 국제아시클로버크림에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 4.365178823471069 초
# 212 번째 답변 :  국제아시클로버크림을 사용하기 전에 반드시 알아야 할 내용은 다음과 같습니다: 이 약에 과민증 환자, 눈 또는 눈 주위에는 이 약을 사용하지 마십시오. 이 약을 사용하기 전에 약물 또는 화장품에 의한 알레르기 환자 또는 경험자, 습윤이나 짓무름이 심한 사람은 의사 또는 약사와 상의하십시오. 국제아시클로버크림은 외용으로만 사용해야 하며, 정해진 용법과 용량을 잘 지켜야 합니다.
# invoke 실행 시간: 4.365031719207764 초
# 213 번째 답변 :  국제아시클로버크림의 사용상 주의사항은 다음과 같습니다: 과민증 환자, 눈 또는 눈 주위에는 이 약을 사용하지 마십시오. 이 약을 사용하기 전에 약 또는 화장품에 알레르기 증상 경험자, 습윤이나 짓무름이 심한 환자는 의사 또는 약사와 상의하십시오. 여드름, 뾰루지가 있는 부분에만 사용하고 주변의 넓은 부분이나 눈 주위, 깊은 상처와 심한 화상에는 사용하지 마십시오.
# invoke 실행 시간: 2.773210048675537 초
# 214 번째 답변 :  국제아시클로버크림을 사용하는 동안 다른 디클로페낙 제제, 비스테로이드 소염제를 함께 사용하지 마십시오. 뉴퀴놀론계 항균제(에녹사신 등)와 함께 사용 시 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 3.3101706504821777 초
# 215 번째 답변 :  국제아시클로버크림을 사용할 때 압통, 작열감, 자통을 포함한 동통, 피부염, 홍반성 발진, 습진, 알레르기 반응, 자극감, 가려움, 외음염, 안면 부종, 피부 탈색, 두드러기, 발진, 소수포성 발진, 피부 벗겨짐 등의 이상반응이 나타날 수 있습니다.
# invoke 실행 시간: 1.6778366565704346 초
# 216 번째 답변 :  국제아시클로버크림은 습기와 빛을 피해 실온에서 보관하고 어린이의 손이 닿지 않는 곳에 보관해야 합니다.
# invoke 실행 시간: 1.5449085235595703 초
# 217 번째 답변 :  죄송합니다, 제공된 정보에는 "그날엔노즈플러스연질캡슐"에 대한 내용이 포함되어 있지 않습니다.
# invoke 실행 시간: 1.5542988777160645 초
# 218 번째 답변 :  죄송합니다, 그날엔노즈플러스연질캡슐에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 1.9401836395263672 초
# 219 번째 답변 :  그날엔노즈플러스연질캡슐에 대한 정보가 없기 때문에 해당 제품에 대한 사용 전 반드시 알아야 할 내용을 알 수 없습니다.
# invoke 실행 시간: 1.5385005474090576 초
# 220 번째 답변 :  죄송합니다, 그날엔노즈플러스연질캡슐에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 1.2052757740020752 초
# 221 번째 답변 :  정주용 지질제와 함께 사용 시 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 4.245906829833984 초
# 222 번째 답변 :  그날엔노즈플러스연질캡슐에 대한 이상반응으로는 과민증, 만 12개월 미만의 젖먹이, 윌슨병, 심한 심부전 환자, 대두유 과민증 또는 알레르기 반응 경험자, 콩 또는 땅콩 과민증 환자가 있습니다. 따라서 이러한 환자들은 그날엔노즈플러스연질캡슐을 복용하지 말아야 합니다.
# invoke 실행 시간: 1.456876516342163 초
# 223 번째 답변 :  저는 그날엔노즈플러스연질캡슐에 대한 정보를 찾을 수 없습니다.
# invoke 실행 시간: 1.838158369064331 초
# 224 번째 답변 :  그날엔정의 효능은 봄철 각막염이나 결막염, 알레르기성 결막염에 사용됩니다.
# invoke 실행 시간: 2.7298972606658936 초
# 225 번째 답변 :  죄송합니다, 그날엔정에 대한 정보가 제공된 문맥에서는 찾을 수 없습니다.
# invoke 실행 시간: 3.2964022159576416 초
# 226 번째 답변 :  그날엔정을 사용하기 전에 반드시 알아야 할 내용은 이 약에 과민증 환자는 이 약을 복용하지 말아야 하며, 황색5호에 과민증 환자, 임부 및 수유부는 의사 또는 약사와 상의해야 합니다. 또한, 정해진 용법과 용량을 잘 지켜야 합니다.
# invoke 실행 시간: 2.1044673919677734 초
# 227 번째 답변 :  그날엔정의 사용으로 인해 발진·발적, 종창, 가려움, 통증, 부종 등의 증상이 나타날 수 있으니 사용을 즉각 중지하고 의사 또는 약사와 상의해아 합니다.
# invoke 실행 시간: 1.1695282459259033 초
# 228 번째 답변 :  정주용 지질제와 함께 사용 시 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 4.755616188049316 초
# 229 번째 답변 :  그날엔정을 사용할 때 나타날 수 있는 이상반응으로는 홍반(붉은 반점), 작열감(화끈감), 수포, 피부 발진, 두통, 어지러움, 고혈압, 가슴 통증, 호흡곤란, 복통, 구토, 변비, 두드러기, 발진, 가려움증, 근육통, 관절통 등이 있습니다. 만약 이러한 증상이 나타나면 즉시 사용을 중지하고 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 1.4349474906921387 초
# 230 번째 답변 :  빛을 피해 상온(15~25 ℃)에서 보관하십시오. 어린이의 손이 닿지 않는 곳에 보관하십시오.
# invoke 실행 시간: 1.4801204204559326 초
# 231 번째 답변 :  죄송합니다, 그날엔코프플러스연질캡슐에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 1.534632682800293 초
# 232 번째 답변 :  죄송합니다, 그날엔코프플러스연질캡슐에 대한 정보가 제공되지 않았습니다.
# invoke 실행 시간: 2.053529977798462 초
# 233 번째 답변 :  제공된 정보에는 "그날엔코프플러스연질캡슐"에 대한 내용이 포함되어 있지 않습니다. 따라서, 해당 제품에 대한 정보를 제공할 수 없습니다.
# invoke 실행 시간: 1.5994582176208496 초
# 234 번째 답변 :  죄송합니다, 그날엔코프플러스연질캡슐에 대한 정보가 제공되지 않았습니다.
# invoke 실행 시간: 1.0504322052001953 초
# 235 번째 답변 :  정주용 지질제와 함께 사용 시 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 3.2606773376464844 초
# 236 번째 답변 :  피부의 세균성 감염증, 안검피부에 사용 시 안압 상승, 녹내장 등의 이상반응이 나타날 수 있습니다. 또한 작열감, 피부자극, 발진, 알레르기성 접촉피부염 등이 발생할 수 있으며, 부종이 나타나면 즉시 사용을 중지하고 의사와 상의해야 합니다.
# invoke 실행 시간: 0.9051835536956787 초
# 237 번째 답변 :  실온에서 보관하십시오.
# invoke 실행 시간: 4.45341944694519 초
# 238 번째 답변 :  콜드플러스연질캡슐은 육체피로, 임신ㆍ수유기, 병중ㆍ병후의 체력 저하 시, 노년기의 비타민 E, B1, B2, B6의 보급과 말초혈행장애 및 갱년기시 어깨ㆍ목결림, 수족저림ㆍ수족냉증, 신경통, 근육통, 관절통, 구각염, 구순염, 구내염, 설염, 습진, 피부염 증상의 완화, 각기, 눈의 피로에 사용됩니다.
# invoke 실행 시간: 1.431544542312622 초
# 239 번째 답변 :  죄송합니다, 제공된 정보에는 "그날엔콜드플러스연질캡슐"에 대한 정보가 포함되어 있지 않습니다.
# invoke 실행 시간: 2.275137186050415 초
# 240 번째 답변 :  제공된 정보에는 "그날엔콜드플러스연질캡슐"에 대한 내용이 포함되어 있지 않습니다. 따라서, 해당 제품에 대한 정보를 제공할 수 없습니다.
# invoke 실행 시간: 1.6984426975250244 초
# 241 번째 답변 :  죄송합니다, 그날엔콜드플러스연질캡슐에 대한 정보가 제공된 문서 중에는 없습니다.
# invoke 실행 시간: 3.9935462474823 초
# 242 번째 답변 :  그날엔콜드플러스연질캡슐을 사용하는 동안 주의해야 할 약 또는 음식은 아세트아미노펜을 포함하는 다른 제품, 다른 소염진통제, 다른 해열진통제와 함께 사용하지 마십시오. 이 약을 사용하기 전에 바르비탈계 약물, 삼환계 항우울제, 알코올을 투여한 환자, 리튬, 티아지드계 이뇨제, 레보도파와 함께 사용 시 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 1.633575201034546 초
# 243 번째 답변 :  구역, 변비 또는 설사, 드물게 위산의 반동성 분비, 가려움증 등이 나타날 수 있습니다.
# invoke 실행 시간: 1.2760124206542969 초
# 244 번째 답변 :  저는 그날엔콜드플러스연질캡슐에 대한 정보를 찾을 수 없습니다.
# invoke 실행 시간: 3.4088213443756104 초
# 245 번째 답변 :  그린록시겔(피록시캄)의 효능은 퇴행성관절염(골관절염), 어깨관절주위염, 건ㆍ건초염, 건주위염, 상완골상과염(테니스 엘보우 등), 근육통(근염, 근막염 등), 외상후의 종창ㆍ동통의 진통ㆍ소염에 사용됩니다.
# invoke 실행 시간: 1.8925769329071045 초
# 246 번째 답변 :  그린록시겔(피록시캄)은 성인 1일 3~4회, 1회 약 3 cm(1 g)를 환부에 얇게 바르고 잘 스며들도록 가볍게 문지릅니다.
# invoke 실행 시간: 1.6841297149658203 초
# 247 번째 답변 :  그린록시겔(피록시캄)을 사용하기 전에 반드시 알아야 할 내용은 제공된 정보에는 포함되어 있지 않습니다.
# invoke 실행 시간: 1.857208013534546 초
# 248 번째 답변 :  제공된 정보에는 "그린록시겔(피록시캄)"에 대한 내용이 없기 때문에 해당 제품의 사용상 주의사항에 대한 정보를 제공할 수 없습니다.
# invoke 실행 시간: 5.86824369430542 초
# 249 번째 답변 :  그린록시겔(피록시캄)을 사용하는 동안 주의해야 할 약 또는 음식은 파라세타몰, 카페인, 이미프라민, 옥사제팜, 펜타조신, 프로프라놀롤, 테오필린, 와파린, 에스트로겐, 리그노카인, 페나세틴, 인슐린, 아드레날린성 길항제(프라조신, 라베탈롤 등), 플레카이니드, 아드레날린성 효능제(이소프레날린, 페닐레프린), 프로폭시펜, 푸로세미드 이뇨제, H2길항제, 베타차단제, 테오필린, 타크린, 클로자핀, 로피니롤과 함께 사용 시 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 2.9414167404174805 초
# 250 번째 답변 :  가려움, 발적, 발진, 인설, 습진ㆍ피부염, 접촉피부염, 홍반, 드물게 광과민증 등의 이상반응이 나타날 수 있습니다. 이러한 증상이 나타나면 즉시 사용을 중지하고 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 1.2848339080810547 초
# 251 번째 답변 :  그린록시겔(피록시캄)은 실온에서 보관해야 합니다.
# invoke 실행 시간: 1.7961361408233643 초
# 252 번째 답변 :  그린코플시럽(딸기향, 바나나향)의 효능은 기침, 가래, 콧물, 코막힘, 재채기에 사용됩니다.
# invoke 실행 시간: 1.616365909576416 초
# 253 번째 답변 :  죄송합니다, 그린코플시럽(딸기향, 바나나향)에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 1.6766886711120605 초
# 254 번째 답변 :  그린코플시럽(딸기향, 바나나향)을 사용하기 전에 반드시 알아야 할 내용은 제공된 정보에는 없습니다.
# invoke 실행 시간: 3.618422269821167 초
# 255 번째 답변 :  그린코플시럽(딸기향, 바나나향)을 사용하는 동안 주의해야 할 약은 인산염, 칼슘염, 경구용 테트라사이클린계 제제, 제산제, 레보도파와 함께 복용하지 말아야 합니다. 또한, 강심배당체, 항알도스테론제, 트리암테렌과 함께 복용 시 의사 또는 약사와 상의해야 합니다. 탄닌을 함유하는 차는 복용 중, 복용 전후에 피해야 합니다.
# invoke 실행 시간: 4.162024736404419 초
# 256 번째 답변 :  그린코플시럽(딸기향, 바나나향)을 사용하는 동안 주의해야 할 약 또는 음식은 인산염, 칼슘염, 경구용 테트라사이클린계 제제, 제산제, 레보도파와 함께 복용하지 마십시오. 또한, 강심배당체, 항알도스테론제, 트리암테렌과 함께 복용 시 의사 또는 약사와 상의하십시오. 녹차, 홍차 등 탄닌을 함유하는 차는 복용 중, 복용 전후에는 피하십시오.
# invoke 실행 시간: 6.811821222305298 초
# 257 번째 답변 :  그린코플시럽(딸기향, 바나나향)을 복용할 때 나타날 수 있는 이상반응은 구역, 구토, 복부(배부분)팽만감, 위장관출혈, 가슴쓰림, 때때로 식욕부진, 위부불쾌감, 설사, 구갈(목마름), 민감한 환자에서 구내염(입안염), 발진, 홍반(붉은 반점), 습진 등이 있습니다. 또한, 드물게 두통, 민감한 환자에서 비염(코염), 때때로 가려움, 심계항진(두근거림), 콧물, 전신의 압박감, 피부점막안증후군(스티븐스-존슨증후군), 독성표피괴사용해(리엘증후군), 간기능장애, 황달, 쇼크 등이 나타날 수 있습니다.
# invoke 실행 시간: 2.0902998447418213 초
# 258 번째 답변 :  그린코플시럽(딸기향, 바나나향)은 직사광선을 피하고 습기가 없는 서늘한 곳에 보관해야 합니다. 냉장보관이 필요하지는 않습니다.
# invoke 실행 시간: 1.7311890125274658 초
# 259 번째 답변 :  제공된 정보에는 "그린콜샷리퀴드연질캡슐"에 대한 정보가 포함되어 있지 않습니다. 따라서 해당 제품의 효능에 대해 알 수 없습니다.
# invoke 실행 시간: 1.580190896987915 초
# 260 번째 답변 :  죄송합니다, 그린콜샷리퀴드연질캡슐에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 1.7485079765319824 초
# 261 번째 답변 :  그린콜샷리퀴드연질캡슐에 대한 정보가 제공되지 않았기 때문에 해당 제품에 대한 내용을 알 수 없습니다.
# invoke 실행 시간: 1.6083908081054688 초
# 262 번째 답변 :  그린콜샷리퀴드연질캡슐에 대한 사용상 주의사항은 제공된 정보에는 없습니다.
# invoke 실행 시간: 4.07196569442749 초
# 263 번째 답변 :  그린콜샷리퀴드연질캡슐을 사용하는 동안 주의해야 할 약 또는 음식은 다른 한약(생약)제제, 칼륨함유제제, 감초함유제제, 글리시리진산 또는 그 염류 함유제제, 루프계 이뇨제(푸로세미드, 에타크린산) 또는 티아지드계 이뇨제(트리클로르메티아지드)와 함께 복용 시 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 5.944082260131836 초
# 264 번째 답변 :  피부점막안증후군(스티븐스-존슨증후군), 독성표피괴사용해(리엘증후군) 같은 심각한 피부 손상, 열, 가려움, 비염, 기침 및 인후염과 같은 비특이적 인플루엔자-유사 전구증상 등의 이상반응이 나타날 수 있습니다. 또한 구역, 구토, 설사, 소화불량, 복통, 가슴쓰림, 두드러기, 피부 발진, 아나필락시스 반응, 혈관부종, 가려움, 호흡곤란, 체온상승 등의 증상이 나타날 수 있습니다. 만약 이러한 증상이 나타나면 즉시 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 1.0784809589385986 초
# 265 번째 답변 :  저장 조건에 대한 정보가 제공되지 않았습니다.
# invoke 실행 시간: 1.1193666458129883 초
# 266 번째 답변 :  죄송합니다, 그 정보는 제공되지 않았습니다.
# invoke 실행 시간: 3.6516566276550293 초
# 267 번째 답변 :  죄송합니다, 국제아스피린장용정100mg에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 1.3458514213562012 초
# 268 번째 답변 :  국제아스피린장용정100mg에 대한 정보가 제공되지 않았습니다.
# invoke 실행 시간: 1.3073039054870605 초
# 269 번째 답변 :  죄송합니다, 국제아스피린장용정100mg에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 4.392545700073242 초
# 270 번째 답변 :  국제아스피린장용정100mg을 사용하는 동안 주의해야 할 약 또는 음식은 인산염, 칼슘염, 경구용 테트라사이클린계 제제, 제산제, 레보도파와 함께 복용하지 말아야 합니다. 또한 에스트로겐을 포함한 경구용 피임제, 항알도스테론제, 트리암테렌, 정주용 지질제와 함께 사용 시 의사 또는 약사와 상의해야 합니다. 녹차, 홍차 등 탄닌을 함유하는 차는 복용 중, 복용 전후에 피해야 합니다.
# invoke 실행 시간: 4.67033839225769 초
# 271 번째 답변 :  국제아스피린장용정100mg의 이상반응으로는 아나필락시스 쇽, 두드러기, 혈관신경부종, 발진, 발열, 기관지경련, 저혈압, 흉통 등이 나타날 수 있습니다. 또한 과립구감소증, 혈소판감소증, 간기능장애, 혈소판감소증, 두통, 피부발진, 설염, 피부가려움 등의 이상반응이 있을 수 있습니다. 만약 이러한 증상이 나타나면 즉시 의사나 약사와 상의해야 합니다.
# invoke 실행 시간: 1.2499916553497314 초
# 272 번째 답변 :  실온에서 보관하고 어린이의 손이 닿지 않는 곳에 보관해야 합니다.
# invoke 실행 시간: 1.4972665309906006 초
# 273 번째 답변 :  제공된 정보에는 "광동아스피린장용정100mg"에 대한 정보가 없습니다. 따라서 해당 제품의 효능에 대해 알 수 없습니다.
# ...
# invoke 실행 시간: 1.3571503162384033 초
# 593 번째 답변 :  저는 솔루펜연질캡슐(덱시부프로펜)에 대한 정보를 찾을 수 없습니다.
# invoke 실행 시간: 0.9708106517791748 초
# 594 번째 답변 :  저는 그 정보를 찾을 수 없습니다.
# invoke 실행 시간: 1.1689414978027344 초
# 595 번째 답변 :  죄송합니다, 수프리정에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 1.2324860095977783 초
# 596 번째 답변 :  죄송합니다, 수프리정에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 1.9950504302978516 초
# 597 번째 답변 :  수프리정을 사용하기 전에 반드시 알아야 할 내용은 만 6세 이하의 어린이가 과량 복용시 철분 중독성 사망을 일으킬 수 있으므로 어린이의 손에 닿지 않는 곳에 보관해야 한다는 것입니다.
# invoke 실행 시간: 1.2372727394104004 초
# 598 번째 답변 :  죄송합니다. 수프리정에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 3.0434274673461914 초
# 599 번째 답변 :  수프리정을 사용하는 동안 주의해야 할 약은 과산화수소와 함께 사용하지 말아야 하며, 리튬제제, 클로르헥시딘, 설파디아진ㆍ은화합물, 알칼리, 수은을 함유한 제제, 효소성분의 상처치료제와 함께 사용 시 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 5.418558359146118 초
# 600 번째 답변 :  수프리정을 복용할 때 나타날 수 있는 이상반응으로는 혈소판감소증, 무과립구증, 청색증, 백혈구감소증, 과립구감소, 용혈성빈혈, 메트헤모글로빈혈증, 혈소판기능저하, 홍조, 피부 반응, 땀분비이상, 가려움증, 피부건조, 두드러기, 쇼크, 호흡곤란, 과민증, 혈관 부종, 발진, 부종, 가슴답답함, 손발이 차가움, 숨가쁨, 화상모양물집, 알레르기 반응 등이 있습니다.
# invoke 실행 시간: 0.7640063762664795 초
# 601 번째 답변 :  실온에서 보관하십시오.
# invoke 실행 시간: 2.9623377323150635 초
# 602 번째 답변 :  순갈근탕에이액의 효능은 식욕감퇴(식욕부진), 위부팽만감, 소화불량, 과식, 체함, 구역, 구토에 사용됩니다.
# invoke 실행 시간: 2.3734934329986572 초
# 603 번째 답변 :  순갈근탕에이액에 대한 정보가 제공된 문서에서는 순갈근탕에이액에 대한 정보가 제공되지 않았습니다. 따라서 순갈근탕에이액의 사용 방법에 대한 정보는 제공할 수 없습니다.
# invoke 실행 시간: 4.536536455154419 초
# 604 번째 답변 :  순갈근탕에이액에 대한 정보가 제공되지 않았기 때문에 해당 제품에 대한 내용을 알 수 없습니다.
# invoke 실행 시간: 1.7520170211791992 초
# 605 번째 답변 :  "순갈근탕에이액"에 대한 정보가 제공되지 않았기 때문에 해당 제품의 사용상 주의사항에 대해 알 수 없습니다.
# invoke 실행 시간: 4.38827109336853 초
# 606 번째 답변 :  순갈근탕에이액을 사용하는 동안 주의해야 할 약 또는 음식은 다른 한약(생약)제제, 칼륨함유제제, 감초함유제제, 글리시리진산 또는 그 염류 함유제제, 루프계 이뇨제(푸로세미드, 에타크린산) 또는 티아지드계 이뇨제(트리클로르메티아지드)와 함께 복용 시 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 3.1243412494659424 초
# 607 번째 답변 :  순갈근탕에이액을 복용할 때 나타날 수 있는 이상반응에는 혈액장애, 소화관 이상, 피부 이상, 시각 이상, 청각 이상, 중추신경계 이상, 순환기계 이상, 신장 이상 등이 포함됩니다. 이러한 이상반응이 나타나면 즉시 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 1.3903121948242188 초
# 608 번째 답변 :  순갈근탕에이액에 대한 정보가 제공되지 않았습니다.
# invoke 실행 시간: 1.9382848739624023 초
# 609 번째 답변 :  순앤로션2.5%(히드로코르티손)의 효능은 습진ㆍ피부염군, 피부가려움, 벌레물린데에 사용됩니다.
# invoke 실행 시간: 1.6948814392089844 초
# 610 번째 답변 :  순앤로션2.5%(히드로코르티손)의 사용법에 대한 정보를 찾을 수 없습니다.
# invoke 실행 시간: 7.179946660995483 초
# 611 번째 답변 :  순앤로션2.5%(히드로코르티손)을 사용하기 전에 알아야 할 내용은 다음과 같습니다: 이 약에 과민증 환자, 피부감염증(결핵, 매독, 칸디다증, 백선, 대상포진, 단순포진, 수두, 종두증, 옴, 사면발이) 등의 환자는 사용하지 말아야 합니다. 또한, 고막 천공이 있는 습진성 외이도염, 궤양(베체트병 제외), 제2도 심재성 이상의 화상 및 동상, 입주위피부염, 보통여드름, 주사 환자, 비염증성 가려움 환자도 사용하지 말아야 합니다. 임부 또는 임신 가능성이 있는 여성, 수유부, 유ㆍ소아(특히 2세 미만), 고령자는 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 7.269485235214233 초
# 612 번째 답변 :  순앤로션2.5%(히드로코르티손)의 사용상 주의사항은 다음과 같습니다: 과민증 환자, 피부감염증(결핵, 매독, 칸디다증, 백선, 대상포진, 단순포진, 수두, 종두증, 옴, 사면발이), 고막 천공이 있는 습진성 외이도염, 궤양(베체트병 제외), 제2도 심재성 이상의 화상 및 동상, 입주위피부염, 보통여드름, 주사 환자, 비염증성 가려움 환자는 이 약을 사용하지 마십시오. 또한, 임부 또는 임신 가능성이 있는 여성, 수유부, 유ㆍ소아(특히 2세 미만), 고령자는 의사 또는 약사와 상의해야 합니다. 안과용으로 사용하거나 화장이나 면도 후 등 치료 이외의 목적으로 사용하지 않아야 합니다.
# invoke 실행 시간: 5.906095266342163 초
# 613 번째 답변 :  파라세타몰, 카페인, 이미프라민, 옥사제팜, 펜타조신, 프로프라놀롤, 테오필린, 와파린, 에스트로겐, 리그노카인, 페나세틴, 인슐린, 아드레날린성 길항제(프라조신, 라베탈롤 등), 플레카이니드, 아드레날린성 효능제(이소프레날린, 페닐레프린), 프로폭시펜, 푸로세미드 이뇨제, H2길항제, 베타차단제, 테오필린, 타크린, 클로자핀, 로피니롤과 함께 사용 시 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 14.926003456115723 초
# 614 번째 답변 :  순앤로션2.5%(히드로코르티손)의 이상반응으로는 쇽(쇼크), 아나필락시양 반응(과민성유사 반응), 흉내고민(가슴쓰림), 오한, 호흡곤란, 혈압저하, 헤마토크리트 감소, 헤모글로빈 감소, 빈혈, 재생불량성빈혈, 용혈성빈혈, 무과립구증, 과립구감소, 백혈구감소, 혈소판감소, 혈소판 기능 저하, 소화성궤양, 위장관궤양, 위장출혈, 천공(뚫림), 궤양성 대장염, 혈변, 위염, 췌장염, 토혈(혈액구토), 크론병, 식욕부진, 구역, 구토, 복통, 소화불량, 설사, 위부불쾌감, 상복부 통증, 구갈, 구내염, 복부팽만감, 구강궤양, 변비, 흑변, 스티븐스-존슨증후군, 중독성표피괴사증, 빈도불명의 호산구 증가 및 전신 증후군을 동반한 약물 발진, 혈관신경성 부종, 수포성피부염, 다형 홍반, 반구진 발진, 피부 붉어짐, 수포(물집), 발진, 간염, 황달, 간기능이상, 간장애, 과민증 또는 아나필락시스 반응, 천식발작, 두드러기, 습진, 자주색반점, 발진, 가려움증, 시각장애, 귀먹음, 귀울림, 미각이상, 현기증, 졸음, 어지러움, 우울, 두통, 뇌혈관사고 또는 신경질, 무균성수막염 또는 수막염 등이 있습니다.
# invoke 실행 시간: 1.5361130237579346 초
# 615 번째 답변 :  저는 순앤로션2.5%(히드로코르티손)에 대한 정보를 찾을 수 없습니다.
# invoke 실행 시간: 3.0527689456939697 초
# 616 번째 답변 :  쉐러콜에스연질캡슐의 효능은 위산과다, 속쓰림, 위부불쾌감, 위부팽만감, 식체(위체), 구역, 구토, 위통, 신트림, 소화불량, 식욕감퇴(식욕부진), 과식, 소화촉진으로 인한 위부팽만감에 사용됩니다.
# invoke 실행 시간: 2.015979051589966 초
# 617 번째 답변 :  쉐러콜에스연질캡슐에 대한 정보는 제공된 문맥에서 찾을 수 없습니다. 해당 제품에 대한 정보가 없기 때문에 사용 방법에 대해 알 수 없습니다.
# invoke 실행 시간: 1.7499675750732422 초
# 618 번째 답변 :  쉐러콜에스연질캡슐에 대한 정보가 제공되지 않았기 때문에 해당 제품에 대한 내용을 알 수 없습니다.
# invoke 실행 시간: 7.884022235870361 초
# 619 번째 답변 :  쉐러콜에스연질캡슐에 대한 사용상 주의사항은 다음과 같습니다: 이 약에 과민증 환자, 만 12개월 미만의 영아, 혈색소증, 헤모시데린 침착증, 철 이용 장애, 비철결핍성 빈혈, 골수 부족에 의한 빈혈, 만성 용혈성빈혈, 철 과잉증, 감염이나 종양으로 인한 철 결핍성 빈혈, 만성 췌장염, 간경변, 갈락토오스불내성, Lapp 유당분해효소결핍증 또는 포도당-갈락토오스 흡수장애 등의 유전적인 문제가 있는 환자는 이 약을 복용하지 마십시오. 이 약을 복용하기 전에 소화성궤양, 만성궤양성대장염, 국한성대장염 등의 위장질환 환자, 심장ㆍ순환기계기능장애, 발작성 야간 혈색소뇨증, 신장애, 저단백혈증 환자는 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 2.7994117736816406 초
# 620 번째 답변 :  쉐러콜에스연질캡슐을 사용하는 동안 다른 디클로페낙 제제, 비스테로이드 소염제를 함께 사용하지 마십시오. 뉴퀴놀론계 항균제(에녹사신 등)와 함께 사용 시 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 5.514995098114014 초
# 621 번째 답변 :  쉐러콜에스연질캡슐 복용 시 나타날 수 있는 이상반응은 피부점막안증후군(스티븐스-존슨증후군), 독성표피괴사용해(리엘증후군)과 같은 심각한 피부 손상, 열, 가려움, 비염, 기침, 인후염 등의 비특이적 인플루엔자-유사 전구증상이 포함됩니다. 또한 구역, 구토, 설사, 소화불량, 두드러기, 피부 발진, 호흡곤란, 체온상승 등 다양한 증상이 나타날 수 있습니다. 만약 이러한 증상이 나타나면 즉시 의사나 약사와 상의해야 합니다.
# invoke 실행 시간: 1.593855619430542 초
# 622 번째 답변 :  습기와 빛을 피해 실온에서 보관하십시오. 어린이의 손이 닿지 않는 곳에 보관하십시오.
# invoke 실행 시간: 1.5521705150604248 초
# 623 번째 답변 :  제공된 정보에는 "슈가린정"에 대한 정보가 없습니다. 따라서 슈가린정의 효능에 대해 알 수 없습니다.
# invoke 실행 시간: 1.1734895706176758 초
# 624 번째 답변 :  죄송합니다, 슈가린정에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 1.4536011219024658 초
# 625 번째 답변 :  슈가린정에 대한 정보가 제공되지 않았기 때문에 해당 제품에 대한 정보를 제공할 수 없습니다.
# invoke 실행 시간: 5.0613343715667725 초
# 626 번째 답변 :  슈가린정의 사용상 주의사항은 다음과 같습니다: 과민증 환자는 사용하지 마십시오. 눈, 눈 주위에는 사용하지 마십시오. 알레르기 증상 경험자, 습윤이나 짓무름이 심한 사람, 프로필렌글리콜에 과민증 환자 또는 경험자는 의사 또는 약사와 상의하십시오. 여드름, 뾰루지가 있는 부분에만 사용하고 주변의 넓은 부분이나 눈 주위에는 사용하지 마십시오. 눈에 들어가지 않도록 주의하고, 눈에 들어간 경우에는 즉시 물 또는 미지근한 물로 씻어내십시오.
# invoke 실행 시간: 3.830725908279419 초
# 627 번째 답변 :  슈가린정을 사용하는 동안 주의해야 할 약은 다른 한약(생약)제제, 칼륨함유제제, 감초함유제제, 글리시리진산 또는 그 염류 함유제제, 루프계 이뇨제(푸로세미드, 에타크린산) 또는 티아지드계 이뇨제(트리클로르메티아지드)와 함께 복용 시 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 5.513069152832031 초
# 628 번째 답변 :  슈가린정을 복용할 때 나타날 수 있는 이상반응으로는 피부점막안증후군(스티븐스-존슨증후군), 독성표피괴사용해(리엘증후군)과 같은 심각한 피부 손상, 열, 가려움, 비염, 기침, 인후염 등의 비특이적 인플루엔자-유사 전구증상이 있습니다. 또한, 구역, 구토, 설사, 소화불량, 두드러기, 피부 발진, 호흡곤란, 체온상승 등의 다양한 증상이 나타날 수 있습니다. 만약 이러한 증상이 나타나면 즉시 의사나 약사와 상의해야 합니다.
# invoke 실행 시간: 1.799668788909912 초
# 629 번째 답변 :  제공된 정보에는 "슈가린정"에 대한 정보가 없습니다. 따라서 슈가린정에 대한 보관 방법에 대한 정보를 제공할 수 없습니다.
# invoke 실행 시간: 1.5199358463287354 초
# 630 번째 답변 :  죄송합니다, 제가 찾은 정보에는 "슈가펜에스정"에 대한 내용이 포함되어 있지 않습니다.
# invoke 실행 시간: 1.2927381992340088 초
# 631 번째 답변 :  죄송합니다, 슈가펜에스정에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 1.1654272079467773 초
# 632 번째 답변 :  슈가펜에스정에 대한 정보를 찾을 수 없습니다.
# invoke 실행 시간: 1.2204360961914062 초
# 633 번째 답변 :  죄송합니다, "슈가펜에스정"에 대한 정보를 찾을 수 없습니다.
# invoke 실행 시간: 6.2057530879974365 초
# 634 번째 답변 :  슈가펜에스정을 사용하는 동안 주의해야 할 약 또는 음식은 파라세타몰, 카페인, 이미프라민, 옥사제팜, 펜타조신, 프로프라놀롤, 테오필린, 와파린, 에스트로겐, 리그노카인, 페나세틴, 인슐린, 아드레날린성 길항제(프라조신, 라베탈롤 등), 플레카이니드, 아드레날린성 효능제(이소프레날린, 페닐레프린), 프로폭시펜, 푸로세미드 이뇨제, H2길항제, 베타차단제, 테오필린, 타크린, 클로자핀, 로피니롤과 함께 사용 시 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 5.939704179763794 초
# 635 번째 답변 :  슈가펜에스정을 복용할 때 나타날 수 있는 이상반응에는 피부점막안증후군(스티븐스-존슨증후군), 독성표피괴사용해(리엘증후군)과 같은 심각한 피부 손상, 열, 가려움, 비염, 기침, 인후염 등의 비특이적 인플루엔자-유사 전구증상이 포함됩니다. 또한 구역, 구토, 설사, 소화불량, 두드러기, 피부 발진, 호흡곤란, 체온상승 등의 다양한 증상이 나타날 수 있습니다. 만약 이러한 증상이 나타나면 즉시 의사나 약사와 상의해야 합니다.
# invoke 실행 시간: 1.6291635036468506 초
# 636 번째 답변 :  슈가펜에스정은 실온에서 보관하고, 습기와 빛을 피해야 합니다. 어린이의 손이 닿지 않는 곳에 보관하는 것이 좋습니다.
# invoke 실행 시간: 1.4403257369995117 초
# 637 번째 답변 :  죄송합니다, 슈리머정에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 1.3989229202270508 초
# 638 번째 답변 :  죄송합니다, 슈리머정에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 1.6577212810516357 초
# 639 번째 답변 :  슈리머정에 대한 정보가 제공되지 않았기 때문에 해당 제품에 대한 내용을 파악할 수 없습니다.
# invoke 실행 시간: 1.6636228561401367 초
# 640 번째 답변 :  제공된 정보에는 "슈리머정"에 대한 내용이 포함되어 있지 않습니다. 따라서 "슈리머정"에 대한 사용상 주의사항에 대한 정보를 제공할 수 없습니다.
# invoke 실행 시간: 3.2034010887145996 초
# 641 번째 답변 :  슈리머정을 사용하는 동안 주의해야 할 약은 과산화수소와 함께 사용하지 말아야 하며, 리튬제제, 클로르헥시딘, 설파디아진ㆍ은화합물, 알칼리, 수은을 함유한 제제, 효소성분의 상처치료제와 함께 사용 시 의사 또는 약사와 상의해야 합니다. 음식에 대한 구체적인 정보는 제공되지 않았습니다.
# invoke 실행 시간: 4.414708614349365 초
# 642 번째 답변 :  슈리머정을 복용할 때 나타날 수 있는 이상반응으로는 구강건조증, 성욕소실, 불안, 졸음, 두통, 설사, 발진, 가려움, 유즙분비과다, 유방통증, 유방 누름 통증 등이 있습니다. 또한, 무력증, 아나필락시스 반응, 초조, 신경질, 어지러움, 추체외로장애, 경련, 안구운동발작, 심실부정맥, 급성 심장사 등의 이상반응이 나타날 수 있습니다.
# invoke 실행 시간: 1.6473543643951416 초
# 643 번째 답변 :  습기와 빛을 피해 실온에서 보관하십시오. 어린이의 손이 닿지 않는 곳에 보관하십시오.
# invoke 실행 시간: 2.8640148639678955 초
# 644 번째 답변 :  죄송합니다. 제공된 정보에는 "스노핀정275밀리그램(나프록센나트륨)"에 대한 정보가 포함되어 있지 않습니다.
# invoke 실행 시간: 1.085228681564331 초
# 645 번째 답변 :  죄송합니다, 그 정보는 제공된 정보에서 찾을 수 없습니다.
# invoke 실행 시간: 6.740310430526733 초
# 646 번째 답변 :  스노핀정275밀리그램(나프록센나트륨)을 사용하기 전에 알아야 할 내용은 다음과 같습니다: 이 약에 과민증 환자, 아스피린 또는 다른 비스테로이드성 항염증제, 천식, 코골이, 비염, 만성 기관지염, 심장병, 고혈압, 당뇨병, 신장병, 간장애, 위장관 궤양, 출혈 경향, 혈소판 감소, 혈액응고장애, 빈혈, 체중감소, 소화기관 출혈, 신경계 출혈, 뇌혈관질환, 고령자, 임부 또는 수유부, 청소년, 체중이 30kg 미만인 소아는 의사 또는 약사와 상의하십시오. 이 약은 위험성이 있으므로 정확한 처방 및 지도를 받아야 합니다.
# invoke 실행 시간: 1.0329577922821045 초
# 647 번째 답변 :  죄송합니다, 그 정보는 제공되지 않았습니다.
# invoke 실행 시간: 2.2584683895111084 초
# 648 번째 답변 :  스노핀정275밀리그램(나프록센나트륨)을 사용하는 동안 주의해야 할 약 또는 음식은 비스테로이드성 소염진통제와 함께 복용 시 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 5.498835325241089 초
# 649 번째 답변 :  스노핀정275밀리그램(나프록센나트륨) 복용 시 나타날 수 있는 이상반응은 적용부위에 화상, 결막염, 눈자극, 눈물흘림 증가, 탈모, 지각과민, 모낭염, 고름물집, 발진, 압통, 여드름, 탈모, 피부건조, 피부장애, 머릿결 이상, 머리카락 색 변화, 모낭염, 미각이상, 두드러기 등이 있습니다. 과민증상 및 자극감이 나타나면 즉시 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 1.5847795009613037 초
# 650 번째 답변 :  저는 스노핀정275밀리그램(나프록센나트륨)에 대한 정보를 찾을 수 없습니다.
# invoke 실행 시간: 1.8167574405670166 초
# 651 번째 답변 :  죄송합니다, 제가 찾은 정보에는 "스로쿨트로키(레몬향)(플루르비프로펜)"에 대한 정보가 없습니다.
# invoke 실행 시간: 1.6234290599822998 초
# 652 번째 답변 :  죄송합니다. 제가 찾은 정보에는 "스로쿨트로키(레몬향)(플루르비프로펜)"에 대한 정보가 없습니다.
# invoke 실행 시간: 1.7710998058319092 초
# 653 번째 답변 :  스로쿨트로키(레몬향)(플루르비프로펜)을 사용하기 전에 반드시 알아야 할 내용은 제공된 정보에는 없습니다.
# invoke 실행 시간: 5.0030481815338135 초
# 654 번째 답변 :  스로쿨트로키(레몬향)(플루르비프로펜)의 사용상 주의사항은 다음과 같습니다: 과민증 환자, 만 2세 미만의 영아, MAO억제제를 복용(사용)하고 있거나 복용(사용)을 중단한 후 2주 이내의 사람은 이 약을 사용하지 말아야 합니다. 또한, 임부 또는 임신 가능성이 있는 여성, 알레르기 체질, 고혈압, 심장질환, 당뇨병, 갑상선질환, 녹내장, 흡연, 천식, 만성 기관지염 등의 질환을 가진 분들은 의사나 약사와 상의해야 합니다. 3일간 사용하여도 증상의 개선이 없을 경우 사용을 즉각 중지하고 의사나 약사와 상의해야 합니다.
# invoke 실행 시간: 6.004051685333252 초
# 655 번째 답변 :  파라세타몰, 카페인, 이미프라민, 옥사제팜, 펜타조신, 프로프라놀롤, 테오필린, 와파린, 에스트로겐, 리그노카인, 페나세틴, 인슐린, 아드레날린성 길항제(프라조신, 라베탈롤 등), 플레카이니드, 아드레날린성 효능제(이소프레날린, 페닐레프린), 프로폭시펜, 푸로세미드 이뇨제, H2길항제, 베타차단제, 테오필린, 타크린, 클로자핀, 로피니롤과 함께 사용 시 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 1.6524441242218018 초
# 656 번째 답변 :  저는 스로쿨트로키(레몬향)(플루르비프로펜)에 대한 정보를 찾을 수 없습니다.
# invoke 실행 시간: 2.3028974533081055 초
# 657 번째 답변 :  스로쿨트로키(레몬향)(플루르비프로펜)은 습기와 빛을 피해 실온에서 보관해야 합니다. 또한 어린이의 손이 닿지 않는 곳에 보관해야 합니다.
# invoke 실행 시간: 2.211254358291626 초
# 658 번째 답변 :  제공된 정보에는 "스몰크림(프레드니솔론발레로아세테이트)"에 대한 정보가 없기 때문에 해당 제품의 효능에 대한 정보를 확인할 수 없습니다.
# invoke 실행 시간: 1.9587736129760742 초
# 659 번째 답변 :  죄송합니다, 제공된 정보에는 "스몰크림(프레드니솔론발레로아세테이트)"에 대한 정보가 포함되어 있지 않습니다. 해당 제품에 대한 사용 방법에 대한 정보를 제공할 수 없습니다.
# invoke 실행 시간: 4.596291542053223 초
# 660 번째 답변 :  스몰크림(프레드니솔론발레로아세테이트)을 사용하기 전에 반드시 알아야 할 내용은 다음과 같습니다: 과민증 환자, 매독, 결핵, 피부감염증, 백신접종 후 이상반응을 보인 환자, 진균증, 경구주위 피부염, 주사 환자는 사용하지 말아야 합니다. 또한 임부 또는 임신 가능성이 있는 여성, 수유부, 소아, 고령자는 의사 또는 약사와 상의해야 합니다. 이 약은 외용으로만 사용해야 합니다.
# invoke 실행 시간: 4.533354759216309 초
# 661 번째 답변 :  스몰크림(프레드니솔론발레로아세테이트)의 사용상 주의사항은 다음과 같습니다: 이 약에 과민증 환자, 매독, 결핵, 피부감염증, 백신접종 후 이상반응을 보인 환자, 진균증, 경구주위 피부염, 주사 환자는 사용을 피해야 합니다. 또한, 임부 또는 임신 가능성이 있는 여성, 수유부, 소아, 고령자는 의사나 약사와 상의해야 합니다. 이 약은 외용으로만 사용해야 합니다.
# invoke 실행 시간: 6.537882566452026 초
# 662 번째 답변 :  스몰크림(프레드니솔론발레로아세테이트)을 사용하는 동안 주의해야 할 약은 다른 비스테로이드성 소염진통제(NSAIDs) 및 살리실산 제제, 고용량의 메토트렉세이트(15mg/주 이상)와 함께 복용하지 말아야 합니다. 또한 이뇨제, 통풍약, 관절염약, 스테로이드제, 항응고제, 혈전용해제, 다른 혈소판응집억제제, 지혈제, 당뇨병치료제, 요산배설촉진제, 저용량의 메토트렉세이트, 리튬제제, 이부프로펜, 선택적 세로토닌 재흡수 억제제, 디곡신, ACE 억제제, 발프로산과 함께 복용 시 의사와 상의해야 합니다.
# invoke 실행 시간: 5.121235370635986 초
# 663 번째 답변 :  스몰크림(프레드니솔론발레로아세테이트)의 사용상 주의사항에 따르면, 이 약에 과민증 환자, 피부감염증, 고막 천공이 있는 습진성 외이도염, 궤양, 제2도 심재성 이상의 화상 및 동상, 입주위피부염, 보통여드름, 주사 환자는 이 약을 사용하지 말아야 합니다. 또한, 임부 또는 임신 가능성이 있는 여성, 수유부, 유ㆍ소아, 고령자는 의사나 약사와 상의해야 합니다. 안과용으로 사용하거나 화장이나 면도 후 치료 이외의 목적으로 사용하면 안 됩니다.
# invoke 실행 시간: 2.0258796215057373 초
# 664 번째 답변 :  제공된 정보에는 "스몰크림(프레드니솔론발레로아세테이트)"에 대한 정보가 없기 때문에 해당 제품에 대한 보관 방법에 대한 정보를 제공할 수 없습니다.
# invoke 실행 시간: 2.1104419231414795 초
# 665 번째 답변 :  스무스케어로션2.5%(히드로코르티손)은 습진ㆍ피부염군, 피부가려움, 벌레물린데에 사용됩니다.
# invoke 실행 시간: 2.5087203979492188 초
# 666 번째 답변 :  스무스케어로션2.5%(히드로코르티손)은 사용 전 잘 흔들어 섞은 후 1일 1~3회 적당량을 환부(질환 부위)에 바르고 증상에 따라 적절히 증감합니다. 이 약의 치료기간은 7일 이내로 제한됩니다.
# invoke 실행 시간: 6.360363245010376 초
# 667 번째 답변 :  스무스케어로션2.5%(히드로코르티손)을 사용하기 전에 반드시 알아야 할 내용은 다음과 같습니다: 이 약에 과민증 환자, 피부 감염증(결핵, 매독, 칸디다증, 백선, 대상포진, 단순포진, 수두, 종두증, 옴, 사면발이), 고막 천공이 있는 습진성 외이도염, 궤양(베체트병 제외), 제2도 심재성 이상의 화상 및 동상, 입주위피부염, 보통여드름, 주사 환자, 2세 미만의 유아는 이 약을 사용하지 마십시오. 임부 및 임신하고 있을 가능성이 있는 여성, 수유부, 유ㆍ소아, 고령자, 프로필렌글리콜에 과민증 환자 또는 경험자는 의사 또는 약사와 상의하십시오. 안과용으로 사용하지 마십시오.
# invoke 실행 시간: 1.732703685760498 초
# 668 번째 답변 :  죄송합니다, 스무스케어로션2.5%(히드로코르티손)에 대한 사용상 주의사항에 대한 정보를 찾을 수 없습니다.
# invoke 실행 시간: 6.329031229019165 초
# 669 번째 답변 :  스무스케어로션2.5%(히드로코르티손)을 사용하는 동안 주의해야 할 약 또는 음식은 다른 비스테로이드성 소염진통제, 아스피린, 메토트렉세이트, 코르티코스테로이드, 알코올, 디곡신, 페니토인, 프로베네시드, 설핀피라존, 설포닐우레아제, ACE 억제제 또는 안지오텐신Ⅱ 수용체 길항제, 이뇨제, 리튬, CYP2C8, CYP2C9의 유도제, 항혈소판제 및 선택적 세로토닌 재흡수 억제제(SSRI)를 함께 복용하는 경우 의사 또는 약사와 상의해야 합니다. 과도한 음주나 흡연을 삼가하십시오.
# invoke 실행 시간: 8.041432857513428 초
# 670 번째 답변 :  스무스케어로션2.5%(히드로코르티손)의 이상반응으로는 쇽, 아나필락시양 반응(과민성 유사), 흉내고민(가슴쓰림), 오한, 호흡곤란, 혈압저하, 헤마토크릿 감소, 헤모글로빈 감소, 재생불량성빈혈, 용혈성빈혈, 무과립구증, 과립구감소, 백혈구감소, 혈소판감소, 혈소판 기능 저하(출혈시간 연장) 등이 있습니다. 또한 소화성궤양, 위장관궤양, 위장출혈, 천공(뚫림), 궤양성 대장염, 혈변, 위염, 췌장염, 토혈(혈액구토), 크론병, 식욕부진, 구역, 구토, 복통, 소화불량, 설사, 위부불쾌감, 상복부 통증, 구갈, 구내염, 복부팽만감, 구강궤양, 변비, 흑변 등의 이상반응이 나타날 수 있습니다.
# invoke 실행 시간: 2.9076364040374756 초
# 671 번째 답변 :  스무스케어로션2.5%(히드로코르티손)은 25도 미만의 실온에서 보관해야 합니다. 직사광선을 피하고 밀폐하여 습기가 없는 곳에 보관하는 것이 좋습니다. 어린이의 손이 닿지 않는 곳에 보관해야 합니다.
# invoke 실행 시간: 1.7592875957489014 초
# 672 번째 답변 :  죄송합니다. "스웨트롤패드액(글리코피롤레이트)"에 대한 정보를 찾을 수 없습니다.
# invoke 실행 시간: 1.589595079421997 초
# 673 번째 답변 :  죄송합니다, "스웨트롤패드액(글리코피롤레이트)"에 대한 정보는 제공되지 않았습니다.
# invoke 실행 시간: 1.6718804836273193 초
# 674 번째 답변 :  스웨트롤패드액(글리코피롤레이트)을 사용하기 전에 반드시 알아야 할 내용은 제공된 정보에는 없습니다.
# invoke 실행 시간: 3.0439772605895996 초
# 675 번째 답변 :  제공된 정보에는 "스웨트롤패드액(글리코피롤레이트)"에 대한 내용이 없습니다. 따라서 해당 제품에 대한 사용상 주의사항을 확인할 수 없습니다.
# invoke 실행 시간: 4.3802571296691895 초
# 676 번째 답변 :  스웨트롤패드액(글리코피롤레이트)을 사용하는 동안 주의해야 할 약 또는 음식은 다른 한약(생약)제제, 칼륨함유제제, 감초함유제제, 글리시리진산 또는 그 염류 함유제제, 루프계 이뇨제(푸로세미드, 에타크린산) 또는 티아지드계 이뇨제(트리클로르메티아지드)와 함께 복용 시 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 4.699635028839111 초
# 677 번째 답변 :  스웨트롤패드액(글리코피롤레이트) 복용 시 나타날 수 있는 이상반응은 발진, 발적, 가려움, 구역, 구토, 식욕부진, 변비, 부종, 배뇨곤란, 어지러움, 불안, 떨림, 불면, 쇽 증상, 피부점막안증후군, 독성표피괴사용해, 천식, 전신의 나른함, 황달, 간질성폐렴, 위알도스테론증, 근병증 등이 있습니다. 이러한 증상이 나타날 경우 즉시 의사 또는 약사와 상의해야 합니다.
# invoke 실행 시간: 2.3088796138763428 초
# 678 번째 답변 :  제공된 정보에는 "스웨트롤패드액(글리코피롤레이트)"에 대한 정보가 없습니다. 따라서 해당 제품에 대한 보관 방법에 대한 정보를 제공할 수 없습니다.
# invoke 실행 시간: 4.780855417251587 초
# 679 번째 답변 :  스카이정의 효능은 육체피로, 임신ㆍ수유기, 병중ㆍ병후(병을 앓는 동안이나 회복 후)의 체력 저하 시 비타민 B1, B2, B6, C의 보급과 신경통, 근육통, 관절통(요통, 어깨결림 등), 구각염(입꼬리염), 구순염(입술염), 구내염(입안염), 설염(혀염), 습진, 피부염 증상의 완화, 각기, 눈의 피로와 아연의 보급에 사용합니다.
# invoke 실행 시간: 2.01416015625 초
# 680 번째 답변 :  죄송합니다, "스카이정"에 대한 정보가 제공된 문맥에서 찾을 수 없습니다. 해당 제품에 대한 정보가 없기 때문에 사용 방법에 대해 알 수 없습니다.
# invoke 실행 시간: 1.7895393371582031 초
# 681 번째 답변 :  스카이정에 대한 정보가 제공되지 않았기 때문에 스카이정을 사용하기 전에 반드시 알아야 할 내용에 대한 정보를 제공할 수 없습니다.
# invoke 실행 시간: 8.748095750808716 초
# 682 번째 답변 :  스카이정의 사용상 주의사항은 다음과 같습니다: 이 약을 복용하기 전에 약에 과민증 환자, 두드러기, 접촉성 피부염, 기관지천식, 알레르기성 비염, 편두통, 음식물 알레르기 등을 일으키기 쉬운 체질을 갖고 있는 사람, 알레르기 증상(예: 발열, 발진, 관절통, 천식, 가려움증 등) 경험자, 수두 또는 인플루엔자에 감염되어 있거나 또는 의심되는 영·유아 및 어린이 (14세 이하), 간장, 신장, 갑상선질환, 당뇨병, 고혈압, 고열, 몸이 약한 사람, 고령자, 임부 또는 임신하고 있을 가능성이 있는 여성 및 수유부는 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 3.6884384155273438 초
# 683 번째 답변 :  스카이정을 사용하는 동안 주의해야 할 약 또는 음식은 다른 한약(생약)제제, 칼륨함유제제, 감초함유제제, 글리시리진산 또는 그 염류 함유제제, 루프계 이뇨제(푸로세미드, 에타크린산) 또는 티아지드계 이뇨제(트리클로르메티아지드)와 함께 복용 시 의사 또는 약사와 상의하십시오.
# invoke 실행 시간: 2.7043979167938232 초
# 684 번째 답변 :  스카이정은 구강건조증, 성욕소실, 불안, 졸음, 두퉁, 설사, 발진, 가려움, 유즙분비과다, 유방통증, 유방 누름 통증, 무력증, 아나필락시스 반응 등의 이상반응이 나타날 수 있습니다.
# invoke 실행 시간: 1.0555963516235352 초
# 685 번째 답변 :  습기와 빛을 피해 실온에서 보관하십시오.

# %%
question = test_data['question']
test_output = pd.DataFrame({"question": question,
                            "answer" : answer})
test_output.to_excel("e약은요 1차 테스트 결과.xlsx",index = False)

# %% [markdown]
# ### db 초기화
# ```python
# # To cleanup, you can delete the collection
# vectordb.delete_collection()
# vectordb.persist()
# ```
